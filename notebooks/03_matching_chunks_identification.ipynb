# %% [markdown]
# # Identify the 3 top matching chunks using LlamaIndex

# %% [markdown]
# LlamaIndex:
# - Github: https://github.com/run-llama/llama_index
# - Documentation: https://docs.llamaindex.ai/en/latest/

# %%
import pandas as pd

# read the xlsx data into a pandas dataframe
df = pd.read_excel(f"../data/ReferenceErrorDetection_data_extended_annotation.xlsx")

# %%
df.head()
# Out:
#     Source Citing Article ID         Citing Article DOI  \
# 0  PubPeer              c001  10.1016/j.est.2021.103553
# 1  PubPeer              c001  10.1016/j.est.2021.103553
# 2  PubPeer              c002       10.1155/2022/4601350
# 3  PubPeer              c003       10.1155/2022/2408685
# 4  PubPeer              c004       10.1155/2022/4783847
#
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain Citation ID  \
# 0                       Yes  Engineering    cit001_1
# 1                       Yes  Engineering    cit001_2
# 2                       Yes    Chemistry    cit002_1
# 3                       Yes     Medicine    cit003_1
# 4                       Yes  Engineering    cit004_1
#
#                              Statement with Citation  \
# 0  Others have aimed to reduce irreversibility or...
# 1  Some researchers have also studied various hea...
# 2  The relative content of total flavonoids in th...
# 3  Research has shown that remimazolam tosylate e...
# 4  if the efficiency of the routing algorithm is ...
#
#                                  Corrected Statement  ...  \
# 0  Others have aimed to reduce irreversibility or...  ...
# 1  Some researchers have also studied various hea...  ...
# 2  The relative content of total flavonoids in th...  ...
# 3  Research has shown that remimazolam tosylate e...  ...
# 4  If the efficiency of the routing algorithm is ...  ...
#
#                              Reference Article Title  \
# 0  A Fault Analysis Method for Three-Phase Induct...
# 1  Develop 24 dissimilar ANNs by suitable archite...
# 2  Lipid Data Acquisition for devices Treatment o...
# 3  Effect of propofol on breast cancer cell, the ...
# 4  Analysis and research hotspots of ceramic mate...
#
#                           Reference Article Abstract  \
# 0  The fault prediction and abductive fault diagn...
# 1  The artificial neural network optimization met...
# 2  Recently, the widespread deployment of smart p...
# 3  Breast cancer is the second leading cause of c...
# 4  From the perspective of scientometrics, comb t...
#
#   Reference Article PDF Available  Reference Article Retracted  \
# 0                             Yes                           No
# 1                             Yes                           No
# 2                             Yes                           No
# 3                             Yes                           No
# 4                             Yes                           No
#
#    Reference Article Downloaded            Label Explanation  Error Type  \
# 0                           Yes  Unsubstantiated  Irrelevant  Irrelevant
# 1                           Yes  Unsubstantiated  Irrelevant  Irrelevant
# 2                           Yes  Unsubstantiated  Irrelevant  Irrelevant
# 3                           Yes  Unsubstantiated  Irrelevant  Irrelevant
# 4                           Yes  Unsubstantiated  Irrelevant  Irrelevant
#
#   Added Previously Partially Substantiated
# 0    No                                NaN
# 1    No                                NaN
# 2    No                                NaN
# 3    No                                NaN
# 4    No                                NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Get text from reference article

# %%
extension = "txt"

# %%
import glob

def get_file_path(reference_article_id):
    # Construct the file path pattern using the Reference Article ID of the first entry
    file_pattern = f"../data/extractions/{'only_text/' if extension == 'txt' else ''}{reference_article_id}*.{extension}"

    # Find the file that matches the pattern
    file_list = glob.glob(file_pattern)
    if file_list:
        file_path = file_list[0]
        return file_path
    else: 
        print("No matching file found.")
        return None

# %%
import xml.etree.ElementTree as ET

def get_reference_text(reference_article_id):
    # Get the file path
    file_path = get_file_path(reference_article_id)
    
    if file_path:
        if extension == "txt":
            # Read the text file
            with open(file_path, 'r') as file:
                reference_text = file.read()
            return reference_text

        elif extension == "xml":
            # Parse the XML file
            tree = ET.parse(file_path)
            root = tree.getroot()

            # Extract the text content from the XML file
            reference_text = ''.join(root.itertext())
            return reference_text

# %% [markdown]
# ## Set OpenAI key

# %%
# Read the content of open_ai_key.txt into a variable
with open('../open_ai_key.txt', 'r') as file:
    open_ai_key = file.read().strip()

# %% [markdown]
# ## Setting up vector index

# %% [markdown]
# ### Reloading or generating index

# %%
model_embeddings = "text-embedding-3-large"

# %%
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import Settings

Settings.embed_model = OpenAIEmbedding(model=model_embeddings, api_key=open_ai_key)

# %%
from llama_index.core import VectorStoreIndex, Document
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.ingestion import IngestionPipeline

def create_index(reference_text, chunk_size, chunk_overlap):
    # create the pipeline with transformations
    pipeline = IngestionPipeline(
        transformations=[
            SentenceSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap),
            OpenAIEmbedding(model=model_embeddings, api_key=open_ai_key)
        ]
    )

    # run the pipeline
    nodes = pipeline.run(documents=[Document(text=reference_text)])
    index = VectorStoreIndex(nodes)
    return index

# %%
from llama_index.core import StorageContext, load_index_from_storage
import os

def load_or_create_index(article_id, reference_text, chunk_size, chunk_overlap, only_checking=False):
    index_path = f"../data/vector_indices/{'only_text_' if extension == 'txt' else ''}{chunk_size}_{chunk_overlap}/{article_id}/"
    index = None
    if only_checking:
        if os.path.exists(index_path) and os.listdir(index_path):
            print(article_id + ": Index exists.")
            return True
        
    assert reference_text is not None and reference_text != '', "Reference text cannot be None or empty."

    try:
        storage_context = StorageContext.from_defaults(persist_dir=index_path)
        index = load_index_from_storage(storage_context)
        print(article_id + ": Loaded existing index.")
    except Exception as e:
        print(e)
        print(article_id + ": Creating a new index.")
        try: 
            index = create_index(reference_text, chunk_size, chunk_overlap)
            index.storage_context.persist(persist_dir=index_path)
        except Exception as e:
            print(e)
            print(article_id + ": Failed to create index.")
            print(reference_text)
    return index

# %% [markdown]
# ### Create Indices for all reference articles

# %%
chunk_size = 1024
chunk_overlap = 20

# %% [markdown]
# around 9 minutes per chunk_size

# %%
# %%time

for _, row in df.iterrows():
    if row['Reference Article Downloaded'] == 'Yes':
        reference_article_id = row['Reference Article ID']
        if reference_article_id:
            reference_text = get_reference_text(reference_article_id)
            index = load_or_create_index(reference_article_id, reference_text, chunk_size, chunk_overlap, only_checking=True)
# Out:
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r001/docstore.json'
# r001: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r002/docstore.json'
# r002: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r003/docstore.json'
# r003: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/
Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r194/docstore.json'
# r194: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r195/docstore.json'
# r195: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r196/docstore.json'
# r196: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r197/docstore.json'
# r197: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r198/docstore.json'
# r198: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r199/docstore.json'
# r199: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r200/docstore.json'
# r200: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r201/docstore.json'
# r201: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r202/docstore.json'
# r202: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r203/docstore.json'
# r203: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r204/docstore.json'
# r204: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r205/docstore.json'
# r205: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r206/docstore.json'
# r206: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r207/docstore.json'
# r207: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r208/docstore.json'
# r208: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r209/docstore.json'
# r209: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r211/docstore.json'
# r211: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r212/docstore.json'
# r212: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r213/docstore.json'
# r213: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r214/docstore.json'
# r214: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r215/docstore.json'
# r215: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r216/docstore.json'
# r216: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r217/docstore.json'
# r217: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r218/docstore.json'
# r218: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r219/docstore.json'
# r219: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r220/docstore.json'
# r220: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r222/docstore.json'
# r222: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r223/docstore.json'
# r223: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r224/docstore.json'
# r224: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r225/docstore.json'
# r225: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r226/docstore.json'
# r226: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r227/docstore.json'
# r227: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r228/docstore.json'
# r228: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r229/docstore.json'
# r229: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r230/docstore.json'
# r230: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r231/docstore.json'
# r231: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r232/docstore.json'
# r232: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r233/docstore.json'
# r233: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r234/docstore.json'
# r234: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r236/docstore.json'
# r236: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r237/docstore.json'
# r237: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r239/docstore.json'
# r239: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r240/docstore.json'
# r240: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r242/docstore.json'
# r242: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/only_text_1024_20/r243/docstore.json'
# r243: Creating a new index.
# CPU times: user 1min 13s, sys: 1.25 s, total: 1min 14s
# Wall time: 3min 54s

# %% [markdown]
# ## Identifying top 3 chunks

# %%
from llama_index.core.retrievers import VectorIndexRetriever

def get_top_k_similar_chunks(statement, index, k=3):
    retriever = VectorIndexRetriever(
        index=index,
        similarity_top_k=k,
    )
    retrieved_nodes = retriever.retrieve(statement)
    return retrieved_nodes

# %%
import json
import os

def save_similar_chunks(doc_ids, reference_id, chunk_size, chunk_overlap):
    file_path = f"../data/similar_chunks/{'only_text_' if extension == 'txt' else ''}{chunk_size}_{chunk_overlap}/{reference_id}.json"
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    with open(file_path, 'w') as file:
        json.dump(doc_ids, file)

def load_similar_chunks(reference_id, chunk_size, chunk_overlap):
    file_path = f"../data/similar_chunks/{'only_text_' if extension == 'txt' else ''}{chunk_size}_{chunk_overlap}/{reference_id}.json"
    with open(file_path, 'r') as file:
        doc_ids = json.load(file)
    return doc_ids

# %% [markdown]
# ### Save the document ids and text contents of the top k chunks of all reference articles to the df

# %%
def get_doc_ids(response):
    doc_ids = []
    for node in response:
        doc_ids.append(node.dict()['node']['id_'])
    return doc_ids

# %%
def save_top_k_chunk_ids(df, chunk_size, chunk_overlap, k=3):
    for _, row in df.iterrows():
        if row['Reference Article Downloaded'] == 'Yes':
            reference_article_id = row['Reference Article ID']
            print(f"------ Starting {reference_article_id} ------")
            
            # Try to load similar chunks first
            try:
                doc_ids = load_similar_chunks(reference_article_id, chunk_size, chunk_overlap)
                print("Loaded similar chunks successfully.")
            except FileNotFoundError:
                # Load reference text and create chunks
                reference_text = get_reference_text(reference_article_id)
                
                # Load or create index
                index = load_or_create_index(reference_article_id, reference_text, chunk_size, chunk_overlap)
                
                # Get the statement and retrieve top chunks
                statement = row["Corrected Statement"]

                print("Receiving top chunks")

                try:
                    response = get_top_k_similar_chunks(statement, index, k)
                    doc_ids = get_doc_ids(response)
                    
                    # Save the top chunks
                    print("Saving top chunks")
                    save_similar_chunks(doc_ids, reference_article_id, chunk_size, chunk_overlap)
                except Exception as e:
                    print(e)
                    print("Failed to get top chunks.")
            print("")

# %% [markdown]
# around 6,5 minutes per chunk_size

# %%
# %%time 

save_top_k_chunk_ids(df, chunk_size, chunk_overlap, k=3)
# Out:
# ------ Starting r001 ------
# r001: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r002 ------
# r002: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r003 ------
# r003: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r004 ------
# r004: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r005 ------
# r005: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r006 ------
# r006: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r007 ------
# r007: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r008 ------
# r008: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r009 ------
# r009: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r010 ------
# r010: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r011 ------
# r011: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r012 ------
# r012: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r013 ------
# r013: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r013 ------
# Loaded similar chunks successfully.
#
# ------ Starting r014 ------
# r014: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r015 ------
# r015: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r005 ------
# Loaded similar chunks successfully.
#
# ------ Starting r018 ------
# r018: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r019 ------
# r019: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r020 ------
# r020: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r021 ------
# r021: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r022 ------
# r022: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r023 ------
# r023: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r024 ------
# r024: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r013 ------
# Loaded similar chunks successfully.
#
# ------ Starting r025 ------
# r025: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r026 ------
# r026: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r028 ------
# r028: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r027 ------
# r027: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r029 ------
# r029: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r030 ------
# r030: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r031 ------
# r031: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r032 ------
# r032: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r033 ------
# r033: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r034 ------
# r034: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r035 ------
# r035: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r036 ------
# r036: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r037 ------
# r037: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r038 ------
# r038: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r039 ------
# r039: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r040 ------
# r040: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r041 ------
# r041: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r042 ------
# r042: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r043 ------
# r043: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r044 ------
# r044: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r045 ------
# r045: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r046 ------
# r046: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r047 ------
# r047: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r048 ------
# r048: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r049 ------
# r049: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r050 ------
# r050: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r051 ------
# r051: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r052 ------
# r052: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r053 ------
# r053: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r051 ------
# Loaded similar chunks successfully.
#
# ------ Starting r055 ------
# r055: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r056 ------
# r056: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r057 ------
# r057: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r058 ------
# r058: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r059 ------
# r059: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r060 ------
# r060: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r061 ------
# r061: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r062 ------
# r062: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r063 ------
# r063: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r064 ------
# r064: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r065 ------
# r065: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r066 ------
# r066: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r068 ------
# r068: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r067 ------
# r067: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r069 ------
# r069: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r070 ------
# r070: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r071 ------
# r071: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r072 ------
# r072: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r074 ------
# r074: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r075 ------
# r075: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r076 ------
# r076: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r077 ------
# r077: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r078 ------
# r078: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r079 ------
# r079: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r080 ------
# r080: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r081 ------
# r081: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r081 ------
# Loaded similar chunks successfully.
#
# ------ Starting r082 ------
# r082: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r083 ------
# r083: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r084 ------
# r084: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r085 ------
# r085: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r086 ------
# r086: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r087 ------
# r087: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r087 ------
# Loaded similar chunks successfully.
#
# ------ Starting r087 ------
# Loaded similar chunks successfully.
#
# ------ Starting r088 ------
# r088: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r145 ------
# r145: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r146 ------
# r146: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r089 ------
# r089: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r090 ------
# r090: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r153 ------
# r153: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r091 ------
# r091: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r092 ------
# r092: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r093 ------
# r093: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r094 ------
# r094: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r095 ------
# r095: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r096 ------
# r096: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r097 ------
# r097: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r098 ------
# r098: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r182 ------
# r182: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r183 ------
# r183: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r184 ------
# r184: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r099 ------
# r099: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r100 ------
# r100: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r101 ------
# r101: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r102 ------
# r102: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r103 ------
# r103: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r104 ------
# r104: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r105 ------
# r105: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r106 ------
# r106: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r107 ------
# r107: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r210 ------
# r210: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r108 ------
# r108: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r221 ------
# r221: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r109 ------
# r109: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r110 ------
# r110: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r111 ------
# r111: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r112 ------
# r112: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r113 ------
# r113: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r114 ------
# r114: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r235 ------
# r235: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r115 ------
# r115: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r116 ------
# r116: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r238 ------
# r238: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r117 ------
# r117: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r118 ------
# r118: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r119 ------
# r119: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r241 ------
# r241: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r120 ------
# r120: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r121 ------
# r121: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r122 ------
# r122: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r123 ------
# r123: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r124 ------
# r124: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r125 ------
# r125: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r126 ------
# r126: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r127 ------
# r127: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r128 ------
# r128: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r129 ------
# r129: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r130 ------
# r130: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r131 ------
# r131: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r132 ------
# r132: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r133 ------
# r133: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r134 ------
# r134: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r135 ------
# r135: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r136 ------
# r136: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r137 ------
# r137: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r138 ------
# r138: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r139 ------
# r139: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r140 ------
# r140: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r141 ------
# r141: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r142 ------
# r142: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r143 ------
# r143: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r144 ------
# r144: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r147 ------
# r147: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r148 ------
# r148: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r149 ------
# r149: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r150 ------
# r150: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r151 ------
# r151: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r152 ------
# r152: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r154 ------
# r154: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r155 ------
# r155: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r156 ------
# r156: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r157 ------
# r157: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r158 ------
# r158: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r159 ------
# r159: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r160 ------
# r160: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r161 ------
# r161: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r162 ------
# r162: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r163 ------
# r163: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r164 ------
# r164: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r165 ------
# r165: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r166 ------
# r166: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r167 ------
# r167: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r168 ------
# r168: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r169 ------
# r169: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r170 ------
# r170: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r170 ------
# Loaded similar chunks successfully.
#
# ------ Starting r171 ------
# r171: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r172 ------
# r172: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r173 ------
# r173: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r174 ------
# r174: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r175 ------
# r175: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r176 ------
# r176: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r177 ------
# r177: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r178 ------
# r178: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r179 ------
# r179: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r180 ------
# r180: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r181 ------
# r181: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r185 ------
# r185: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r186 ------
# r186: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r187 ------
# r187: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r188 ------
# r188: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r189 ------
# r189: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r190 ------
# r190: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r191 ------
# r191: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r192 ------
# r192: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r193 ------
# r193: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r194 ------
# r194: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r195 ------
# r195: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r196 ------
# r196: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r197 ------
# r197: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r198 ------
# r198: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r199 ------
# r199: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r200 ------
# r200: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r201 ------
# r201: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r202 ------
# r202: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r203 ------
# r203: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r204 ------
# r204: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r205 ------
# r205: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r206 ------
# r206: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r207 ------
# r207: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r208 ------
# r208: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r209 ------
# r209: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r211 ------
# r211: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r212 ------
# r212: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r213 ------
# r213: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r214 ------
# r214: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r215 ------
# r215: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r216 ------
# r216: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r217 ------
# r217: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r218 ------
# r218: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r219 ------
# r219: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r220 ------
# r220: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r222 ------
# r222: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r223 ------
# r223: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r224 ------
# r224: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r225 ------
# r225: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r226 ------
# r226: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r227 ------
# r227: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r228 ------
# r228: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r229 ------
# r229: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r230 ------
# r230: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r231 ------
# r231: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r232 ------
# r232: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r233 ------
# r233: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r234 ------
# r234: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r236 ------
# r236: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r237 ------
# r237: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r239 ------
# r239: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r240 ------
# r240: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r242 ------
# r242: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r243 ------
# r243: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# CPU times: user 47.6 s, sys: 332 ms, total: 47.9 s
# Wall time: 2min 9s

# %%
import pandas as pd

output_dir = f"../data/dfs/{'only_text_' if extension == 'txt' else ''}{chunk_size}_{chunk_overlap}/"
os.makedirs(output_dir, exist_ok=True)
# df2 = pd.read_pickle(os.path.join(output_dir, f"ReferenceErrorDetection_data_with_chunk_info.pkl"))

# %%
def add_top_k_chunk_ids_and_texts_to_df(df, chunk_size, chunk_overlap, k=3):
    doc_ids_list = []
    doc_texts_list = []
    for _, row in df.iterrows():
        if row['Reference Article Downloaded'] == 'Yes':
            reference_article_id = row['Reference Article ID']
            
            print(f"------ Starting {reference_article_id} ------")

            # load index
            index_path = f"../data/vector_indices/{'only_text_' if extension == 'txt' else ''}{chunk_size}_{chunk_overlap}/{reference_article_id}/"
            storage_context = StorageContext.from_defaults(persist_dir=index_path)
            index = load_index_from_storage(storage_context)

            # load similar chunks
            doc_ids = load_similar_chunks(reference_article_id, chunk_size, chunk_overlap)
            doc_texts = [index.docstore.docs[doc_id].text for doc_id in doc_ids]

            # add to lists
            doc_ids_list.append(doc_ids)
            doc_texts_list.append(doc_texts)
        else:
            doc_ids_list.append(None)
            doc_texts_list.append(None)
    
    df[f'Top_{k}_Chunk_IDs'] = doc_ids_list
    df[f'Top_{k}_Chunk_Texts'] = doc_texts_list
    return df

# %% [markdown]
# around 4,5 minutes per chunk_size

# %%
df2 = add_top_k_chunk_ids_and_texts_to_df(df, chunk_size, chunk_overlap, k=3)
# Out:
# ------ Starting r001 ------
# ------ Starting r002 ------
# ------ Starting r003 ------
# ------ Starting r004 ------
# ------ Starting r005 ------
# ------ Starting r006 ------
# ------ Starting r007 ------
# ------ Starting r008 ------
# ------ Starting r009 ------
# ------ Starting r010 ------
# ------ Starting r011 ------
# ------ Starting r012 ------
# ------ Starting r013 ------
# ------ Starting r013 ------
# ------ Starting r014 ------
# ------ Starting r015 ------
# ------ Starting r005 ------
# ------ Starting r018 ------
# ------ Starting r019 ------
# ------ Starting r020 ------
# ------ Starting r021 ------
# ------ Starting r022 ------
# ------ Starting r023 ------
# ------ Starting r024 ------
# ------ Starting r013 ------
# ------ Starting r025 ------
# ------ Starting r026 ------
# ------ Starting r028 ------
# ------ Starting r027 ------
# ------ Starting r029 ------
# ------ Starting r030 ------
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain Citation ID  \
# 0                       Yes  Engineering    cit001_1
# 1                       Yes  Engineering    cit001_2
# 2                       Yes    Chemistry    cit002_1
# 3                       Yes     Medicine    cit003_1
# 4                       Yes  Engineering    cit004_1
#
#                              Statement with Citation  \
# 0  Others have aimed to reduce irreversibility or...
# 1  Some researchers have also studied various hea...
# 2  The relative content of total flavonoids in th...
# 3  Research has shown that remimazolam tosylate e...
# 4  if the efficiency of the routing algorithm is ...
#
#                                  Corrected Statement  ...  \
# 0  Others have aimed to reduce irreversibility or...  ...
# 1  Some researchers have also studied various hea...  ...
# 2  The relative content of total flavonoids in th...  ...
# 3  Research has shown that remimazolam tosylate e...  ...
# 4  If the efficiency of the routing algorithm is ...  ...
#
#   Reference Article PDF Available Reference Article Retracted  \
# 0                             Yes                          No
# 1                             Yes                          No
# 2                             Yes                          No
# 3                             Yes                          No
# 4                             Yes                          No
#
#   Reference Article Downloaded            Label  Explanation  Error Type  \
# 0                          Yes  Unsubstantiated   Irrelevant  Irrelevant
# 1                          Yes  Unsubstantiated   Irrelevant  Irrelevant
# 2                          Yes  Unsubstantiated   Irrelevant  Irrelevant
# 3                          Yes  Unsubstantiated   Irrelevant  Irrelevant
# 4                          Yes  Unsubstantiated   Irrelevant  Irrelevant
#
#   Added Previously Partially Substantiated  \
# 0    No                                NaN
# 1    No                                NaN
# 2    No                                NaN
# 3    No                                NaN
# 4    No                                NaN
#
#                                      Top_3_Chunk_IDs  \
# 0  [2d702f6c-a1b1-4e0d-bc5b-efc4a257f7e3, 55221b8...
# 1  [118c524c-3f14-4fe2-8d06-ce6d6570e788, d5cf0f4...
# 2  [cb961e2a-5ede-4186-b1ec-33297d140cdd, 9d6cf7b...
# 3  [d18a377e-c8dc-47ab-988f-0f8655f1fdc4, cd058e6...
# 4  [dba1e500-ca49-4b33-8d1d-106beafbf1b3, a230068...
#
#                                    Top_3_Chunk_Texts
# 0  [-en, maintenance personnels can check the mot...
# 1  [Introduction\nThe mixture composed of nanopar...
# 2  [This is the simple industrial flow. The strip...
# 3  [Low perioperative levels of NK activity are a...
# 4  [As can be seen from the figure, the most freq...
#
# [5 rows x 31 columns]

# %%
import os

# Ensure the directory exists
output_dir = f"../data/dfs/{'only_text_' if extension == 'txt' else ''}{chunk_size}_{chunk_overlap}/"
os.makedirs(output_dir, exist_ok=True)

# Save the DataFrame to a pickle file
df2.to_pickle(os.path.join(output_dir, f"ReferenceErrorDetection_data_with_chunk_info.pkl"))

# Save the DataFrame to a excel file
df2.to_excel(os.path.join(output_dir, f"ReferenceErrorDetection_data_with_chunk_info.xlsx"), index=False)
