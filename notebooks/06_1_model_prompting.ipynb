# %% [markdown]
# # Prompting the models to classify the statements

# %%
# %%capture output
# %run ./06_0_prompt_creation.ipynb

# %%
import pandas as pd

embedding = "te3l" # / "te3s"
grobid_model = "full_model"
no_prev_chunking = True

annotated = False
corrected_statements = False

path = f"../data/dfs{'/annotated_data' if annotated else ''}{'/corrected_statements' if corrected_statements else ''}/{embedding}{'_no_prev_chunking' if no_prev_chunking else ''}/{grobid_model}/ReferenceErrorDetection_data_with_chunk_info.pkl"
print(path)

# read the dataframe from a pickle file
df = pd.read_pickle(path)
# Out:
# ../data/dfs/te3l_no_prev_chunking/full_model/ReferenceErrorDetection_data_with_chunk_info.pkl

# %%
df.head()
# Out:
#     Source Citing Article ID         Citing Article DOI  \
# 0  PubPeer              c001  10.1016/j.est.2021.103553
# 1  PubPeer              c001  10.1016/j.est.2021.103553
# 2  PubPeer              c002       10.1155/2022/4601350
# 3  PubPeer              c003       10.1155/2022/2408685
# 4  PubPeer              c004       10.1155/2022/4783847
#
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain  \
# 0                       Yes  Engineering
# 1                       Yes  Engineering
# 2                       Yes    Chemistry
# 3                       Yes     Medicine
# 4                       Yes  Engineering
#
#                              Statement with Citation Reference Article ID  \
# 0  Others have aimed to reduce irreversibility or...                 r001
# 1  Some researchers have also studied various hea...                 r002
# 2  The relative content of total flavonoids in th...                 r003
# 3  Research has shown that remimazolam tosylate e...                 r004
# 4  if the efficiency of the routing algorithm is ...                 r005
#
#              Reference Article DOI  \
# 0             10.1155/2021/2087027
# 1      10.1016/j.physa.2018.12.031
# 2  10.1088/1742-6596/1937/1/012038
# 3        10.1186/s12871-018-0543-3
# 4      10.36410/jcpr.2022.23.3.312
#
#                              Reference Article Title  \
# 0  A Fault Analysis Method for Three-Phase Induct...
# 1  Develop 24 dissimilar ANNs by suitable archite...
# 2  Lipid Data Acquisition for devices Treatment o...
# 3  Effect of propofol on breast cancer cell, the ...
# 4  Analysis and research hotspots of ceramic mate...
#
#                           Reference Article Abstract  \
# 0  The fault prediction and abductive fault diagn...
# 1  The artificial neural network optimization met...
# 2  Recently, the widespread deployment of smart p...
# 3  Breast cancer is the second leading cause of c...
# 4  From the perspective of scientometrics, comb t...
#
#   Reference Article PDF Available Reference Article Retracted  \
# 0                             Yes                          No
# 1                             Yes                          No
# 2                             Yes                          No
# 3                             Yes                          No
# 4                             Yes                          No
#
#   Reference Article Downloaded           Label Explanation  \
# 0                          Yes  Unsubstantiate  Irrelevant
# 1                          Yes  Unsubstantiate  Irrelevant
# 2                          Yes  Unsubstantiate  Irrelevant
# 3                          Yes  Unsubstantiate  Irrelevant
# 4                          Yes  Unsubstantiate  Irrelevant
#
#                                      Top_3_Chunk_IDs  \
# 0  [d5149dde-3f61-477d-acd9-0c8f97b154b5, f834613...
# 1  [dc4cd1b8-1ae4-4c15-be29-a4eb6e4270ba, 6210cc4...
# 2  [2eeaa48b-a7ec-4674-87ac-511b439139c8, 0d45e20...
# 3  [c6131293-c506-4347-8441-06e480444093, 821ac75...
# 4  [65b14485-4faa-441e-9aac-9967bad1f603, 8b03de6...
#
#                                    Top_3_Chunk_Texts
# 0  [Automatic implementation of fuzzy reasoning s...
# 1  [Heat transfer improvement of water/single-wal...
# 2  [The correspondence curve for our photochemica...
# 3  [Determination of the median effective concent...
# 4  [In the table, China's intermediary centrality...

# %% [markdown]
# ## Prompting the models (batch processing)

# %%
import os
import json

def create_batch_files(df, model, number_files=1, ignore_ids=[]):
    output_dir = f"../data/batch_files/{embedding}{'_no_prev_chunking' if no_prev_chunking else ''}/{grobid_model}"
    os.makedirs(output_dir, exist_ok=True)

    output_files = []
    for i in range(number_files):
        output_file = os.path.join(output_dir, f"prompt_batch_{model}_{i}.jsonl")
        # If the file already exists, empty it
        if os.path.exists(output_file):
            open(output_file, "w").close()
        output_files.append(output_file)
    
    for index, row in df.iterrows():
        if row['Reference Article Downloaded'] == 'Yes' and index not in ignore_ids:
            prompt = create_prompt(row)
            json_sequence = {
                "custom_id": f"request-{index}", 
                "method": "POST", 
                "url": "/v1/chat/completions", 
                "body": {
                    "model": model, 
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ],
                    "temperature": 0,
                }
            }

            output_file = output_files[index % number_files]
            with open(output_file, "a") as f:
                f.write(json.dumps(json_sequence) + "\n")
                
    # Remove empty output files from list
    output_files = [file for file in output_files if os.path.getsize(file) > 0]
    
    return output_files

# %%
import json

models = ["gpt-3.5-turbo-0125", "gpt-4-0125-preview", "gpt-4o-2024-05-13", "gpt-4-turbo-preview"]
model = models[2]

try:
    with open(f'../data/responses_dict_batch_{model}.json', 'r') as file:
        responses_dict = json.load(file)
    ids_to_ignore = [int(key) for key in responses_dict.keys()]
except FileNotFoundError:
    ids_to_ignore = []

print(ids_to_ignore)
# Out:
# [0, 1, 2, 3, 20, 21, 22, 23, 40, 41, 42, 43, 60, 61, 62, 63, 80, 81, 82, 83, 100, 101, 102, 103, 120, 121, 122, 123, 140, 141, 142, 143, 160, 161, 162, 163, 180, 181, 182, 183, 200, 201, 202, 203, 220, 221, 222, 223, 240, 241, 242, 243]

# %%
batch_file_paths = create_batch_files(df, model, 20, ids_to_ignore)
batch_file_paths
# Out:
# ['../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_4.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_5.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_6.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_7.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_8.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_9.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_10.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_11.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_12.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_13.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_14.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_15.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_16.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_17.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_18.jsonl',
#  '../data/batch_files/te3l_no_prev_chunking/full_model/prompt_batch_gpt-4o-2024-05-13_19.jsonl']

# %%
# Read the content of open_ai_key.txt into a variable
with open('../open_ai_key.txt', 'r') as file:
    open_ai_key = file.read().strip()

# %%
def check_batch(batch_id, client):
    batch = client.batches.retrieve(batch_id)
    print(f"{batch_id} - Current status: {batch.status}")
    
    if batch.status == 'completed' or batch.status == 'failed':
        return batch
    return None

# %%
import time
from openai import OpenAI

batch_input_files = []
batch_creation_responses = []
batches = []

client = OpenAI(api_key=open_ai_key)

def prompt_model_in_batches():
    global batch_input_files
    global batch_creation_responses
    global batches

    for batch_file_path in batch_file_paths:
        # Creating input file
        if os.stat(batch_file_path).st_size == 0:
            print(f"Skipping empty file: {batch_file_path}")
            continue
        batch_input_file = client.files.create(
            file=open(batch_file_path, "rb"),
            purpose="batch"
        )
        print(batch_input_file)
        batch_input_files.append(batch_input_file)

        # Starting batch job
        batch_input_file_id = batch_input_file.id
        batch_creation_response = client.batches.create(
            input_file_id=batch_input_file_id,
            endpoint="/v1/chat/completions",
            completion_window="24h"
        )
        print("Started: " + batch_creation_response.id)

        time.sleep(5)
        # Check the status of the created batch until it is completed
        while True:
            batch_id = batch_creation_response.id
            batch = check_batch(batch_id, client)
            if batch:
                if batch.status == "failed":
                    return
                elif batch.status == "completed":
                    batches.append(batch)
                    break
            time.sleep(30)

# %%
prompt_model_in_batches()
# Out:
# FileObject(id='file-1PSQzk27aTqCLHxxKqTp7i', bytes=78631, created_at=1742993668, filename='prompt_batch_gpt-4o-2024-05-13_4.jsonl', object='file', purpose='batch', status='processed', expires_at=None, status_details=None)
# Started: batch_67e3f904c67c81908dfe7f867b6f2e45
# batch_67e3f904c67c81908dfe7f867b6f2e45 - Current status: failed

# %% [markdown]
# ### Check all open batches

# %%
from openai import OpenAI
client = OpenAI(api_key=open_ai_key)

open_batches = client.batches.list(limit=5)

# %%
list(open_batches)
# Out:
# [Batch(id='batch_67e3f904c67c81908dfe7f867b6f2e45', completion_window='24h', created_at=1742993668, endpoint='/v1/chat/completions', input_file_id='file-1PSQzk27aTqCLHxxKqTp7i', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4o-2024-05-13 in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743080068, failed_at=1742993670, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3f7ceae3c819088917e7b6928d06e', completion_window='24h', created_at=1742993358, endpoint='/v1/chat/completions', input_file_id='file-NiajatLWPoMPnU5oVGkcVn', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4o-2024-05-13 in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743079758, failed_at=1742993359, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3f78c14148190b6dc936391e30a17', completion_window='24h', created_at=1742993292, endpoint='/v1/chat/completions', input_file_id='file-MFWofoonBkegQB6ExrprGp', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742993357, error_file_id=None, errors=None, expired_at=None, expires_at=1743079692, failed_at=None, finalizing_at=1742993355, in_progress_at=1742993293, metadata=None, output_file_id='file-SgxpCaW2xDauzsJHnv1wb9', request_counts=BatchRequestCounts(completed=13, failed=0, total=13)),
#  Batch(id='batch_67e3f767a0588190b15a45e5b64f98c2', completion_window='24h', created_at=1742993255, endpoint='/v1/chat/completions', input_file_id='file-73QgGpCQrYGbDfkEVpUF6J', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742993262, error_file_id=None, errors=None, expired_at=None, expires_at=1743079655, failed_at=None, finalizing_at=1742993261, in_progress_at=1742993256, metadata=None, output_file_id='file-RJLiWvhXfWTEm818wNCMXc', request_counts=BatchRequestCounts(completed=13, failed=0, total=13)),
#  Batch(id='batch_67e3f724fc008190855c9159f493b1b1', completion_window='24h', created_at=1742993188, endpoint='/v1/chat/completions', input_file_id='file-44iMKEoUm4vji8V9554YTd', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742993230, error_file_id=None, errors=None, expired_at=None, expires_at=1743079588, failed_at=None, finalizing_at=1742993228, in_progress_at=1742993190, metadata=None, output_file_id='file-Usy2QDX3kUdpSFNVcsT8W1', request_counts=BatchRequestCounts(completed=13, failed=0, total=13)),
#  Batch(id='batch_67e3f623e6a4819090cd55dbd2881b80', completion_window='24h', created_at=1742992931, endpoint='/v1/chat/completions', input_file_id='file-CvT47WZHBLv5J7Sk4BC15E', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742993006, error_file_id=None, errors=None, expired_at=None, expires_at=1743079331, failed_at=None, finalizing_at=1742993004, in_progress_at=1742992934, metadata=None, output_file_id='file-84Dc3a2z1Mbxgfj4wSV2Af', request_counts=BatchRequestCounts(completed=13, failed=0, total=13)),
#  Batch(id='batch_67e3f59d40d481909daaec0ae70d9f7a', completion_window='24h', created_at=1742992797, endpoint='/v1/chat/completions', input_file_id='file-St9tuGA3XN5k2zNs41ZZZQ', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4-0125-preview in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743079197, failed_at=1742992798, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3f20d778c8190a7f71211dba0549a', completion_window='24h', created_at=1742991885, endpoint='/v1/chat/completions', input_file_id='file-Bg15q8iQDpMcxUy8sdN2NQ', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4-0125-preview in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743078285, failed_at=1742991886, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3ef3230b881908c068b560a6e163d', completion_window='24h', created_at=1742991154, endpoint='/v1/chat/completions', input_file_id='file-XprRZwGVAM32K2M1S9C2X4', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4-0125-preview in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743077554, failed_at=1742991155, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3eeeb774881908f99ce5936c10242', completion_window='24h', created_at=1742991083, endpoint='/v1/chat/completions', input_file_id='file-4h8JtyRLnEPtZq1a2Qcb5q', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742991149, error_file_id=None, errors=None, expired_at=None, expires_at=1743077483, failed_at=None, finalizing_at=1742991147, in_progress_at=1742991085, metadata=None, output_file_id='file-JQUe31QVbcjje1MhFZgaQH', request_counts=BatchRequestCounts(completed=13, failed=0, total=13)),
#  Batch(id='batch_67e3dc3e2dd881908121eaa51f5545e6', completion_window='24h', created_at=1742986302, endpoint='/v1/chat/completions', input_file_id='file-T2RcxB2Ut6ppVPPRdRBAJ8', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4-0125-preview in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743072702, failed_at=1742986303, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3d91568f48190a2620e7a25f53f57', completion_window='24h', created_at=1742985493, endpoint='/v1/chat/completions', input_file_id='file-BcyLo2qV3WSC246Ha72H3n', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4-0125-preview in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743071893, failed_at=1742985494, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3d87c37cc81908192d248e5fd8044', completion_window='24h', created_at=1742985340, endpoint='/v1/chat/completions', input_file_id='file-BcyLo2qV3WSC246Ha72H3n', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4-0125-preview in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743071740, failed_at=1742985340, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3d2c696048190882c43ae88abd0a5', completion_window='24h', created_at=1742983878, endpoint='/v1/chat/completions', input_file_id='file-UXeVgJ4g9p4VRgNu126xiy', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4-0125-preview in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743070278, failed_at=1742983879, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3d2800cdc8190800520298d1326dc', completion_window='24h', created_at=1742983808, endpoint='/v1/chat/completions', input_file_id='file-9z2J7TmGjNoYHjMVdXsPmW', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4-0125-preview in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743070208, failed_at=1742983809, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e3cf592eb081908cd64e5e1dc55fa0', completion_window='24h', created_at=1742983001, endpoint='/v1/chat/completions', input_file_id='file-9z2J7TmGjNoYHjMVdXsPmW', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742983057, error_file_id=None, errors=None, expired_at=None, expires_at=1743069401, failed_at=None, finalizing_at=1742983053, in_progress_at=1742983002, metadata=None, output_file_id='file-4VXAcYBKjWELDLGs52uTAK', request_counts=BatchRequestCounts(completed=50, failed=0, total=50)),
#  Batch(id='batch_67e3cc5efef8819085752b3e80bf19c7', completion_window='24h', created_at=1742982238, endpoint='/v1/chat/completions', input_file_id='file-XBrpkfg6R4HL5tSfMyfM9G', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='token_limit_exceeded', line=None, message='Enqueued token limit reached for gpt-4-0125-preview in organization org-6SCiN9rjR6tU38WJ0DavgNRs. Limit: 90,000 enqueued tokens. Please try again once some in_progress batches have been completed.', param=None)], object='list'), expired_at=None, expires_at=1743068638, failed_at=1742982240, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0)),
#  Batch(id='batch_67e189022f3c8190be971477ff6a73bc', completion_window='24h', created_at=1742833922, endpoint='/v1/chat/completions', input_file_id='file-Q2nb2DDM5idxjmsQMK4v9L', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742833993, error_file_id=None, errors=None, expired_at=None, expires_at=1742920322, failed_at=None, finalizing_at=1742833973, in_progress_at=1742833923, metadata=None, output_file_id='file-342sFVKS3eAseqXW5kP8Xp', request_counts=BatchRequestCounts(completed=247, failed=0, total=247)),
#  Batch(id='batch_67e181e80c1081908c8bef46affc15bf', completion_window='24h', created_at=1742832104, endpoint='/v1/chat/completions', input_file_id='file-TmYP2CqRwVgMgM1EceRkGa', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742832394, error_file_id=None, errors=None, expired_at=None, expires_at=1742918504, failed_at=None, finalizing_at=1742832377, in_progress_at=1742832106, metadata=None, output_file_id='file-ACjtviphJvB7jLcaaLe2zB', request_counts=BatchRequestCounts(completed=247, failed=0, total=247)),
#  Batch(id='batch_67e1759a06e081908fd9ef00b36a2210', completion_window='24h', created_at=1742828954, endpoint='/v1/chat/completions', input_file_id='file-P7ycNgs8zQyPUYVhW3vJ6c', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742829150, error_file_id=None, errors=None, expired_at=None, expires_at=1742915354, failed_at=None, finalizing_at=1742829118, in_progress_at=1742828955, metadata=None, output_file_id='file-KmMEn7v9PGkJPEuVmMbZtL', request_counts=BatchRequestCounts(completed=247, failed=0, total=247)),
#  Batch(id='batch_67e164dd8e0881908b90679ecf92f9c1', completion_window='24h', created_at=1742824669, endpoint='/v1/chat/completions', input_file_id='file-SYDuxSAEvuU9N7kjTFXTvp', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1742824749, error_file_id=None, errors=None, expired_at=None, expires_at=1742911069, failed_at=None, finalizing_at=1742824732, in_progress_at=1742824670, metadata=None, output_file_id='file-J5iPkaAyxvsv9JeSSPfubG', request_counts=BatchRequestCounts(completed=247, failed=0, total=247)),
#  Batch(id='batch_67e1639ef8308190ba14c2ac05eb1c4c', completion_window='24h', created_at=1742824350, endpoint='/v1/responses', input_file_id='file-3vWh52SstDocvKNhqLmNx4', object='batch', status='failed', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=Errors(data=[BatchError(code='missing_required_parameter', line=1, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=2, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=3, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=4, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=5, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=6, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=7, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=8, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=9, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=10, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=11, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=12, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=13, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=14, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=15, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=16, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=17, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=18, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=19, message="Missing required parameter: 'input'.", param='body.input'), BatchError(code='missing_required_parameter', line=20, message="Missing required parameter: 'input'.", param='body.input')], object='list'), expired_at=None, expires_at=1742910750, failed_at=1742824352, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))]

# %%
client.batches.cancel("batch_67e3cf592eb081908cd64e5e1dc55fa0")
# Out:
# ---------------------------------------------------------------------------
# ConflictError                             Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 client.batches.cancel("batch_67e3cf592eb081908cd64e5e1dc55fa0")
#
# File ~/master_thesis/citation-verification/.venv/lib/python3.10/site-packages/openai/resources/batches.py:229, in Batches.cancel(self, batch_id, extra_headers, extra_query, extra_body, timeout)
#     227 if not batch_id:
#     228     raise ValueError(f"Expected a non-empty value for `batch_id` but received {batch_id!r}")
# --> 229 return self._post(
#     230     f"/batches/{batch_id}/cancel",
#     231     options=make_request_options(
#     232         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     233     ),
#     234     cast_to=Batch,
#     235 )
#
# File ~/master_thesis/citation-verification/.venv/lib/python3.10/site-packages/openai/_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)
#    1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/master_thesis/citation-verification/.venv/lib/python3.10/site-packages/openai/_base_client.py:919, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     916 else:
#     917     retries_taken = 0
# --> 919 return self._request(
#     920     cast_to=cast_to,
#     921     options=options,
#     922     stream=stream,
#     923     stream_cls=stream_cls,
#     924     retries_taken=retries_taken,
#     925 )
#
# File ~/master_thesis/citation-verification/.venv/lib/python3.10/site-packages/openai/_base_client.py:1008, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1006 if remaining_retries > 0 and self._should_retry(err.response):
#    1007     err.response.close()
# -> 1008     return self._retry_request(
#    1009         input_options,
#    1010         cast_to,
#    1011         retries_taken=retries_taken,
#    1012         response_headers=err.response.headers,
#    1013         stream=stream,
#    1014         stream_cls=stream_cls,
#    1015     )
#    1017 # If the response is streamed then we need to explicitly read the response
#    1018 # to completion before attempting to access the response text.
#    1019 if not err.response.is_closed:
#
# File ~/master_thesis/citation-verification/.venv/lib/python3.10/site-packages/openai/_base_client.py:1057, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1053 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1054 # different thread if necessary.
#    1055 time.sleep(timeout)
# -> 1057 return self._request(
#    1058     options=options,
#    1059     cast_to=cast_to,
#    1060     retries_taken=retries_taken + 1,
#    1061     stream=stream,
#    1062     stream_cls=stream_cls,
#    1063 )
#
# File ~/master_thesis/citation-verification/.venv/lib/python3.10/site-packages/openai/_base_client.py:1008, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1006 if remaining_retries > 0 and self._should_retry(err.response):
#    1007     err.response.close()
# -> 1008     return self._retry_request(
#    1009         input_options,
#    1010         cast_to,
#    1011         retries_taken=retries_taken,
#    1012         response_headers=err.response.headers,
#    1013         stream=stream,
#    1014         stream_cls=stream_cls,
#    1015     )
#    1017 # If the response is streamed then we need to explicitly read the response
#    1018 # to completion before attempting to access the response text.
#    1019 if not err.response.is_closed:
#
# File ~/master_thesis/citation-verification/.venv/lib/python3.10/site-packages/openai/_base_client.py:1057, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1053 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1054 # different thread if necessary.
#    1055 time.sleep(timeout)
# -> 1057 return self._request(
#    1058     options=options,
#    1059     cast_to=cast_to,
#    1060     retries_taken=retries_taken + 1,
#    1061     stream=stream,
#    1062     stream_cls=stream_cls,
#    1063 )
#
# File ~/master_thesis/citation-verification/.venv/lib/python3.10/site-packages/openai/_base_client.py:1023, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1020         err.response.read()
#    1022     log.debug("Re-raising status error")
# -> 1023     raise self._make_status_error_from_response(err.response) from None
#    1025 return self._process_response(
#    1026     cast_to=cast_to,
#    1027     options=options,
#    (...)
#    1031     retries_taken=retries_taken,
#    1032 )
#
# ConflictError: Error code: 409 - {'error': {'message': "Cannot cancel a batch with status 'completed'.", 'type': 'invalid_request_error', 'param': None, 'code': None}}

# %% [markdown]
# ### Check the batch status

# %%
import time

def wait_for_batch_completion(batch_id, client, interval=10):
    while True:
        batch = check_batch(batch_id, client)
        if batch != None:
            return batch
        time.sleep(interval)

# %%
batch = wait_for_batch_completion("batch_67e3f623e6a4819090cd55dbd2881b80", client)
# Out:
# batch_67e3f623e6a4819090cd55dbd2881b80 - Current status: completed

# %%
import json

# save responds of completed batches
for batch in batches:
    if batch.status != "completed":
        continue
    model_responses = client.files.content(batch.output_file_id).text

    # Parse the model_responses into a list of objects
    responses_list = [json.loads(line) for line in model_responses.splitlines()]

    try:
        for response in responses_list:
            responses_dict[int(response['custom_id'].split('-')[1])] = response
            responses_dict = dict(sorted(responses_dict.items(), key=lambda item: int(item[0])))
    except NameError:
        responses_dict = {int(response['custom_id'].split('-')[1]): response for response in responses_list}

# %%
responses_dict
# Out:
# {'0': {'id': 'batch_req_67e3f66ca9e08190af68289b2a2932e0',
#   'custom_id': 'request-0',
#   'response': {'status_code': 200,
#    'request_id': 'ffe57df5bc3436abb99959553d87203c',
#    'body': {'id': 'chatcmpl-BFKNvTfovSy3j9ve8zmC0b5EDWmcP',
#     'object': 'chat.completion',
#     'created': 1742992979,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on fault analysis and diagnosis methods for three-phase induction motors using spiking neural P systems and related techniques. It does not discuss reducing irreversibility or optimizing energy-consumed devices, which is the subject of the statement in the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1172,
#      'completion_tokens': 75,
#      'total_tokens': 1247,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  1: {'id': 'batch_req_67e3f74cb92c8190a37d8c544877c46b',
#   'custom_id': 'request-1',
#   'response': {'status_code': 200,
#    'request_id': 'bc705c89e51ec039e192f40ccf9be8a1',
#    'body': {'id': 'chatcmpl-BFKRTct89Bk9wHfDcFDScRbRCxfVy',
#     'object': 'chat.completion',
#     'created': 1742993199,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article discusses various heat transfer studies and devices, which aligns with the statement about researchers studying heat exchange devices. However, the primary focus of the reference article is on artificial neural networks and their optimization, not specifically on enhancing the efficiency of heat exchange devices. Therefore, while there is some relevance, the reference does not fully substantiate the statement."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1144,
#      'completion_tokens': 93,
#      'total_tokens': 1237,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  2: {'id': 'batch_req_67e3f76d7cac81908ae9cb9e3a58259b',
#   'custom_id': 'request-2',
#   'response': {'status_code': 200,
#    'request_id': '444e6bc76a01ff33a16ec98051d0b319',
#    'body': {'id': 'chatcmpl-BFKSPMEOZTVgsCiBBmlCrEURBevfR',
#     'object': 'chat.completion',
#     'created': 1742993257,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on a smartphone-based blood lipid data acquisition dongle and its application in measuring blood lipid levels. It does not discuss the relative content of total flavonoids or phenolic acids in any phase, nor does it provide any relevant data or context to support the statement about the content of flavonoids and phenolic acids in Sophora flavescens."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1240,
#      'completion_tokens': 98,
#      'total_tokens': 1338,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  3: {'id': 'batch_req_67e3f7cbe4f08190be24cef15b1d7d87',
#   'custom_id': 'request-3',
#   'response': {'status_code': 200,
#    'request_id': '20c5f6f2423954524a153a34f412d2d1',
#    'body': {'id': 'chatcmpl-BFKTx4SkVdT5gkpf2VXxaKgv2ZLAh',
#     'object': 'chat.completion',
#     'created': 1742993353,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on the effects of propofol on breast cancer cells, the immune system, and patient outcomes, and does not discuss remimazolam tosylate, dexmedetomidine, or awakening times in gastroscopic practices. Therefore, it does not substantiate the statement from the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1282,
#      'completion_tokens': 87,
#      'total_tokens': 1369,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '20': {'id': 'batch_req_67e3f66cc1588190bf3ca26638094e72',
#   'custom_id': 'request-20',
#   'response': {'status_code': 200,
#    'request_id': '749901cabe8fa466a3efde807bc2bd9d',
#    'body': {'id': 'chatcmpl-BFKNx4UB1eoS6K5NjVBHvYvVzcVEA',
#     'object': 'chat.completion',
#     'created': 1742992981,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on bi-level energy optimization models and mathematical optimization problems in wireless communication systems. It does not discuss the process of parties putting forward opinions, gaining experience, or working according to objectives in public management contexts."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1151,
#      'completion_tokens': 67,
#      'total_tokens': 1218,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  21: {'id': 'batch_req_67e3f74cd9588190918f05fe7761f7c2',
#   'custom_id': 'request-21',
#   'response': {'status_code': 200,
#    'request_id': '8b5be0194617d857056753bd2380b55c',
#    'body': {'id': 'chatcmpl-BFKRWJk6EDFwg50hV1JSkNJAesqY9',
#     'object': 'chat.completion',
#     'created': 1742993202,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on cyberattack detection using unsupervised machine learning and Gaussian mixture models. It does not discuss urban planning, natural environment constraints, or resilience development in cities."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1209,
#      'completion_tokens': 59,
#      'total_tokens': 1268,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  22: {'id': 'batch_req_67e3f76d8a008190b3ad01994413846d',
#   'custom_id': 'request-22',
#   'response': {'status_code': 200,
#    'request_id': '80a676becb2541cbb8abd547cf863fd7',
#    'body': {'id': 'chatcmpl-BFKSPHDgNWVRiNYjB4SbJcq8W1Pkk',
#     'object': 'chat.completion',
#     'created': 1742993257,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article \'DeepCleave: a deep learning predictor for caspase and matrix metalloprotease substrates and cleavage sites\' focuses on deep learning methods for predicting protease substrates and cleavage sites. It does not address issues related to arranging classes or summarizing grades in a high-level management context, which is the subject of the statement in the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1277,
#      'completion_tokens': 95,
#      'total_tokens': 1372,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  23: {'id': 'batch_req_67e3f7cbf8508190965f51c1d50bcaee',
#   'custom_id': 'request-23',
#   'response': {'status_code': 200,
#    'request_id': '8dd3a3ebe31ba35fa078be032496f6be',
#    'body': {'id': 'chatcmpl-BFKT0cFNc43m7Vpd5YbjrlonlrLRu',
#     'object': 'chat.completion',
#     'created': 1742993294,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on the cost-effectiveness of stereotactic ablative body radiation therapy compared to other treatments for liver cancer. It does not discuss nursing-sensitive quality indicators or their application in the context of orthopedic nursing, making it unrelated to the statement in the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1303,
#      'completion_tokens': 78,
#      'total_tokens': 1381,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '40': {'id': 'batch_req_67e3f66cd55c819094c36d35f2cd0a94',
#   'custom_id': 'request-40',
#   'response': {'status_code': 200,
#    'request_id': '15c66328f53715137f7f8bf445aaa7fe',
#    'body': {'id': 'chatcmpl-BFKNzDNYIaX2gt3Ovpk96FaMPEMKs',
#     'object': 'chat.completion',
#     'created': 1742992983,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on the monotonicity properties of a function involving the psi function and its applications in mathematical analysis. It does not discuss recent developments in science and technology or their impact on human health and life."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1143,
#      'completion_tokens': 66,
#      'total_tokens': 1209,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  41: {'id': 'batch_req_67e3f74cf82c8190a3eaf3f0be900bf4',
#   'custom_id': 'request-41',
#   'response': {'status_code': 200,
#    'request_id': 'c90ad2f4aa1e42ccfb0496e2a23b1259',
#    'body': {'id': 'chatcmpl-BFKRYaVbqH1wOL5jjkBQBOIOpJxNW',
#     'object': 'chat.completion',
#     'created': 1742993204,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on bug report classification in software systems and does not discuss coordination chemistry, DNA binding, redox reactivity, or metal-specific geometries. Therefore, it does not substantiate the statement from the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1277,
#      'completion_tokens': 69,
#      'total_tokens': 1346,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  42: {'id': 'batch_req_67e3f76d98c081909db1dabb2ba910d4',
#   'custom_id': 'request-42',
#   'response': {'status_code': 200,
#    'request_id': 'e7ad487ef6cf998321f0049b246e3cf9',
#    'body': {'id': 'chatcmpl-BFKSPSfZR9XCmTjkifKO65X1ZbfAa',
#     'object': 'chat.completion',
#     'created': 1742993257,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on the synthesis and properties of aluminum hydride (AlH3) for hydrogen storage applications and does not discuss metal complexes, their cationic characteristics, ligands, structural geometries, electronic properties, kinetic properties, mechanisms of drug action, gene regulation, DNA interactions, or therapeutic agent design."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1334,
#      'completion_tokens': 87,
#      'total_tokens': 1421,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  43: {'id': 'batch_req_67e3f7cc087c81909d8a37cec98ad1dc',
#   'custom_id': 'request-43',
#   'response': {'status_code': 200,
#    'request_id': '1d480b02880b8617ff640c3dc06e312f',
#    'body': {'id': 'chatcmpl-BFKT0YOztaOYcqZyCBRKDGCunDjGV',
#     'object': 'chat.completion',
#     'created': 1742993294,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on the mechanochemical synthesis and properties of α-AlH3 as a hydrogen storage material, and does not discuss metal complexes, their cationic characteristics, ligands, structural geometries, electronic properties, kinetic properties, mechanisms of drug action, gene regulation, DNA probing, or therapeutic agent design."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1325,
#      'completion_tokens': 87,
#      'total_tokens': 1412,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '60': {'id': 'batch_req_67e3f66ceab48190b0f925c7de619f86',
#   'custom_id': 'request-60',
#   'response': {'status_code': 200,
#    'request_id': 'caa967d7bdd3001f34f6986189daa987',
#    'body': {'id': 'chatcmpl-BFKO27WV8vsvzHXWjGincNvljtzyp',
#     'object': 'chat.completion',
#     'created': 1742992986,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on acoustic emission signal processing technology and does not discuss coordination polymers, their construction, or their properties. Therefore, it does not substantiate the statement about coordination polymers in the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1137,
#      'completion_tokens': 64,
#      'total_tokens': 1201,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  61: {'id': 'batch_req_67e3f74d1ad08190b31f671fc9da7454',
#   'custom_id': 'request-61',
#   'response': {'status_code': 200,
#    'request_id': 'b07793e0b6d04485c427fdaf10297398',
#    'body': {'id': 'chatcmpl-BFKRazmVVijuUBKfeZB5LAHUWFGV1',
#     'object': 'chat.completion',
#     'created': 1742993206,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on the application of big data technology and ant colony optimization in vehicular ad hoc networks for smart cities. It does not discuss or provide information about a professional team with theoretical knowledge and practical skills in education management."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1182,
#      'completion_tokens': 69,
#      'total_tokens': 1251,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  62: {'id': 'batch_req_67e3f76da88481908b5fc2d3d562f4da',
#   'custom_id': 'request-62',
#   'response': {'status_code': 200,
#    'request_id': '7a2925be3ae8245cc380665b53f8148f',
#    'body': {'id': 'chatcmpl-BFKSPRcPWoVBagDKQtLUbPeZlmQuM',
#     'object': 'chat.completion',
#     'created': 1742993257,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article does not mention the SIMPLE scheme or the convergence metric set to 10^–6. It focuses on the effects of pin angle on friction stir welding and the use of CFD for simulation, but does not provide any information related to the pressure-velocity coupling scheme or convergence criteria."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1032,
#      'completion_tokens': 82,
#      'total_tokens': 1114,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  63: {'id': 'batch_req_67e3f7cc19d08190a71b3665af0979be',
#   'custom_id': 'request-63',
#   'response': {'status_code': 200,
#    'request_id': '432e82013f8dd1fa648fbb369cde290c',
#    'body': {'id': 'chatcmpl-BFKT0ItDCLm3frFxhDYvOwH6Kl0wf',
#     'object': 'chat.completion',
#     'created': 1742993294,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on stormwater management and urban water allocation systems under drought conditions. It does not mention the SIMPLE scheme, pressure-velocity coupling, or convergence metrics, which are the key points in the statement from the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1134,
#      'completion_tokens': 70,
#      'total_tokens': 1204,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '80': {'id': 'batch_req_67e3f66d02448190afb1fcea1d5ae303',
#   'custom_id': 'request-80',
#   'response': {'status_code': 200,
#    'request_id': '05b45b6e9de7b532fd5207a3031ce984',
#    'body': {'id': 'chatcmpl-BFKO3K89seq4HYBNhmkpIBk5VpqdG',
#     'object': 'chat.completion',
#     'created': 1742992987,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article indicates that salivary oxytocin concentrations were significantly reduced after choir singing and did not change in response to solo singing. This contradicts the statement that oxytocin is increased when participating in group singing."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1241,
#      'completion_tokens': 68,
#      'total_tokens': 1309,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  81: {'id': 'batch_req_67e3f74d3d648190843d73cf7e950123',
#   'custom_id': 'request-81',
#   'response': {'status_code': 200,
#    'request_id': '4e20ed47eeed042e01bba6ebe9536289',
#    'body': {'id': 'chatcmpl-BFKRdLfoVD0pVt3ztXSTY1UyD2d60',
#     'object': 'chat.completion',
#     'created': 1742993209,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article by Beyer et al. does not discuss the mechanism of action for extracellular loop peptides. It focuses on the families of gap junction proteins, including connexins, innexins, and pannexins, and their roles in forming gap junction channels."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1109,
#      'completion_tokens': 76,
#      'total_tokens': 1185,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  82: {'id': 'batch_req_67e3f76db9008190be1acfd88f31db3d',
#   'custom_id': 'request-82',
#   'response': {'status_code': 200,
#    'request_id': '9abc24ac901241b1702f3d4c81d09e09',
#    'body': {'id': 'chatcmpl-BFKSPNNBG4ev4lKpkDa5FNyw3SdHh',
#     'object': 'chat.completion',
#     'created': 1742993257,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article supports the statement regarding the effects of Peptide 5 on chronic kidney disease but does not mention its effects on retinal pigment epithelial cell barrier function or diabetic retinopathy. Therefore, the reference partially substantiates the statement."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1814,
#      'completion_tokens': 70,
#      'total_tokens': 1884,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  83: {'id': 'batch_req_67e3f7cc2c908190bb8df5b2bcd439cf',
#   'custom_id': 'request-83',
#   'response': {'status_code': 200,
#    'request_id': 'de5618071d3de319d9984c87435f562f',
#    'body': {'id': 'chatcmpl-BFKT0xnRX7gVioYlY1EO1KeLDPlP1',
#     'object': 'chat.completion',
#     'created': 1742993294,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on the effects of the connexin43 mimetic peptide Gap19 on astrocytes and its role in inhibiting hemichannels without affecting gap junction channels. It does not discuss Peptide5 or its effects on retinal pigment epithelial cell barrier function, diabetic retinopathy, or chronic kidney disease."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1207,
#      'completion_tokens': 87,
#      'total_tokens': 1294,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '100': {'id': 'batch_req_67e3f66d18448190aa3c2170cc1f0dfb',
#   'custom_id': 'request-100',
#   'response': {'status_code': 200,
#    'request_id': '1a5b84e40384f887d2f3e7c92e3f5e1e',
#    'body': {'id': 'chatcmpl-BFKO5tTQPzzSiaWaFu96cABNWRd9f',
#     'object': 'chat.completion',
#     'created': 1742992989,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article supports the idea that human diets with reduced livestock products can contribute to sustainable food systems and reduce environmental impact. However, it does not explicitly mention the role of agro-industries, farms, and civil society in developing a worldwide strategy, nor does it directly address the reduction of food waste."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1198,
#      'completion_tokens': 83,
#      'total_tokens': 1281,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  101: {'id': 'batch_req_67e3f74d5df881908324f52366824742',
#   'custom_id': 'request-101',
#   'response': {'status_code': 200,
#    'request_id': '0e2c3224288fe81aab931dbee9fdf54e',
#    'body': {'id': 'chatcmpl-BFKRf1Lxad9FzahdGiqyL0qo9pjco',
#     'object': 'chat.completion',
#     'created': 1742993211,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article confirms that E2-2 is a central regulator of pDC development, which supports part of the statement. However, it does not mention Pitt-Hopkins syndrome (PHS), abnormal craniofacial and neural development, severe mental retardation, motor dysfunction, or the gene 7CF4. Therefore, the reference only partially substantiates the statement."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1211,
#      'completion_tokens': 98,
#      'total_tokens': 1309,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  102: {'id': 'batch_req_67e3f76dc6f8819091fcf65a138ba589',
#   'custom_id': 'request-102',
#   'response': {'status_code': 200,
#    'request_id': '86b19702487b236afdaa2b4c7bf81b72',
#    'body': {'id': 'chatcmpl-BFKSPqN3weE6sFzayC6Bl7U7WIYIQ',
#     'object': 'chat.completion',
#     'created': 1742993257,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article by Vaquerizas et al. describes a high-confidence data set of 1,391 transcription factors, which aligns with the statement that the collection included 84% of the high-confidence TFs described by Vaquerizas et al. This indicates that the citing article\'s claim is fully supported by the reference article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1113,
#      'completion_tokens': 88,
#      'total_tokens': 1201,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  103: {'id': 'batch_req_67e3f7cc3dd88190a1b6d7c5f7dd849c',
#   'custom_id': 'request-103',
#   'response': {'status_code': 200,
#    'request_id': '6d89290d5562bf7dc083e091cbab99f0',
#    'body': {'id': 'chatcmpl-BFKT0PFgpDJHHqCNysV7fGkreCbcX',
#     'object': 'chat.completion',
#     'created': 1742993294,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article discusses the development and advantages of low-loss photopatternable polymer dielectrics for LWIR-metamaterial applications, highlighting their potential for scalability and economic benefits. However, it does not explicitly state that polymeric photonics is a growing field. The statement in the citing article is generally supported by the reference, but the specific claim about the growth of the field is not directly addressed."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1284,
#      'completion_tokens': 104,
#      'total_tokens': 1388,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '120': {'id': 'batch_req_67e3f66d2b1c8190a452112c46264c6b',
#   'custom_id': 'request-120',
#   'response': {'status_code': 200,
#    'request_id': 'd2afcc5d8c3ad1513edc2d30a10a9a6f',
#    'body': {'id': 'chatcmpl-BFKO78fIThEfScHKeVQKDKgJKI6Ig',
#     'object': 'chat.completion',
#     'created': 1742992991,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article provides details on the use of a 7-nA 30-kV gallium ion beam and the generation of isotropic voxel image stacks, which aligns with the statement. However, it does not mention the specific use of an InLens detector or the filtering of secondary electrons through sample biasing, which are key components of the statement."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1277,
#      'completion_tokens': 94,
#      'total_tokens': 1371,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  121: {'id': 'batch_req_67e3f74d7ef08190b100bcb8ff89a38c',
#   'custom_id': 'request-121',
#   'response': {'status_code': 200,
#    'request_id': '5dbaa63e32504e3a52692ab5dc938749',
#    'body': {'id': 'chatcmpl-BFKRhVOCAOhu5QXkq2uKb6TIIAig5',
#     'object': 'chat.completion',
#     'created': 1742993213,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article discusses the pressure-temperature phase relations and phase transitions of MAPbX3 (X = Cl, Br, I) crystals, but it does not provide any information about the pyroelectric response of tetragonal MAPbBr3. Therefore, it does not substantiate the statement regarding the pyroelectric measurements of tetragonal MAPbBr3."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1289,
#      'completion_tokens': 95,
#      'total_tokens': 1384,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  122: {'id': 'batch_req_67e3f76dd55c819096075f0755cc5651',
#   'custom_id': 'request-122',
#   'response': {'status_code': 200,
#    'request_id': '6f17f2bd89e0629902bd6e85a154dc8b',
#    'body': {'id': 'chatcmpl-BFKSPggabpve9JCAu03CqELg5nDUc',
#     'object': 'chat.completion',
#     'created': 1742993257,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article describes the use of baseline MRI scans to ensure that Wistar rats had normal brain ventricular anatomy before proceeding with further studies. This directly supports the statement that all animals underwent MRI before sonication to ensure normal brain ventricular anatomy."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1170,
#      'completion_tokens': 69,
#      'total_tokens': 1239,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  123: {'id': 'batch_req_67e3f7cc4fe48190839fc69ed4c9a687',
#   'custom_id': 'request-123',
#   'response': {'status_code': 200,
#    'request_id': 'fbf57a0c4c6a3ca6376ac56534e46f36',
#    'body': {'id': 'chatcmpl-BFKT0VQUKQ9PC9x7FGwZBIbdFYYYw',
#     'object': 'chat.completion',
#     'created': 1742993294,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article provides values for the Grüneisen parameter and Poisson ratio, which are used in the context of the study. Specifically, the Grüneisen parameter (g) and Poisson ratio (r) are mentioned in the context of elastic properties and thermal conductivity calculations, supporting the statement in the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1046,
#      'completion_tokens': 86,
#      'total_tokens': 1132,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '140': {'id': 'batch_req_67e3f66d3ed8819089f492d3161cf0e7',
#   'custom_id': 'request-140',
#   'response': {'status_code': 200,
#    'request_id': '46acb203460d57e9fb378796d95ebe2f',
#    'body': {'id': 'chatcmpl-BFKO9dI7DNEZSDTCoFfGjSxltm4bY',
#     'object': 'chat.completion',
#     'created': 1742992993,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article discusses the enhancement of laser linewidth due to the Petermann factor, which is consistent with the statement. However, it does not specifically address the third-order exceptional point, making the statement only partially substantiated."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1119,
#      'completion_tokens': 67,
#      'total_tokens': 1186,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  141: {'id': 'batch_req_67e3f74d9f5c819083add205320b9b7d',
#   'custom_id': 'request-141',
#   'response': {'status_code': 200,
#    'request_id': '94c3c4bcbf2c2542436a027528f513a0',
#    'body': {'id': 'chatcmpl-BFKRjpibK0kSsj8hwvPRr7XPOElHj',
#     'object': 'chat.completion',
#     'created': 1742993215,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article discusses the Trinity method for de novo assembly and its effectiveness, which supports the use of Trinity in the statement. However, the reference article does not mention the specific version of Trinity (r2012-01-25) used in the citing article, nor does it discuss the use of TopHat and Cufflinks with the specified versions and parameters. Therefore, while the reference supports the use of Trinity for de novo assembly, it does not fully substantiate the entire statement."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1209,
#      'completion_tokens': 121,
#      'total_tokens': 1330,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  142: {'id': 'batch_req_67e3f76de3548190b3e1fdca79ea10ae',
#   'custom_id': 'request-142',
#   'response': {'status_code': 200,
#    'request_id': 'eec2a0ffc6d20197625eef3042de21ca',
#    'body': {'id': 'chatcmpl-BFKSPOR5polBcNPUwqF0xrneKjP8f',
#     'object': 'chat.completion',
#     'created': 1742993257,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article discusses the strategy of identifying and managing specific reef areas with natural resistance and resilience to bleaching, which aligns with the concept of identifying and protecting spatial refugia for conservation purposes mentioned in the statement from the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1214,
#      'completion_tokens': 67,
#      'total_tokens': 1281,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  143: {'id': 'batch_req_67e3f7cc618881909b8a19034b60b449',
#   'custom_id': 'request-143',
#   'response': {'status_code': 200,
#    'request_id': '8c3cde6af8f1b9388987391b6df5b97c',
#    'body': {'id': 'chatcmpl-BFKT1lb1ehl4YtEeFA788fwzj1HG7',
#     'object': 'chat.completion',
#     'created': 1742993295,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article describes the voom method, which includes calculating precision weights, scaling read counts by library size, and quantile normalization. These steps are consistent with the statement in the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1124,
#      'completion_tokens': 61,
#      'total_tokens': 1185,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '160': {'id': 'batch_req_67e3f66d52f8819090ecda0b73fd7c64',
#   'custom_id': 'request-160',
#   'response': {'status_code': 200,
#    'request_id': '2c74131211951d13f242beb2caaf5ec8',
#    'body': {'id': 'chatcmpl-BFKOAY3uAqo2eqCw5GT6JVW554DDB',
#     'object': 'chat.completion',
#     'created': 1742992994,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article discusses the short lifetime and transport length of hot electrons, mentioning timescales on the order of 100 fs to 180 fs, which is shorter than the picosecond timescale mentioned in the citing article. However, it does support the general idea that hot carriers lose their excess energy quickly, which aligns with the main challenge described in the statement."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1151,
#      'completion_tokens': 97,
#      'total_tokens': 1248,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  161: {'id': 'batch_req_67e3f74dc12c8190b6dbe22be05a6abc',
#   'custom_id': 'request-161',
#   'response': {'status_code': 200,
#    'request_id': 'b243d7fd8cdd72cf5e74a79dfc0fdac9',
#    'body': {'id': 'chatcmpl-BFKRljcMQqGuywM6nygXQlx7NQENC',
#     'object': 'chat.completion',
#     'created': 1742993217,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article discusses the detection of Majorana fermions through zero-bias conductance peaks and their modulation, which aligns with the statement. However, it does not explicitly mention the modulation by external electrical fields, only magnetic fields. Thus, the reference partially supports the statement but misses a specific detail."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1259,
#      'completion_tokens': 83,
#      'total_tokens': 1342,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  162: {'id': 'batch_req_67e3f76df2ac81908b986927f27e0d4c',
#   'custom_id': 'request-162',
#   'response': {'status_code': 200,
#    'request_id': '3b726b46e5358535ec34d5c1429d54b0',
#    'body': {'id': 'chatcmpl-BFKSPfeEfzAqeif5ndrNBAEnzrzJb',
#     'object': 'chat.completion',
#     'created': 1742993257,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article discusses ejecta mass (Mej) and velocity (vej) values that are in the same order of magnitude as those cited in the statement (Mej = 0.05 M☉, vej = 0.1c). However, the specific values mentioned in the statement are not directly supported by the reference article, which provides a range of values and a fiducial model with different parameters (Mej = 5 × 10^-3 M☉, vej = 0.2c)."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1291,
#      'completion_tokens': 131,
#      'total_tokens': 1422,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  163: {'id': 'batch_req_67e3f7cc73948190a2ad0cc9fa2099e9',
#   'custom_id': 'request-163',
#   'response': {'status_code': 200,
#    'request_id': '643f92df59889c745ce4d0b5b1e66209',
#    'body': {'id': 'chatcmpl-BFKT1xfsuIEjmLuxREU29VaH57kU8',
#     'object': 'chat.completion',
#     'created': 1742993295,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
# ...
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1203,
#      'completion_tokens': 84,
#      'total_tokens': 1287,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  201: {'id': 'batch_req_67e3f74e03bc81908d7bcfad96266864',
#   'custom_id': 'request-201',
#   'response': {'status_code': 200,
#    'request_id': 'be8b8bb9d325ce3230c833de8bd80f4b',
#    'body': {'id': 'chatcmpl-BFKRpYBvxFiaDHQELC26ZaZ7jBsq0',
#     'object': 'chat.completion',
#     'created': 1742993221,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article discusses the challenges related to the placement, micromotion, and wiring of nanowires to external recording systems, which aligns with the statement in the citing article. Specifically, it mentions the logistical challenges of transmitting information from recording sites, the issue of electrode micromotions, and the need for flexible micro-wires or nanowires to decouple recording sites from electronics."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1127,
#      'completion_tokens': 99,
#      'total_tokens': 1226,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  202: {'id': 'batch_req_67e3f76e10bc8190a71566df87f37416',
#   'custom_id': 'request-202',
#   'response': {'status_code': 200,
#    'request_id': '13f566e385161e98f11a139298659ef5',
#    'body': {'id': 'chatcmpl-BFKSQxXM8hkOyKSN4EaPin88KUmPw',
#     'object': 'chat.completion',
#     'created': 1742993258,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article describes a touch panel made of a highly deformable conductive gel with electrodes attached at each corner, capable of detecting both touch and stretch. This aligns with the statement in the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1174,
#      'completion_tokens': 62,
#      'total_tokens': 1236,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  203: {'id': 'batch_req_67e3f7cc964081909d5245567d0334b9',
#   'custom_id': 'request-203',
#   'response': {'status_code': 200,
#    'request_id': 'e89ceab30df843d8a58522c535e19092',
#    'body': {'id': 'chatcmpl-BFKT2QSsL0gJJjuqVkgtlxkvIK5n2',
#     'object': 'chat.completion',
#     'created': 1742993296,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article discusses dielectric loss spectra and mentions low-frequency ionic relaxation and high-frequency electronic processes in MAPbI3. However, the specific frequency ranges cited in the statement (low-frequency <104 Hz and high-frequency ~105 to 106 Hz) are not explicitly supported by the reference article, which mentions a low-/high-frequency boundary at ~103 Hz and other frequency behaviors. Thus, while the general concept is supported, the exact frequency ranges are not."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1260,
#      'completion_tokens': 115,
#      'total_tokens': 1375,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '220': {'id': 'batch_req_67e3f66d8fc8819080ca64a9f20e486a',
#   'custom_id': 'request-220',
#   'response': {'status_code': 200,
#    'request_id': 'e178266577b162f8db79fb5224b4c3c1',
#    'body': {'id': 'chatcmpl-BFKOG2UobnSZ3hC6nN8cAOuibY0cC',
#     'object': 'chat.completion',
#     'created': 1742993000,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article discusses the use of anisotropic nanostructures to create photonic structures with tunable properties, which aligns with the concept of bio-inspired structural color materials. However, it does not specifically mention hydrogels or their applications in switches, optical devices, sensing materials, and wearable electronics. Therefore, while it supports the general idea of bio-inspired structural color materials, it does not fully substantiate the specific claims made in the statement."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1094,
#      'completion_tokens': 113,
#      'total_tokens': 1207,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  221: {'id': 'batch_req_67e3f74e26f0819096f91674519f4783',
#   'custom_id': 'request-221',
#   'response': {'status_code': 200,
#    'request_id': 'c3a32e7def9ef45ce4745c68a4be7c37',
#    'body': {'id': 'chatcmpl-BFKRsNmBKAhvJjZuwBwIzlSWoDHaT',
#     'object': 'chat.completion',
#     'created': 1742993224,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article discusses the adverse impacts of elevated chloride concentrations on freshwater ecosystems, including potential harm to aquatic species and water quality. This supports the statement in the citing article that elevated chloride concentrations can have adverse effects on water quality and aquatic ecosystems."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1225,
#      'completion_tokens': 70,
#      'total_tokens': 1295,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  222: {'id': 'batch_req_67e3f76e1f2c81909459a67fc46a6984',
#   'custom_id': 'request-222',
#   'response': {'status_code': 200,
#    'request_id': '584c005a9deebf1503b8b18f7ecb9f99',
#    'body': {'id': 'chatcmpl-BFKSSkeWY609EwqyddYuf5ByztpXl',
#     'object': 'chat.completion',
#     'created': 1742993260,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article provides evidence that phosphorylation preferentially targets nuclear proteins, as stated in the citing article. Specifically, it mentions that almost half of the phosphorylation events occurred on nuclear proteins, which supports the claim made in the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1183,
#      'completion_tokens': 68,
#      'total_tokens': 1251,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  223: {'id': 'batch_req_67e3f7cca8948190be372f9681a90934',
#   'custom_id': 'request-223',
#   'response': {'status_code': 200,
#    'request_id': '762b79f7abb2f1e2cc3f93adc937ea3d',
#    'body': {'id': 'chatcmpl-BFKT4NtNyear2SSICbJBVqUPEBVqM',
#     'object': 'chat.completion',
#     'created': 1742993298,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article discusses the high inter-observer variation in identifying osteophytes in skeletal samples, which aligns with the statement in the citing article. The reference article specifically mentions the need for better operational definitions and the variability in diagnosing osteoarthritis, supporting the claim that osteophytes were not used as a diagnostic criterion due to this variation."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1207,
#      'completion_tokens': 89,
#      'total_tokens': 1296,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  '240': {'id': 'batch_req_67e3f66da42c8190949386ec88899210',
#   'custom_id': 'request-240',
#   'response': {'status_code': 200,
#    'request_id': '634d52bc70514eef2bf9776b64450423',
#    'body': {'id': 'chatcmpl-BFKOIs3kpNViVBYG9hMTpkonc6MA5',
#     'object': 'chat.completion',
#     'created': 1742993002,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article discusses the role of Yap in C2C12 myogenesis, including its phosphorylation and localization changes during differentiation. However, it does not provide information about a transition zone with nuclear localization increasing from 2 to 38 kPa, nor does it compare YAP expression and nuclear localization patterns between C2C12 myoblasts and stem cells."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1369,
#      'completion_tokens': 95,
#      'total_tokens': 1464,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  241: {'id': 'batch_req_67e3f74e489481909b2c9c06fd27fc28',
#   'custom_id': 'request-241',
#   'response': {'status_code': 200,
#    'request_id': '7b3368a869b1c5b604fa92c35315b2cb',
#    'body': {'id': 'chatcmpl-BFKRuR5CzRkgjxe6wG7LxqXfRjVJn',
#     'object': 'chat.completion',
#     'created': 1742993226,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Fully substantiate",\n  "explanation": "The reference article discusses the role of Mdm1 as an interorganelle tethering protein that localizes to ER-lysosome (vacuole in yeast) membrane contact sites. This supports the statement that ER appositions were found with lysosomes, as mentioned in the citing article."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1271,
#      'completion_tokens': 82,
#      'total_tokens': 1353,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  242: {'id': 'batch_req_67e3f76e2e448190b2600839802a181a',
#   'custom_id': 'request-242',
#   'response': {'status_code': 200,
#    'request_id': '6d3ec9fc51812b2f10d244dbea842dd7',
#    'body': {'id': 'chatcmpl-BFKSQmhsEuF5TkKXxuw21ioc7tfwL',
#     'object': 'chat.completion',
#     'created': 1742993258,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article does not provide any information about the neurological scores of wild-type and NSEMT1-GFP mice 2 hours after pMCAO. It focuses on the effects of ICE-like protease inhibitors on ischemic and excitotoxic neuronal damage, and the neurological deficits were assessed at different time points and under different conditions."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1437,
#      'completion_tokens': 89,
#      'total_tokens': 1526,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None},
#  243: {'id': 'batch_req_67e3f7ccbc7c81908895e03ce5c9a743',
#   'custom_id': 'request-243',
#   'response': {'status_code': 200,
#    'request_id': '038ff009702a43bbb090da2d6f7077ed',
#    'body': {'id': 'chatcmpl-BFKT66K9u9o5APJj03wWB23rh9fUi',
#     'object': 'chat.completion',
#     'created': 1742993300,
#     'model': 'gpt-4o-2024-05-13',
#     'choices': [{'index': 0,
#       'message': {'role': 'assistant',
#        'content': '```json\n{\n  "label": "Partially substantiate",\n  "explanation": "The reference article provides evidence for GPCR signaling from endosomes, which supports part of the statement. However, it does not mention GPCRs on endoplasmic reticulum, nuclear, or mitochondrial membranes, making the statement only partially substantiated."\n}\n```',
#        'refusal': None,
#        'annotations': []},
#       'logprobs': None,
#       'finish_reason': 'stop'}],
#     'usage': {'prompt_tokens': 1309,
#      'completion_tokens': 73,
#      'total_tokens': 1382,
#      'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0},
#      'completion_tokens_details': {'reasoning_tokens': 0,
#       'audio_tokens': 0,
#       'accepted_prediction_tokens': 0,
#       'rejected_prediction_tokens': 0}},
#     'service_tier': 'default',
#     'system_fingerprint': 'fp_49b7ecf55e'}},
#   'error': None}}

# %%
import json

# Save responses_dict to a JSON file
with open(f'../data/responses_dict_batch_{model}.json', 'w') as file:
    json.dump(responses_dict, file, indent=4)

# %% [markdown]
# #### Save responds to Dataframe

# %%
# Create a new column in the dataframe to store the responses
if 'Model Classification' not in df.columns:
    df['Model Classification'] = None

# Iterate through the dataframe
for index, row in df.iterrows():
    if row['Reference Article Downloaded'] == 'Yes':
        print(responses_dict)
        model_response = responses_dict[index]['response']['body']['choices'][0]['message']['content']
        
        # Save the response to the new column
        df.at[index, 'Model Classification'] = model_response
# Out:
# {0: {'id': 'batch_req_67e3cf8de7b88190ad3b1448870ebab2', 'custom_id': 'request-0', 'response': {'status_code': 200, 'request_id': 'f0520eab9a6260230996aaa5b8327b81', 'body': {'id': 'chatcmpl-BFHn1hPe6dsjo8DQBzB4L44OSa2P7', 'object': 'chat.completion', 'created': 1742983003, 'model': 'gpt-4-0125-preview', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on a fault analysis method for three-phase induction motors using modified fuzzy reasoning spiking neural P systems, which is unrelated to reducing irreversibility or optimizing energy-consumed devices as mentioned in the citing article\'s statement."\n}\n```', 'refusal': None, 'annotations': []}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 1188, 'completion_tokens': 70, 'total_tokens': 1258, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'service_tier': 'default', 'system_fingerprint': None}}, 'error': None}, 5: {'id': 'batch_req_67e3cf8df81081909002a58bba6b41f5', 'custom_id': 'request-5', 'response': {'status_code': 200, 'request_id': 'faf3c5e77611d8f0b22ccf28d787e055', 'body': {'id': 'chatcmpl-BFHn1Gcz4WcGTZeXJ5ycPMIIF9nW5', 'object': 'chat.completion', 'created': 1742983003, 'model': 'gpt-4-0125-preview', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on the development trends and technology hotspots in China\'s textile manufacturing industry, utilizing knowledge maps and visualization tools. It does not discuss or mention trust values, communication success or failure rates, or any concepts related to trust management in wireless sensor networks. Therefore, it does not substantiate the statement from the citing article regarding trust values and communication metrics."\n}\n```', 'refusal': None, 'annotations': []}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 1312, 'completion_tokens': 95, 'total_tokens': 1407, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'service_tier': 'default', 'system_fingerprint': None}}, 'error': None}, 10: {'id': 'batch_req_67e3cf8e08d08190be5db2bc67ae1d19', 'custom_id': 'request-10', 'response': {'status_code': 200, 'request_id': '18014f6d2b43c18ab1f9a92150738603', 'body': {'id': 'chatcmpl-BFHn1bHy03SNyBRRfBlJsom0MWOOC', 'object': 'chat.completion', 'created': 1742983003, 'model': 'gpt-4-0125-preview', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article discusses a particle centroid drift (PCD) algorithm for target positioning in large-scale wireless sensor networks (WSNs) and does not mention or propose a hybrid artificial bee colony algorithm. Therefore, it does not substantiate the statement from the citing article."\n}\n```', 'refusal': None, 'annotations': []}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 1124, 'completion_tokens': 75, 'total_tokens': 1199, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'service_tier': 'default', 'system_fingerprint': None}}, 'error': None}, 15: {'id': 'batch_req_67e3cf8e1b0c81909e0a8fbb65bb0b44', 'custom_id': 'request-15', 'response': {'status_code': 200, 'request_id': '22ecd6c348f829ddd1659e02ea0efce7', 'body': {'id': 'chatcmpl-BFHn10fyRt8DTGjBcpEq1l0QFlmhF', 'object': 'chat.completion', 'created': 1742983003, 'model': 'gpt-4-0125-preview', ...
# {0: {'id': 'batch_req_67e3cf8de7b88190ad3b1448870ebab2', 'custom_id': 'request-0', 'response': {'status_code': 200, 'request_id': 'f0520eab9a6260230996aaa5b8327b81', 'body': {'id': 'chatcmpl-BFHn1hPe6dsjo8DQBzB4L44OSa2P7', 'object': 'chat.completion', 'created': 1742983003, 'model': 'gpt-4-0125-preview', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on a fault analysis method for three-phase induction motors using modified fuzzy reasoning spiking neural P systems, which is unrelated to reducing irreversibility or optimizing energy-consumed devices as mentioned in the citing article\'s statement."\n}\n```', 'refusal': None, 'annotations': []}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 1188, 'completion_tokens': 70, 'total_tokens': 1258, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'service_tier': 'default', 'system_fingerprint': None}}, 'error': None}, 5: {'id': 'batch_req_67e3cf8df81081909002a58bba6b41f5', 'custom_id': 'request-5', 'response': {'status_code': 200, 'request_id': 'faf3c5e77611d8f0b22ccf28d787e055', 'body': {'id': 'chatcmpl-BFHn1Gcz4WcGTZeXJ5ycPMIIF9nW5', 'object': 'chat.completion', 'created': 1742983003, 'model': 'gpt-4-0125-preview', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article focuses on the development trends and technology hotspots in China\'s textile manufacturing industry, utilizing knowledge maps and visualization tools. It does not discuss or mention trust values, communication success or failure rates, or any concepts related to trust management in wireless sensor networks. Therefore, it does not substantiate the statement from the citing article regarding trust values and communication metrics."\n}\n```', 'refusal': None, 'annotations': []}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 1312, 'completion_tokens': 95, 'total_tokens': 1407, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'service_tier': 'default', 'system_fingerprint': None}}, 'error': None}, 10: {'id': 'batch_req_67e3cf8e08d08190be5db2bc67ae1d19', 'custom_id': 'request-10', 'response': {'status_code': 200, 'request_id': '18014f6d2b43c18ab1f9a92150738603', 'body': {'id': 'chatcmpl-BFHn1bHy03SNyBRRfBlJsom0MWOOC', 'object': 'chat.completion', 'created': 1742983003, 'model': 'gpt-4-0125-preview', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article discusses a particle centroid drift (PCD) algorithm for target positioning in large-scale wireless sensor networks (WSNs) and does not mention or propose a hybrid artificial bee colony algorithm. Therefore, it does not substantiate the statement from the citing article."\n}\n```', 'refusal': None, 'annotations': []}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 1124, 'completion_tokens': 75, 'total_tokens': 1199, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'service_tier': 'default', 'system_fingerprint': None}}, 'error': None}, 15: {'id': 'batch_req_67e3cf8e1b0c81909e0a8fbb65bb0b44', 'custom_id': 'request-15', 'response': {'status_code': 200, 'request_id': '22ecd6c348f829ddd1659e02ea0efce7', 'body': {'id': 'chatcmpl-BFHn10fyRt8DTGjBcpEq1l0QFlmhF', 'object': 'chat.completion', 'created': 1742983003, 'model': 'gpt-4-0125-preview', ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 9
#       7 if row['Reference Article Downloaded'] == 'Yes':
#       8     print(responses_dict)
# ----> 9     model_response = responses_dict[index]['response']['body']['choices'][0]['message']['content']
#      11     # Save the response to the new column
#      12     df.at[index, 'Model Classification'] = model_response
#
# KeyError: 1

# %%
df.to_pickle(f"../data/dfs/{embedding}{'_no_prev_chunking' if no_prev_chunking else ''}/{grobid_model}/ReferenceErrorDetection_data_with_prompt_results_batched.pkl")

# %% [markdown]
# ## Prompting the models (no batching)

# %%
# Read the content of open_ai_key.txt into a variable
with open('../open_ai_key.txt', 'r') as file:
    open_ai_key = file.read().strip()

# %%
from openai import OpenAI
client = OpenAI(api_key=open_ai_key)

def send_prompt(prompt, model):
    completion = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "user",
                "content": prompt
            }
        ],
        temperature=0,
        timeout=30,

    )
    return completion.choices[0].message.content

# %%
models = ["gpt-3.5-turbo-0125", "gpt-4-0125-preview", "gpt-4o-2024-05-13", "gpt-4-turbo-preview"]
model = models[2]

send_prompt(example_prompt, model)
# Out:
# '```json\n{\n  "label": "Unsubstantiate",\n  "explanation": "The reference article \'DeepCleave: a deep learning predictor for caspase and matrix metalloprotease substrates and cleavage sites\' focuses on deep learning models for predicting protease-specific substrates and cleavage sites. It does not address issues related to arranging classes or summarizing grades in a high-level management context, which is the subject of the statement in the citing article."\n}\n```'

# %%
# path = f"../data/dfs/{embedding}{'_no_prev_chunking' if no_prev_chunking else ''}/{grobid_model}/ReferenceErrorDetection_data_with_prompt_results.pkl"
# df = pd.read_pickle(path)

# %%
ids_to_prompt = []
ids_not_to_prompt = []

# %%
def prompting_model(df, model, save_intermediate_results=False):
    print(f"Prompting model: {model}")

    # Create a new column in the dataframe to store the responses
    if 'Model Classification' not in df.columns:
        df['Model Classification'] = None

    # Iterate through the dataframe
    for index, row in df.iterrows():
        if row['Reference Article Downloaded'] == 'Yes':
            if len(ids_to_prompt) != 0 and row['Reference Article ID'] not in ids_to_prompt:
                continue

            if len(ids_not_to_prompt) != 0 and row['Reference Article ID'] in ids_not_to_prompt:
                continue

            print(f"Processing: " + row['Reference Article ID'])

            # Create the prompt
            prompt = create_prompt(row)
            
            # Send the prompt and get the response
            response = send_prompt(prompt, model)
            
            # Save the response to the new column
            df.at[index, 'Model Classification'] = response

            if save_intermediate_results and index % 10 == 0:
                df.to_pickle(f"../data/dfs/{embedding}{'_no_prev_chunking' if no_prev_chunking else ''}/{grobid_model}/ReferenceErrorDetection_data_with_prompt_results_{model}_intermed.pkl")
    return df

# %%
df2 = prompting_model(df, model, True)
# Out:
# Prompting model: gpt-4o-2024-05-13
# Processing: r001
# Processing: r002
# Processing: r003
# Processing: r004
# Processing: r005
# Processing: r006
# Processing: r007
# Processing: r008
# Processing: r009
# Processing: r010
# Processing: r011
# Processing: r012
# Processing: r013
# Processing: r013
# Processing: r014
# Processing: r015
# Processing: r005
# Processing: r017
# Processing: r018
# Processing: r019
# Processing: r020
# Processing: r021
# Processing: r022
# Processing: r023
# Processing: r024
# Processing: r013
# Processing: r025
# Processing: r026
# Processing: r027
# Processing: r028
# Processing: r029
# Processing: r030
# Processing: r031
# Processing: r032
# Processing: r033
# Processing: r034
# Processing: r035
# Processing: r036
# Processing: r037
# Processing: r038
# Processing: r039
# Processing: r040
# Processing: r041
# Processing: r042
# Processing: r043
# Processing: r044
# Processing: r045
# Processing: r046
# Processing: r047
# Processing: r048
# Processing: r049
# Processing: r050
# Processing: r051
# Processing: r052
# Processing: r053
# Processing: r051
# Processing: r055
# Processing: r056
# Processing: r057
# Processing: r058
# Processing: r059
# Processing: r060
# Processing: r061
# Processing: r062
# Processing: r063
# Processing: r064
# Processing: r065
# Processing: r066
# Processing: r067
# Processing: r068
# Processing: r069
# Processing: r070
# Processing: r071
# Processing: r072
# Processing: r074
# Processing: r075
# Processing: r076
# Processing: r077
# Processing: r078
# Processing: r079
# Processing: r080
# Processing: r081
# Processing: r081
# Processing: r082
# Processing: r083
# Processing: r084
# Processing: r085
# Processing: r086
# Processing: r087
# Processing: r087
# Processing: r087
# Processing: r088
# Processing: r089
# Processing: r090
# Processing: r091
# Processing: r092
# Processing: r093
# Processing: r094
# Processing: r095
# Processing: r096
# Processing: r097
# Processing: r098
# Processing: r099
# Processing: r100
# Processing: r101
# Processing: r102
# Processing: r103
# Processing: r104
# Processing: r105
# Processing: r106
# Processing: r107
# Processing: r108
# Processing: r109
# Processing: r110
# Processing: r111
# Processing: r112
# Processing: r113
# Processing: r114
# Processing: r115
# Processing: r116
# Processing: r117
# Processing: r118
# Processing: r119
# Processing: r120
# Processing: r121
# Processing: r122
# Processing: r123
# Processing: r124
# Processing: r125
# Processing: r126
# Processing: r127
# Processing: r128
# Processing: r129
# Processing: r130
# Processing: r131
# Processing: r132
# Processing: r133
# Processing: r134
# Processing: r135
# Processing: r136
# Processing: r137
# Processing: r138
# Processing: r139
# Processing: r140
# Processing: r141
# Processing: r142
# Processing: r143
# Processing: r144
# Processing: r145
# Processing: r146
# Processing: r147
# Processing: r148
# Processing: r149
# Processing: r150
# Processing: r151
# Processing: r152
# Processing: r153
# Processing: r154
# Processing: r155
# Processing: r156
# Processing: r157
# Processing: r158
# Processing: r159
# Processing: r160
# Processing: r161
# Processing: r162
# Processing: r163
# Processing: r164
# Processing: r165
# Processing: r166
# Processing: r167
# Processing: r168
# Processing: r169
# Processing: r170
# Processing: r171
# Processing: r172
# Processing: r173
# Processing: r174
# Processing: r175
# Processing: r176
# Processing: r177
# Processing: r178
# Processing: r179
# Processing: r180
# Processing: r181
# Processing: r182
# Processing: r183
# Processing: r184
# Processing: r185
# Processing: r186
# Processing: r187
# Processing: r188
# Processing: r189
# Processing: r190
# Processing: r191
# Processing: r192
# Processing: r193
# Processing: r194
# Processing: r195
# Processing: r196
# Processing: r197
# Processing: r198
# Processing: r199
# Processing: r200
# Processing: r201
# Processing: r202
# Processing: r203
# Processing: r204
# Processing: r205
# Processing: r206
# Processing: r207
# Processing: r208
# Processing: r209
# Processing: r210
# Processing: r211
# Processing: r212
# Processing: r213
# Processing: r214
# Processing: r215
# Processing: r216
# Processing: r217
# Processing: r218
# Processing: r219
# Processing: r220
# Processing: r221
# Processing: r222
# Processing: r223
# Processing: r224
# Processing: r225
# Processing: r226
# Processing: r227
# Processing: r228
# Processing: r229
# Processing: r230
# Processing: r231
# Processing: r232
# Processing: r233
# Processing: r234
# Processing: r235
# Processing: r236
# Processing: r237
# Processing: r238
# Processing: r239
# Processing: r240
# Processing: r241
# Processing: r242
# Processing: r243

# %%
df2.to_pickle(f"../data/dfs/{embedding}{'_no_prev_chunking' if no_prev_chunking else ''}/{grobid_model}/ReferenceErrorDetection_data_with_prompt_results_{model}.pkl")
