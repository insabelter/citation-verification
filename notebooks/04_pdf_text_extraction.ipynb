# %% [markdown]
# # PDF Text Extraction

# %% [markdown]
# PDF scientific paper text extraction using GROBID:
# - Github: https://github.com/kermitt2/grobid
# - Documentation: https://grobid.readthedocs.io/en/latest/

# %%
import os
import requests

def convert_pdf_to_xml(input_pdf_path, output_xml_path):
    if os.path.exists(output_xml_path):
        print(f"Already exists: {output_xml_path}")
        return
    
    url = "http://localhost:8070/api/processFulltextDocument"
    with open(input_pdf_path, 'rb') as pdf_file:
        files = {'input': pdf_file}
        response = requests.post(url, files=files)
        
        if response.status_code == 200:
            with open(output_xml_path, 'wb') as xml_file:
                xml_file.write(response.content)
            print(f"Successfully converted: {output_xml_path}")
        else:
            print(f"Failed to convert {input_pdf_path}. Status code: {response.status_code}")

# %%
# Example usage
pdf_name = "c001_Heating a residential building using the heat generated in the lithium ion battery pack by the elect"
input_pdf_path = f"../data/papers/{pdf_name}.pdf"
output_xml_path = f"../data/extractions/{pdf_name}.xml"
convert_pdf_to_xml(input_pdf_path, output_xml_path)
# Out:
# The file ../data/extractions/c001_Heating a residential building using the heat generated in the lithium ion battery pack by the elect.xml already exists.

# %%
# Directory containing the PDF files
pdf_directory = "../data/papers"

# Iterate through all the files in the directory
for filename in os.listdir(pdf_directory):
    if filename.endswith(".pdf"):
        pdf_name = filename[:-4]  # Remove the .pdf extension
        input_pdf_path = os.path.join(pdf_directory, filename)
        output_xml_path = f"../data/extractions/{pdf_name}.xml"
        convert_pdf_to_xml(input_pdf_path, output_xml_path)
# Out:
# Already exists: ../data/extractions/c001_Heating a residential building using the heat generated in the lithium ion battery pack by the elect.xml
# Successfully converted: ../data/extractions/c002_Oxidative Potential and Nanoantioxidant Activity of Flavonoids and Phenolic Acids in Sophora flavesc.xml
# Successfully converted: ../data/extractions/c003_The Choice of Anesthetic Drugs in Outpatient Hysteroscopic Surgery A.xml
# Successfully converted: ../data/extractions/c004_A Fault-Tolerant Structure for Nano-Power Communication Based on the Multidimensional Crossbar Switc.xml
# Successfully converted: ../data/extractions/c005_A Secure Routing Protocol for Wireless Sensor Energy Network Based on Trust Management.xml
# Successfully converted: ../data/extractions/c006_A Study on the Impact of International Translation Levels Based on Multiple Correlation Analysis.xml
# Successfully converted: ../data/extractions/c007_An Effective Hybrid Multiobjective Flexible Job Shop Scheduling Problem Based on Improved Genetic Al.xml
# Successfully converted: ../data/extractions/c008_An Empirical Study on the Influence Mechanism of High-Level Universities on Local Enterprise Innovat.xml
# Successfully converted: ../data/extractions/c009_Analysis of Factors Related to Spiritual Psychology and Quality of Life in Patients.xml
# Successfully converted: ../data/extractions/c010_Application and Visualization of Human 3D Anatomy Teaching for Healthy People Based on a Hybrid Netw.xml
# Successfully converted: ../data/extractions/c011_Application of Cloud Computing and GIS Based on Internet of Things in Oil and Gas Storage.xml
# Successfully converted: ../data/extractions/c012_Application of Computer Vision and Sensor Technology in Multivariate Assessment of Ecological Enviro.xml
# Successfully converted: ../data/extractions/c013_Application of Data Mining Algorithm in Electric Power Marketing Inspection Forecast Analysis.xml
# Successfully converted: ../data/extractions/c014_Application of Edge Computing in Physical Education Teaching Management.xml
# Successfully converted: ../data/extractions/c015_Application of Functional Training in Sports Dance Training.xml
# Successfully converted: ../data/extractions/c016_Application of Improved DEA Algorithm in Public Management Problem Classification.xml
# Successfully converted: ../data/extractions/c017_A Model of Urban Economic Resilience Development with Multisource Data Fusion.xml
# Successfully converted: ../data/extractions/c018_A Random Matrix Network Model for the Network Teaching System of College Music Education Courses.xml
# Successfully converted: ../data/extractions/c019_Individualized Management of Quality of Care in Orthopedic Nurses Based on Sensitive Indicators.xml
# Successfully converted: ../data/extractions/c020_Music Timbre Extracted from Audio Signal Features.xml
# Successfully converted: ../data/extractions/c021_Supply Chain Management System for Automobile Manufacturing Enterprises Based on SAP.xml
# Successfully converted: ../data/extractions/c022_Analysis on the Artistic Presentation Effect of 3D Rendering Ink Painting Based on the Evaluation of.xml
# Successfully converted: ../data/extractions/c023_Optimization Algorithm of Moving Object Detection Using Multiscale Pyramid Convolutional Neural Netw.xml
# Successfully converted: ../data/extractions/c024_Hybrid deep learning model for automatic fake news detection.xml
# Successfully converted: ../data/extractions/c025_Smart assistance to dyslexia students using artificial intelligence based augmentative alternative c.xml
# Successfully converted: ../data/extractions/c026_Biosynthesis of Zn-doped CuFe2O4 nanoparticles and their cytotoxic activity.xml
# Successfully converted: ../data/extractions/c027_Crystal structure and anticancer activity of retinoblastoma of an in(iii)-na(i) coordination polymer.xml
# Successfully converted: ../data/extractions/c028_Structural insights and anti-colon cancer activity of two Zn(ii)-based coordination ploymers based o.xml
# Successfully converted: ../data/extractions/c029_Comparison of individual based approaches using RAPD markers for identifying genetic relationships i.xml
# Successfully converted: ../data/extractions/c030_Evaluation of genetic variability Rindera using RAPD markers.xml
# Successfully converted: ../data/extractions/c031_Gene flow and genetic structure between populations of Hesperis L.xml
# Successfully converted: ../data/extractions/c032_Genetic diversity and gene-pool of Aegilops tauschii Coss.xml
# Successfully converted: ../data/extractions/c033_Genetic diversity and gene-pool of Salicornia Sinus-Persica Akhani based on retrotransposon-based ma.xml
# Successfully converted: ../data/extractions/c034_Genetic diversity and population structure analysis in Lonicera L. (Caprifoliaceae) with the use of.xml
# Successfully converted: ../data/extractions/c035_Retracted Genetic diversity of Cordia myxa L. assessed by ISSR markers, 10.2298gensr2201063n.xml
# Successfully converted: ../data/extractions/c036_Molecular systematic studies in the genus Glaucium (Papaveraceae.xml
# Successfully converted: ../data/extractions/c037_Two Novel Ca(II)-Carboxylate Coordination Polymers Crystal Structures and Antimyeloma Activity Eval.xml
# Successfully converted: ../data/extractions/c038_A New Coordination Polymer Based on Two Dual-Functional Ligands Structural Insights and Treatment E.xml
# Successfully converted: ../data/extractions/c039_The Exploration and Countermeasures of University Education Management Model Based on Big Data Techn.xml
# Successfully converted: ../data/extractions/c040_Numerical assessment of the influence of helical baffle on the hydrothermal aspects of nanofluid tur.xml
# Successfully converted: ../data/extractions/c041_Research on English teaching system based on artificial intelligence and WBIETS wireless network sys.xml
# Successfully converted: ../data/extractions/c042_Pattern mining model based on improved neural network and modified genetic algorithm for cloud mobil.xml
# Successfully converted: ../data/extractions/c043_Monitoring of Sports Health Indicators Based on Wearable Nanobiosensors.xml
# Successfully converted: ../data/extractions/c044_Solar radiation impact on ferrofluid convection with applying electric field.xml
# Successfully converted: ../data/extractions/c046_Peptidic Connexin43 Therapeutics in Cardiac Reparative Medicine.xml
# Successfully converted: ../data/extractions/c047_Cell Therapy for Anal Sphincter Incontinence Where Do We Stand.xml
# Successfully converted: ../data/extractions/c048_Association of Generalized granuloma annulare with autoantibodies.xml
# Successfully converted: ../data/extractions/c049_Autoantibodies in scleroderma.xml
# Successfully converted: ../data/extractions/c050_Treatment of chronic postoperative otorrhea with cultured keratinocyte sheets.xml
# Successfully converted: ../data/extractions/c051_Origin and initial course of the renal arteries a radiological study.xml
# Successfully converted: ../data/extractions/c052_Variation rs9929218 and risk of the colorectal Cancer and adenomas A meta-analysis.xml
# Successfully converted: ../data/extractions/c053_Association Between c-Myc and Colorectal Cancer Prognosis A Meta-Analysis.xml
# Successfully converted: ../data/extractions/c054_The relationships between HLA class II alleles and antigens with gestational diabetes mellitus A me.xml
# Successfully converted: ../data/extractions/c055_Vertically extensive and unstable magmatic systems A unified view of igneous processes.xml
# Successfully converted: ../data/extractions/c056_Inflammation and metabolism in tissue repair and regeneration.xml
# Successfully converted: ../data/extractions/c057_An environment-dependent transcriptional network specifies human microglia identity.xml
# Successfully converted: ../data/extractions/c058_High dislocation density-induced large ductility in deformed and partitioned steels.xml
# Successfully converted: ../data/extractions/c059_ATP as a biological hydrotrope.xml
# Successfully converted: ../data/extractions/c060_Biodiversity redistribution under climate change Impacts on ecosystems and human well-being.xml
# Successfully converted: ../data/extractions/c061_A roadmap for rapid decarbonization.xml
# Successfully converted: ../data/extractions/c062_Mapping the human DC lineage through the integration of high-dimensional techniques.xml
# Successfully converted: ../data/extractions/c063_Impact of cytosine methylation on DNA binding specificities of human transcription factors.xml
# Successfully converted: ../data/extractions/c064_Scalable-manufactured randomized glass-polymer hybrid metamaterial for daytime radiative cooling.xml
# Successfully converted: ../data/extractions/c065_Snowball Earth climate dynamics and Cryogenian geology-geobiology.xml
# Successfully converted: ../data/extractions/c066_Blueprint for a microwave trapped ion quantum computer.xml
# Successfully converted: ../data/extractions/c067_Oriented assembly of anisotropic nanoparticles into frame-like superstructures.xml
# Successfully converted: ../data/extractions/c068_Disabling Cas9 by an anti-CRISPR DNA mimic.xml
# Successfully converted: ../data/extractions/c069_Resource tracking within and across continents in long-distance bird migrants.xml
# Successfully converted: ../data/extractions/c070_Extracellular polymeric substances are transient media for microbial extracellular electron transfer.xml
# Successfully converted: ../data/extractions/c071_Self-powered integrated microfluidic point-of-care low-cost enabling (SIMPLE) chip.xml
# Successfully converted: ../data/extractions/c072_Strained hybrid perovskite thin films and their impact on the intrinsic stability of perovskite sola.xml
# Successfully converted: ../data/extractions/c073_Identification of the gene that codes for the sigma(2) receptor.xml
# Successfully converted: ../data/extractions/c074_Natural climate solutions.xml
# Successfully converted: ../data/extractions/c075_Understanding band gaps of solids in generalized Kohn-Sham theory.xml
# Successfully converted: ../data/extractions/c076_Toxic PRn poly-dipeptides encoded by the C9orf72 repeat expansion block nuclear import and export.xml
# Successfully converted: ../data/extractions/c077_High thermal conductivity in soft elastomers with elongated liquid metal inclusions.xml
# Successfully converted: ../data/extractions/c078_Full atomistic reaction mechanism with kinetics for CO reduction on Cu(100) from ab initio molecular.xml
# Successfully converted: ../data/extractions/c079_Biocompatible and totally disintegrable semiconducting polymer for ultrathin and ultralightweight tr.xml
# Successfully converted: ../data/extractions/c080_Strengthening protected areas for biodiversity and ecosystem services in China.xml
# Successfully converted: ../data/extractions/c081_Contacts between the endoplasmic reticulum and other membranes in neurons.xml
# Successfully converted: ../data/extractions/c082_Tetragonal CH3NH3PbI3 is ferroelectric.xml
# Successfully converted: ../data/extractions/c083_Disrupting the blood-brain barrier by focused ultrasound induces sterile inflammation.xml
# Successfully converted: ../data/extractions/c084_Vacancy-induced dislocations within grains for high-performance PbSe thermoelectrics.xml
# Successfully converted: ../data/extractions/c085_Nanodiamonds suppress the growth of lithium dendrites.xml
# Successfully converted: ../data/extractions/c086_Dynamic plasmonic colour display.xml
# Successfully converted: ../data/extractions/c087_One-Year stable perovskite solar cells by 2D3D interface engineerin.xml
# Successfully converted: ../data/extractions/c088_Cryo-EM structure of haemoglobin at 3.2 angstrom determined with the Volta phase plate.xml
# Successfully converted: ../data/extractions/c089_X-ray pulses reach the carbon K-edge.xml
# Successfully converted: ../data/extractions/c090_A mesoporous cationic thorium-organic framework that rapidly traps anionic persistent organic pollut.xml
# Successfully converted: ../data/extractions/c091_nitrogen-doped graphene foam with encapsulated germaniumnitrogen-doped graphene yolk-shell nanoarch.xml
# Successfully converted: ../data/extractions/c092_Ruthenium-cobalt nanoalloys encapsulated in nitrogen-doped graphene as active electrocatalysts for p.xml
# Successfully converted: ../data/extractions/c093_Brigatinib combined with anti-EGFR antibody overcomes osimertinib resistance in EGFR-mutated non-sma.xml
# Successfully converted: ../data/extractions/c094_Precise tuning in platinum-nickel nickel sulfide interface nanowires for synergistic hydrogen evolu.xml
# Successfully converted: ../data/extractions/c095_Transcending the slow bimolecular recombination in lead-halide perovskites for electroluminescence.xml
# Successfully converted: ../data/extractions/c096_Thermally stable single atom Ptm-Al2O3 for selective hydrogenation and CO oxidation.xml
# Successfully converted: ../data/extractions/c097_Massively parallel digital transcriptional profiling of single cells.xml
# Successfully converted: ../data/extractions/c098_Enhanced sensitivity at higher-order exceptional points.xml
# Successfully converted: ../data/extractions/c099_An atlas of human long non-coding RNAs with accurate 5 ' ends.xml
# Successfully converted: ../data/extractions/c100_Global warming and recurrent mass bleaching of corals.xml
# Successfully converted: ../data/extractions/c101_A distinct role for Lgr5(+) stem cells in primary and metastatic colon cancer.xml
# Successfully converted: ../data/extractions/c102_The whole-genome landscape of medulloblastoma subtypes.xml
# Successfully converted: ../data/extractions/c103_Identification of essential genes for cancer immunotherapy.xml
# Successfully converted: ../data/extractions/c104_Cell diversity and network dynamics in photosensitive human brain organoids.xml
# Successfully converted: ../data/extractions/c105_structures of individual mammalian genomes studied by single-cell Hi-C.xml
# Successfully converted: ../data/extractions/c106_A communal catalogue reveals Earth's multiscale microbial diversity.xml
# Successfully converted: ../data/extractions/c107_Comprehensive single-cell transcriptional profiling of a multicellular organism.xml
# Successfully converted: ../data/extractions/c108_Transition metal-catalyzed alkyl-alkyl bond formation Another dimension in cross-coupling chemistry.xml
# Successfully converted: ../data/extractions/c109_Observation of the Wigner-Huntington transition to metallic hydrogen.xml
# Successfully converted: ../data/extractions/c110_The atom, the molecule, and the covalent organic framework.xml
# Successfully converted: ../data/extractions/c111_Epigenetic plasticity and the hallmarks of cancer.xml
# Successfully converted: ../data/extractions/c112_Long-range hot-carrier transport in hybrid perovskites visualized by ultrafast microscopy.xml
# Successfully converted: ../data/extractions/c113_Chiral Majorana fermion modes in a quantum anomalous Hall insulator-superconductor structure.xml
# Successfully converted: ../data/extractions/c114_Illuminating gravitational waves A concordant picture of photons from a neutron star merger.xml
# Successfully converted: ../data/extractions/c115_Active sites for CO2 hydrogenation to methanol on CuZnO catalysts.xml
# Successfully converted: ../data/extractions/c116_Water harvesting from air with metal-organic frameworks powered by natural sunlight.xml
# Successfully converted: ../data/extractions/c117_Engrams and circuits crucial for systems consolidation of a memory.xml
# Successfully converted: ../data/extractions/c118_Combining theory and experiment in electrocatalysis Insights into materials design.xml
# Successfully converted: ../data/extractions/c119_Structure of a eukaryotic voltage-gated sodium channel at near-atomic resolution.xml
# Successfully converted: ../data/extractions/c120_Colloidally prepared La-doped BaSnO3 electrodes for efficient, photostable perovskite solar cells.xml
# Successfully converted: ../data/extractions/c121_Selective anaerobic oxidation of methane enables direct synthesis of methanol.xml
# Successfully converted: ../data/extractions/c122_Decoupling genetics, lineages, and microenvironment in IDH-mutant gliomas by single-cell RNA-seq.xml
# Successfully converted: ../data/extractions/c123_Highly stretchable polymer semiconductor films through the nanoconfinement effect.xml
# Successfully converted: ../data/extractions/c124_Satellite-based entanglement distribution over 1200 kilometers.xml
# Successfully converted: ../data/extractions/c125_An organic-inorganic perovskite ferroelectric with large piezoelectric response.xml
# Successfully converted: ../data/extractions/c126_Advances in engineering hydrogels.xml
# Successfully converted: ../data/extractions/c127_Robust epitaxial growth of two-dimensional heterostructures, multiheterostructures, and superlattice.xml
# Successfully converted: ../data/extractions/c128_Deep reefs are not universal refuges Reseeding potential varies among coral species.xml
# Successfully converted: ../data/extractions/c129_Two orders of magnitude enhancement in oxygen evolution reactivity on amorphous Ba0.5Sr0.5Co0.8Fe0.2.xml
# Successfully converted: ../data/extractions/c130_2015 - Improved estimates of ocean heat content from 1960 to.xml
# Successfully converted: ../data/extractions/c131_Machine learning of accurate energy-conserving molecular force fields.xml
# Successfully converted: ../data/extractions/c132_From the generalized reflection law to the realization of perfect anomalous reflectors.xml
# Successfully converted: ../data/extractions/c133_Impending extinction crisis of the world's primates Why primates matter.xml
# Successfully converted: ../data/extractions/c134_Toward garnet electrolyte-based Li metal batteries An ultrathin, highly effective, artificial solid.xml
# Successfully converted: ../data/extractions/c135_Quasi-solid state rechargeable Na-CO2 batteries with reduced graphene oxide Na anodes.xml
# Successfully converted: ../data/extractions/c136_A dynamic hydrophobic core orchestrates allostery in protein kinases.xml
# Successfully converted: ../data/extractions/c137_Artificially lit surface of Earth at night increasing in radiance and extent.xml
# Successfully converted: ../data/extractions/c138_Wearabledisposable sweat-based glucose monitoring device with multistage transdermal drug delivery.xml
# Successfully converted: ../data/extractions/c139_Design of ultrathin Pt-Mo-Ni nanowire catalysts for ethanol electrooxidation.xml
# Successfully converted: ../data/extractions/c140_Knitting and weaving artificial muscles.xml
# Successfully converted: ../data/extractions/c141_Lead halide perovskites Crystal-liquid duality, phonon glass electron crystals, and large polaron f.xml
# Successfully converted: ../data/extractions/c142_The ground truth about metadata and community detection in networks.xml
# Successfully converted: ../data/extractions/c143_Next-generation probes, particles, and proteins for neural interfacing.xml
# Successfully converted: ../data/extractions/c144_Bend und touch - Locating a finger on an actively deformed transparent sensor array.xml
# Successfully converted: ../data/extractions/c145_Understanding charge transport in lead iodide perovskite thin-film field-effect transistors.xml
# Successfully converted: ../data/extractions/c146_Rainfall regimes of the Green Sahara.xml
# Successfully converted: ../data/extractions/c147_A highly stretchable, transparent, and conductive polymer.xml
# Successfully converted: ../data/extractions/c148_Discovery of Lorentz-violating type II Weyl fermions in LaAlGe.xml
# Successfully converted: ../data/extractions/c149_CRISPR-Cpf1 correction of muscular dystrophy mutations in human cardiomyocytes and mice.xml
# Successfully converted: ../data/extractions/c150_Origami by frontal photopolymerization.xml
# Successfully converted: ../data/extractions/c151_Dependence of drivers affects risks associated with compound events.xml
# Successfully converted: ../data/extractions/c152_Polymer-modified halide perovskite films for efficient and stable planar heterojunction solar cells.xml
# Successfully converted: ../data/extractions/c153_Timing and tempo of the Great Oxidation Event.xml
# Successfully converted: ../data/extractions/c154_Simplified and representative bacterial community of maize roots.xml
# Successfully converted: ../data/extractions/c155_Future urban land expansion and implications for global croplands.xml
# Successfully converted: ../data/extractions/c156_Three-dimensional stable lithium metal anode with nanoscale lithium islands embedded in ionically co.xml
# Successfully converted: ../data/extractions/c157_Bio-inspired self-healing structural color hydrogel.xml
# Successfully converted: ../data/extractions/c158_Salting our freshwater lakes.xml
# Successfully converted: ../data/extractions/c159_Phosphoproteins in extracellular vesicles as candidate markers for breast cancer.xml
# Successfully converted: ../data/extractions/c160_Knee osteoarthritis has doubled in prevalence since the mid-20th century.xml
# Successfully converted: ../data/extractions/c161_On-demand high-capacity ride-sharing via dynamic trip-vehicle assignment.xml
# Successfully converted: ../data/extractions/c162_Major transitions in dinoflagellate evolution unveiled by phylotranscriptomics.xml
# Successfully converted: ../data/extractions/c163_Manipulation of ionized impurity scattering for achieving high thermoelectric performance in n-type.xml
# Successfully converted: ../data/extractions/c164_Gut microbiota from multiple sclerosis patients enables spontaneous autoimmune encephalomyelitis in.xml
# Successfully converted: ../data/extractions/c165_Attenuated PfSPZ Vaccine induces strain-transcending T cells and durable protection against heterolo.xml
# Successfully converted: ../data/extractions/c166_Tunable moire bands and strong correlations in small-twist-angle bilayer graphene.xml
# Successfully converted: ../data/extractions/c167_Wettability effect on nanoconfined water flow.xml
# Successfully converted: ../data/extractions/c168_Spread of Zika virus in the Americas.xml
# Successfully converted: ../data/extractions/c169_Active MLKL triggers the NLRP3 inflammasome in a cell-intrinsic manner.xml
# Successfully converted: ../data/extractions/c170_Contemporary H3N2 influenza viruses have a glycosylation site that alters binding of antibodies elic.xml
# Successfully converted: ../data/extractions/c171_Entanglement and thermodynamics after a quantum quench in integrable systems.xml
# Successfully converted: ../data/extractions/c172_pathway regulates PD-L1 expression in tumor-associated macrophages and myeloid-derived suppressor ce.xml
# Successfully converted: ../data/extractions/c173_Stem cell migration and mechanotransduction on linear stiffness gradient hydrogels.xml
# Successfully converted: ../data/extractions/c174_Dual role of mitochondria in producing melatonin and driving GPCR signaling to block cytochrome c re.xml
# Successfully converted: ../data/extractions/c175_Fast oxygen diffusion and iodide defects mediate oxygen-induced degradation of perovskite solar cell.xml
# Successfully converted: ../data/extractions/c176_Muscle-specific CRISPRCas9 dystrophin gene editing ameliorates pathophysiology in a mouse model for.xml
# Successfully converted: ../data/extractions/c177_Single-cell RNA-seq enables comprehensive tumour and immune cell profiling in primary breast cancer.xml
# Successfully converted: ../data/extractions/c178_Broadband achromatic optical metasurface devices.xml
# Successfully converted: ../data/extractions/r001_A Fault Analysis Method for Three-Phase Induction Motors Based on Spiking Neural P Systems.xml
# Successfully converted: ../data/extractions/r002_Develop 24 dissimilar ANNs by suitable architectures & training algorithms via sensitivity analysis.xml
# Successfully converted: ../data/extractions/r003_Lipid Data Acquisition for devices Treatment of Coronary Diseases Health stuff on the Internet of Me.xml
# Successfully converted: ../data/extractions/r004_Effect of propofol on breast cancer cell, the immune system, and patient outcome.xml
# Successfully converted: ../data/extractions/r005_Analysis and research hotspots of ceramic materials in textile application.xml
# Successfully converted: ../data/extractions/r006_Knowledge map visualization of technology hotspots and development trends in China’s textile manufac.xml
# Successfully converted: ../data/extractions/r007_Is a negative correlation between sTNFR1 and TNF in patients with chronic Chagas disease the key to.xml
# Successfully converted: ../data/extractions/r008_A negative correlation between blood glucose level and 68Ga-DOTA-TOC uptake in the pancreas uncinate.xml
# Successfully converted: ../data/extractions/r009_Strong negative correlation between codon usage bias and protein structural disorder impedes protein.xml
# Successfully converted: ../data/extractions/r010_Negative correlation between neonatal and pediatric extracorporeal membrane oxygenation circuit chan.xml
# Successfully converted: ../data/extractions/r011_Target positioning based on particle centroid drift in large-scale WSNs.xml
# Successfully converted: ../data/extractions/r012_Noninvasive imaging technologies in the diagnosis of melanoma.xml
# Successfully converted: ../data/extractions/r013_IIBE An Improved Identity-Based Encryption Algorithm for Wsn Security.xml
# Successfully converted: ../data/extractions/r014_COVID-19 information exposure and vaccine hesitancy the influence of trust in government and vaccin.xml
# Successfully converted: ../data/extractions/r015_Potential energy as a new approach for detection and monitoring of fatigue damage in scarf adhesive.xml
# Successfully converted: ../data/extractions/r017_Security analysis on the decentralized energy trading system using blockchain technology.xml
# Successfully converted: ../data/extractions/r018_An empirical study of intelligent security analysis methods utilizing big data.xml
# Successfully converted: ../data/extractions/r019_Bi-level energy optimization model in smart integrated engineering systems using WSN.xml
# Successfully converted: ../data/extractions/r020_Ensemble unsupervised autoencoders and Gaussian mixture model for cyberattack detection.xml
# Successfully converted: ../data/extractions/r021_DeepCleave a deep learning predictor for caspase and matrix metalloprotease substrates and cleavage.xml
# Successfully converted: ../data/extractions/r022_Cost-effectiveness analysis of stereotactic ablative body radiation therapy compared with surgery an.xml
# Successfully converted: ../data/extractions/r023_Doppler audio signal analysis as an additional tool in Evaluation of umbilical artery circulation.xml
# Successfully converted: ../data/extractions/r024_The X-linked lymphoproliferative disease gene product SAP regulates signals induced through the co-r.xml
# Successfully converted: ../data/extractions/r025_Advanced technology of high-resolution radar target detection, tracking, imaging, and recognition.xml
# Successfully converted: ../data/extractions/r026_Visual sensor intelligent module based image transmission in industrial manufacturing for monitoring.xml
# Successfully converted: ../data/extractions/r027_Intelligent Secured Two-Way Image Transmission Using Corvus Corone Module over WSN.xml
# Successfully converted: ../data/extractions/r028_Manufacturing intelligent Corvus corone module for a secured two way image transmission under WSN.xml
# Successfully converted: ../data/extractions/r029_Trustworthiness in Industrial IoT Systems Based on Artificial Intelligence.xml
# Successfully converted: ../data/extractions/r030_A Novel PCA-Firefly Based XGBoost Classification Model for Intrusion Detection in Networks Using GPU.xml
# Successfully converted: ../data/extractions/r031_Evaluating and recognizing stressful periods and events of urban migrant children from microblog.xml
# Successfully converted: ../data/extractions/r032_A Face Emotion Recognition Method Using Convolutional Neural Network and Image Edge Computing.xml
# Successfully converted: ../data/extractions/r033_An IoT-Cloud Based Intelligent Computer-Aided Diagnosis of Diabetic Retinopathy Stage Classification.xml
# Successfully converted: ../data/extractions/r034_Local adjacent extrema pattern for fingerprint image classification.xml
# Successfully converted: ../data/extractions/r035_Dynamicity of the scout bee phase for an Artificial Bee Colony for optimized cluster head and networ.xml
# Successfully converted: ../data/extractions/r036_Urban water resource management for sustainable environment planning using artificial intelligence t.xml
# Successfully converted: ../data/extractions/r037_Quadratic transformation inequalities for Gaussian hypergeometric function.xml
# Successfully converted: ../data/extractions/r038_Monotonicity properties of a function involving the psi function with applications.xml
# Successfully converted: ../data/extractions/r039_Ensemble Data Reduction Techniques and Multi-RSMOTE via Fuzzy Integral for Bug Report Classification.xml
# Successfully converted: ../data/extractions/r040_Ionic liquids as an efficient medium for the mechanochemical synthesis of.xml
# Successfully converted: ../data/extractions/r041_An efficient mechanochemical synthesis of alpha-aluminum hydride Synergistic effect of TiF3 on the.xml
# Successfully converted: ../data/extractions/r042_Application of pattern recognition tools for classifying acute coronary syndrome an integrated medi.xml
# Successfully converted: ../data/extractions/r043_The prevalence of severe depression in Iranian older adult a meta-analysis and meta-regression.xml
# Successfully converted: ../data/extractions/r044_Empidine dance flies pollinate the woodland geranium as effectively as bees.xml
# Successfully converted: ../data/extractions/r045_Floral dimorphism, pollination, and self-fertilization in gynodioecious GERANIUM RICHARDSONII (Geran.xml
# Successfully converted: ../data/extractions/r046_Comprehensive landscape of epigenetic-dysregulated lncRNAs reveals a profound role of enhancers in c.xml
# Successfully converted: ../data/extractions/r047_UBQLN1 mediates sorafenib resistance through regulating mitochondrial biogenesis and ROS homeostasis.xml
# Successfully converted: ../data/extractions/r048_Locally Ordered Graphitized Carbon Cathodes for High-Capacity Dual-Ion Batteries.xml
# Successfully converted: ../data/extractions/r049_Recent Advances and Perspectives on the Polymer Electrolytes for SodiumPotassium-Ion Batteries.xml
# Successfully converted: ../data/extractions/r050_Morphometric and ISSR-Analysis of Local Populations of Geranium molle L. from the Southern Coast of.xml
# Successfully converted: ../data/extractions/r051_Metagenomic analysis of gut microbiota modulatory effects of jujube (Ziziphus jujuba Mill.) polysacc.xml
# Successfully converted: ../data/extractions/r052_Gene2vec gene subsequence embedding for prediction of mammalian N6-methyladenosine sites from mRNA.xml
# Successfully converted: ../data/extractions/r053_Population differentiation and gene flow in Rrodium cicutarium A potential medicinal plant.xml
# Successfully converted: ../data/extractions/r055_Enhancement of photocatalytic hydrogen production of BiFeO3 by Gd3+ doping.xml
# Successfully converted: ../data/extractions/r056_Ultrafast room-temperature synthesis of hierarchically porous metal–organic frameworks by a versatil.xml
# Successfully converted: ../data/extractions/r057_Research and Application of Acoustic Emission Signal Processing Technology.xml
# Successfully converted: ../data/extractions/r058_An effect of big data technology with ant colony optimization based routing in vehicular ad hoc netw.xml
# Successfully converted: ../data/extractions/r059_Pin Angle Thermal Effects on Friction Stir Welding of AA5058 Aluminum Alloy.xml
# Successfully converted: ../data/extractions/r060_Evaluating the stormwater management model to improve urban water allocation system in drought condi.xml
# Successfully converted: ../data/extractions/r061_Green synthesis and mechanism analysis of a new metal-organic framework constructed from Al (III) an.xml
# Successfully converted: ../data/extractions/r062_Numerical simulation of composition B high explosive charge desensitization in gap test assembly aft.xml
# Successfully converted: ../data/extractions/r063_A hybrid model based on rough sets theory and genetic algorithms for stock price forecasting.xml
# Successfully converted: ../data/extractions/r064_Extreme learning machine algorithm, theory and applications.xml
# Successfully converted: ../data/extractions/r065_A review on particle swarm optimization algorithm and its variants to clustering high-dimensional da.xml
# Successfully converted: ../data/extractions/r066_The evolution of cell formation problem methodologies based on recent studies (1997–2008.xml
# Successfully converted: ../data/extractions/r067_Optimizing top precision performance measure of content-based image retrieval by learning similarity.xml
# Successfully converted: ../data/extractions/r068_An Effective Image Representation Method Using Kernel Classification.xml
# Successfully converted: ../data/extractions/r069_Development of a pH indicator composed of high moisture-absorbing materials for real-time monitoring.xml
# Successfully converted: ../data/extractions/r070_Molecular bottlebrushes new opportunities in nanomaterials fabrication.xml
# Successfully converted: ../data/extractions/r071_Response to Comments on Assessing the Risk of Engineered Nanomaterials in the Environment Developm.xml
# Successfully converted: ../data/extractions/r072_Physical Activity and Health in Children Younger than 6 Years A.xml
# Successfully converted: ../data/extractions/r074_Quantum Ostrowski-type inequalities for twice quantum differentiable functions in quantum calculus.xml
# Successfully converted: ../data/extractions/r075_Monotonicity, convexity and bounds involving the beta and Ramanujan R-functions.xml
# Successfully converted: ../data/extractions/r076_Comprehensive evaluation of flat plate and parabolic dish solar collectors’ performance using differ.xml
# Successfully converted: ../data/extractions/r077_Choir versus Solo Singing Effects on Mood, and Salivary Oxytocin and Cortisol Concentrations.xml
# Successfully converted: ../data/extractions/r078_Gap junction gene and protein families Connexins, innexins, and pannexins.xml
# Successfully converted: ../data/extractions/r079_Blocking Connexin-43 mediated hemichannel activity protects against early tubular injury in experime.xml
# Successfully converted: ../data/extractions/r080_The connexin43 mimetic peptide Gap19 inhibits hemichannels without altering gap junctional communica.xml
# Successfully converted: ../data/extractions/r081_Local Injection of Bone Marrow Progenitor Cells for the Treatment of Anal Sphincter Injury.xml
# Successfully converted: ../data/extractions/r082_Treatment of Experimental Injury of Anal Sphincters with Primary Surgical Repair and Injection of Bo.xml
# Successfully converted: ../data/extractions/r083_Epidermal dendritic S100 positive cells in necrobiosis lipoidica and granuloma annulare.xml
# Successfully converted: ../data/extractions/r084_Scl 70 antibody–a specific marker of systemic sclerosis.xml
# Successfully converted: ../data/extractions/r085_The Biology of Skin Grafts.xml
# Successfully converted: ../data/extractions/r086_Location of the ostia of the renal arteries in the aorta.xml
# Successfully converted: ../data/extractions/r087_Systematic reviews on rehabilitation interventions.xml
# Successfully converted: ../data/extractions/r088_Fluid overpressure in layered intrusions formation of a breccia pipe in the Eastern Bushveld Comple.xml
# Successfully converted: ../data/extractions/r089_Eosinophils secrete IL-4 to facilitate liver regeneration.xml
# Successfully converted: ../data/extractions/r090_The NHGRI GWAS Catalog, a curated resource of SNP-trait associations.xml
# Successfully converted: ../data/extractions/r091_The role of retained austenite on tensile properties of steels with bainitic microstructures.xml
# Successfully converted: ../data/extractions/r092_The betaalpha peak height ratio of ATP. A measure of free [Mg2+] using 31P NMR.xml
# Successfully converted: ../data/extractions/r093_Environment and development. Earth system science for global sustainability grand challenges.xml
# Successfully converted: ../data/extractions/r094_Exploring the biophysical option space for feeding the world without deforestation.xml
# Successfully converted: ../data/extractions/r095_Plasmacytoid dendritic cells Recent progress and open questions.xml
# Successfully converted: ../data/extractions/r096_A census of human transcription factors Function, expression and evolution.xml
# Successfully converted: ../data/extractions/r097_Low loss photopatternable matrix materials for LWIR-metamaterial applications.xml
# Successfully converted: ../data/extractions/r098_Microbial life at −13 °C in the brine of an ice-sealed Antarctic lake.xml
# Successfully converted: ../data/extractions/r099_Controlling fast transport of cold trapped ions.xml
# Successfully converted: ../data/extractions/r100_Nanoparticle superlattice engineering with DNA.xml
# Successfully converted: ../data/extractions/r101_CTFFIND4 - Fast and accurate defocus estimation from electron micrographs.xml
# Successfully converted: ../data/extractions/r102_High juvenile mortality during migration in a declining population of a long-distance migratory rapt.xml
# Successfully converted: ../data/extractions/r103_A simple activity measurement of lysozyme.xml
# Successfully converted: ../data/extractions/r104_Megapixel digital PCR.xml
# Successfully converted: ../data/extractions/r105_In situ dynamic observations of perovskite crystallisation and microstructure evolution intermediate.xml
# Successfully converted: ../data/extractions/r106_Non-invasive intravital imaging of cellular differentiation with a bright red-excitable fluorescent.xml
# Successfully converted: ../data/extractions/r107_Carbon cycle feedbacks and future climate change.xml
# Successfully converted: ../data/extractions/r108_General treatment of the singularities in Hartree-Fock and exact-exchange Kohn-Sham methods for soli.xml
# Successfully converted: ../data/extractions/r109_The two faces of the FUSEWSTAF15 protein family.xml
# Successfully converted: ../data/extractions/r110_Thermal conductivity and specific heat of noncrystalline solids.xml
# Successfully converted: ../data/extractions/r111_A consistent and accurate ab initio parametrization of density functional dispersion correction (DFT.xml
# Successfully converted: ../data/extractions/r112_Intrinsically stretchable and healable semiconducting polymer for organic transistors.xml
# Successfully converted: ../data/extractions/r113_Securing natural capital and expanding equity to rescale civilization.xml
# Successfully converted: ../data/extractions/r114_Enhanced FIB-SEM systems for large-volume 3D imaging.xml
# Successfully converted: ../data/extractions/r115_p-T phase relations of CH3NH3PbX3 (X = Cl, Br, I) crystals.xml
# Successfully converted: ../data/extractions/r116_Imaging of spontaneous ventriculomegaly and vascular malformations in Wistar rats Implications for.xml
# Successfully converted: ../data/extractions/r117_Thermoelectric alloys between PbSe and PbS with effective thermal conductivity reduction and high fi.xml
# Successfully converted: ../data/extractions/r118_The correlation between surface chemistry, surface morphology, and cycling efficiency of lithium ele.xml
# Successfully converted: ../data/extractions/r119_Dendrite-free nanostructured anode Entrapment of lithium in a 3D fibrous matrix for ultra-stable li.xml
# Successfully converted: ../data/extractions/r120_Nano-optics from sensing to waveguiding.xml
# Successfully converted: ../data/extractions/r121_Yttrium hydride nanoantennas for active plasmonics.xml
# Successfully converted: ../data/extractions/r122_Solvent engineering for high-performance inorganic–organic hybrid perovskite solar cells.xml
# Successfully converted: ../data/extractions/r123_Features and development of Coot.xml
# Successfully converted: ../data/extractions/r124_Subfemtosecond pulses.xml
# Successfully converted: ../data/extractions/r125_A highly stable zeotype mesoporous zirconium metal-organic framework with ultralarge pores.xml
# Successfully converted: ../data/extractions/r126_Three dimensionals α-Fe2O3polypyrrole (ppy) nanoarray as anode for micro lithium ion batteries.xml
# Successfully converted: ../data/extractions/r127_Pd-Co3[Co(CN)6]2 hybrid nanoparticles preparation, characterization, and challenge for the Suzuki-M.xml
# Successfully converted: ../data/extractions/r128_Porous nanoMoC@graphite shell derived from a MOFs-directed strategy an efficient electrocatalyst fo.xml
# Successfully converted: ../data/extractions/r129_RET fusion gene translation to personalized lung cancer therapy.xml
# Successfully converted: ../data/extractions/r130_Ab initio molecular dynamics for liquid metals.xml
# Successfully converted: ../data/extractions/r131_MBE deserves a place in the history books.xml
# Successfully converted: ../data/extractions/r132_Facile synthesis for ordered mesoporous gamma-aluminas with high thermal stability.xml
# Successfully converted: ../data/extractions/r133_The 2008 revision of the World Health Organization (WHO) classification of myeloid neoplasms and acu.xml
# Successfully converted: ../data/extractions/r134_General linewidth formula for steady-state multimode lasing in arbitrary cavities.xml
# Successfully converted: ../data/extractions/r135_Full-length transcriptome assembly from RNA-Seq data without a reference genome.xml
# Successfully converted: ../data/extractions/r136_Resistance and resilience to coral bleaching implications for coral reef conservation and managemen.xml
# Successfully converted: ../data/extractions/r137_voom precision weights unlock linear model analysis tools for RNA-seq read counts.xml
# Successfully converted: ../data/extractions/r138_The genetic landscape of the childhood cancer medulloblastoma.xml
# Successfully converted: ../data/extractions/r139_Trimmomatic A flexible trimmer for Illumina sequence data.xml
# Successfully converted: ../data/extractions/r140_TCGA2STAT simple TCGA data access for integrated statistical analysis in R.xml
# Successfully converted: ../data/extractions/r141_Close-Packed Silicon Microelectrodes for Scalable Spatially Oversampled Neural Recording.xml
# Successfully converted: ../data/extractions/r142_The nucleosome remodeling and deacetylase complex NuRD is built from preformed catalytically active.xml
# Successfully converted: ../data/extractions/r143_A consistent metric for nestedness analysis in ecological systems reconciling concept and measureme.xml
# Successfully converted: ../data/extractions/r144_Single-cell gene expression analysis reveals genetic associations masked in whole-tissue experiments.xml
# Successfully converted: ../data/extractions/r145_Development, mobilisation and eruption of a large crystal-rich rhyolite The Ongatiti ignimbrite.xml
# Successfully converted: ../data/extractions/r146_Hybrid troctolites from mid-ocean ridges inherited mantle in the lower crust.xml
# Successfully converted: ../data/extractions/r147_New developments in palladium catalysed cross coupling The coupling of alkyl iodides with alkyl Gri.xml
# Successfully converted: ../data/extractions/r148_Anharmonic effects in atomic hydrogen Superconductivity and lattice dynamical stability.xml
# Successfully converted: ../data/extractions/r149_Conjugated organic framework with three-dimensionally ordered stable structure and delocalized π clo.xml
# Successfully converted: ../data/extractions/r150_A Star of David catenane.xml
# Successfully converted: ../data/extractions/r151_Reticular synthesis and the design of new materials.xml
# Successfully converted: ../data/extractions/r152_Overcoming intrinsic multidrug resistance in melanoma by blocking the mitochondrial respiratory chai.xml
# Successfully converted: ../data/extractions/r153_Impact of natural genetic variation on enhancer selection and function.xml
# Successfully converted: ../data/extractions/r154_Atomically resolved real-space imaging of hot electron dynamics.xml
# Successfully converted: ../data/extractions/r155_Experimental detection of a Majorana mode in the core of a magnetic vortex inside a topological insu.xml
# Successfully converted: ../data/extractions/r156_Radioactivity and thermalization in the ejecta of compact object mergers and their impact on kilonov.xml
# Successfully converted: ../data/extractions/r157_Operando synchrotron x-ray powder diffraction and modulated-excitation infrared spectroscopy elucida.xml
# Successfully converted: ../data/extractions/r158_Adsorption-driven heat pumps The potential of metal-organic frameworks.xml
# Successfully converted: ../data/extractions/r159_Energy-efficient dehumidification over hierachically porous metal-organic frameworks as advanced wat.xml
# Successfully converted: ../data/extractions/r160_Labelling and optical erasure of synaptic memory traces in the motor cortex.xml
# Successfully converted: ../data/extractions/r161_Mesoporous nitrogen-doped carbon for the electrocatalytic synthesis of hydrogen peroxide.xml
# Successfully converted: ../data/extractions/r162_The pore, not cytoplasmic domains, underlies inactivation in a prokaryotic sodium channel.xml
# Successfully converted: ../data/extractions/r163_efficient perovskite solar cell based on ZnO nanorods An effective charge collection system.xml
# Successfully converted: ../data/extractions/r164_Direct, nonoxidative conversion of methane to ethylene, aromatics, and hydrogen.xml
# Successfully converted: ../data/extractions/r165_The role of RhoA, RhoB and RhoC GTPases in cell morphology, proliferation and migration in human cyt.xml
# Successfully converted: ../data/extractions/r166_Experimental evidence that short-range intermolecular aggregation is sufficient for efficient charge.xml
# Successfully converted: ../data/extractions/r167_A single quantum cannot be cloned.xml
# Successfully converted: ../data/extractions/r168_Piezoresponse force microscopy A window into electromechanical behavior at the nanoscale.xml
# Successfully converted: ../data/extractions/r169_Diisopropylammonium bromide is a high-temperature molecular ferroelectric crystal.xml
# Successfully converted: ../data/extractions/r170_Organization of intracellular reactions with rationally designed RNA assemblies.xml
# Successfully converted: ../data/extractions/r171_Strong, tough, stretchable, and self-adhesive hydrogels from intrinsically unstructured proteins.xml
# Successfully converted: ../data/extractions/r172_Scalable manufacture of built-to-order nanomedicine Spray-assisted layer-by-layer functionalization.xml
# Successfully converted: ../data/extractions/r173_Lattice dynamics in mono- and few-layer sheets of WS2 and WSe2.xml
# Successfully converted: ../data/extractions/r174_Multiple scales of genetic connectivity in a brooding coral on isolated reefs following catastrophic.xml
# Successfully converted: ../data/extractions/r175_Nanoscale nickel oxidenickel heterostructures for active hydrogen evolution electrocatalysis.xml
# Successfully converted: ../data/extractions/r176_Possible artifacts of data biases in the recent global surface warming hiatus.xml
# Successfully converted: ../data/extractions/r177_Machine learning potentials for atomistic simulations.xml
# Successfully converted: ../data/extractions/r178_Synthesis of passive lossless metasurfaces using auxiliary fields for reflectionless beam splitting.xml
# Successfully converted: ../data/extractions/r179_A multi-taxa assessment of biodiversity change after single and recurrent wildfires in a Brazilian A.xml
# Successfully converted: ../data/extractions/r180_Lithium-coated polymeric matrix as a minimum volume-change and dendrite-free lithium metal anode.xml
# Successfully converted: ../data/extractions/r181_High rate and stable cycling of lithium metal anode.xml
# Successfully converted: ../data/extractions/r182_Reconstruction of paleo-redox conditions and early sulfur cycling during deposition of the Cryogenia.xml
# Successfully converted: ../data/extractions/r183_A history of Neoproterozoic glacial geology, 1871–1997.xml
# Successfully converted: ../data/extractions/r184_The turbulent circulation of a Snowball Earth ocean.xml
# Successfully converted: ../data/extractions/r185_Synthesis of monolithic graphene–graphite integrated electronics.xml
# Successfully converted: ../data/extractions/r186_Allosteric cooperativity in protein kinase A.xml
# Successfully converted: ../data/extractions/r187_Solid-state lighting An energy-economics perspective.xml
# Successfully converted: ../data/extractions/r188_VIIRS daynight band radiometric calibration stability monitoring using the Moon.xml
# Successfully converted: ../data/extractions/r189_Soft network composite materials with deterministic and bio-inspired designs.xml
# Successfully converted: ../data/extractions/r190_Symmetric growth of Pt ultrathin nanowires from dumbbell nuclei for use as oxygen reduction catalyst.xml
# Successfully converted: ../data/extractions/r191_Free-standing polypyrrole actuators with response rate of 10.8%.xml
# Successfully converted: ../data/extractions/r192_Ultralow thermal conductivity in all-inorganic halide perovskites.xml
# Successfully converted: ../data/extractions/r193_Inference and phase transitions in the detection of modules in sparse networks.xml
# Successfully converted: ../data/extractions/r194_Testing and modeling dependencies between a network and nodal attributes.xml
# Successfully converted: ../data/extractions/r195_Nanotechnology and neurophysiology.xml
# Successfully converted: ../data/extractions/r196_Highly stretchable, transparent ionic touch panel.xml
# Successfully converted: ../data/extractions/r197_Polarization and dielectric study of methylammonium lead iodide thin film to reveal its nonferroelec.xml
# Successfully converted: ../data/extractions/r198_Results of PMIP2 coupled simulations of the Mid-Holocene and Last Glacial Maximum–Part 1 Experiment.xml
# Successfully converted: ../data/extractions/r199_Universal Arrhenius temperature activated charge transport in diodes from disordered organic semicon.xml
# Successfully converted: ../data/extractions/r200_Phase transition between the quantum spin Hall and insulator phases in 3D Emergence of a topologica.xml
# Successfully converted: ../data/extractions/r201_Magnetic breakdown and Klein tunneling in a type-II Weyl semimetal.xml
# Successfully converted: ../data/extractions/r202_Correction of a genetic disease in mouse via use of CRISPR-Cas9.xml
# Successfully converted: ../data/extractions/r203_Stimuli responsive self-folding using thin polymer films.xml
# Successfully converted: ../data/extractions/r204_A review of recent advances in research on extreme heat events.xml
# Successfully converted: ../data/extractions/r205_Interface and composition analysis on perovskite solar cells.xml
# Successfully converted: ../data/extractions/r206_A Cryogenian chronology Two long-lasting synchronous Neoproterozoic glaciations.xml
# Successfully converted: ../data/extractions/r207_Uncultured bacterial diversity in tropical maize (Zea mays L.) rhizosphere.xml
# Successfully converted: ../data/extractions/r208_Artificial ecosystem selection.xml
# Successfully converted: ../data/extractions/r209_Biogeography of a human oral microbiome at the micron scale.xml
# Successfully converted: ../data/extractions/r210_How much land-based greenhouse gas mitigation can be achieved without compromising food security and.xml
# Successfully converted: ../data/extractions/r211_Farming the planet 1. Geographic distribution of global agricultural lands in the year.xml
# Successfully converted: ../data/extractions/r212_Surprised by supermarkets Diffusion of modern food retail in India.xml
# Successfully converted: ../data/extractions/r213_A comparative first-principles study of the structure, energetics, and properties of Li–M (M = Si.xml
# Successfully converted: ../data/extractions/r214_Magnetic assembly and field-tuning of ellipsoidal-nanoparticle-based colloidal photonic crystals.xml
# Successfully converted: ../data/extractions/r215_Great Lakes chloride trends Long-term mass balance and loading analysis.xml
# Successfully converted: ../data/extractions/r216_Global, in vivo, and site-specific phosphorylation dynamics in signaling networks.xml
# Successfully converted: ../data/extractions/r217_Inter-observer variation in coding osteoarthritis in human skeletal remains.xml
# Successfully converted: ../data/extractions/r218_A branch-and-cut algorithm for the dial-a-ride problem.xml
# Successfully converted: ../data/extractions/r219_A reconstruction of Archean biological diversity based on molecular fossils from the 2.78 to 2.45 bi.xml
# Successfully converted: ../data/extractions/r220_On intensifying carrier impurity scattering to enhance thermoelectric performance in Cr-doped CeyCo4.xml
# Successfully converted: ../data/extractions/r221_More realistic band gaps from meta-generalized gradient approximations Only in a generalized Kohn-S.xml
# Successfully converted: ../data/extractions/r222_IL-10 suppressor activity and ex vivo Tr1 cell function are impaired in multiple sclerosis.xml
# Successfully converted: ../data/extractions/r223_Type I interferons and microbial metabolites of tryptophan modulate astrocyte activity and central n.xml
# Successfully converted: ../data/extractions/r224_A T-cell response to a liver-stage Plasmodium antigen is not boosted by repeated sporozoite immuniza.xml
# Successfully converted: ../data/extractions/r225_Local spectroscopy of moire-induced electronic structure in gate-tunable twisted bilayer graphene.xml
# Successfully converted: ../data/extractions/r226_Water at hydrophobic surfaces Weak hydrogen bonding and strong orientation effects.xml
# Successfully converted: ../data/extractions/r227_2013 - Potential for Zika virus transmission through blood transfusion demonstrated during an outbreak in F.xml
# Successfully converted: ../data/extractions/r228_Caspase-11 cleaves gasdermin D for non-canonical inflammasome signalling.xml
# Successfully converted: ../data/extractions/r229_Necrostatin a potentially novel cardioprotective agent.xml
# Successfully converted: ../data/extractions/r230_Electron microscopy of influenza haemagglutinin-monoclonal antibody complexes.xml
# Successfully converted: ../data/extractions/r231_Alternatives to eigenstate thermalization.xml
# Successfully converted: ../data/extractions/r232_Enhancing the efficacy of cancer vaccines in urologic oncology new directions.xml
# Successfully converted: ../data/extractions/r233_Cell movement is guided by the rigidity of the substrate.xml
# Successfully converted: ../data/extractions/r234_Yap is a novel regulator of C2C12 myogenesis.xml
# Successfully converted: ../data/extractions/r235_Mdm1Snx13 is a novel ER-endolysosomal interorganelle tethering protein.xml
# Successfully converted: ../data/extractions/r236_Inhibition of interleukin 1beta converting enzyme family proteases reduces ischemic and excitotoxic.xml
# Successfully converted: ../data/extractions/r237_Conformational biosensors reveal GPCR signalling from endosomes.xml
# Successfully converted: ../data/extractions/r238_Monocyte chemoattractant protein-1 and the blood-brain barrier.xml
# Successfully converted: ../data/extractions/r239_Role of the crystallization substrate on the photoluminescence properties of organo-lead mixed halid.xml
# Successfully converted: ../data/extractions/r240_Deficiency of a glycoprotein component of the dystrophin complex in dystrophic muscle.xml
# Successfully converted: ../data/extractions/r241_Deagglomeration and functionalisation of detonation nanodiamond with long alkyl chains.xml
# Successfully converted: ../data/extractions/r242_The first five years of single-cell cancer genomics and beyond.xml
# Successfully converted: ../data/extractions/r243_Wave front engineering from an array of thin aperture antennas.xml
