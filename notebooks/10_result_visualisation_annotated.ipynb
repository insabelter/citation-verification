# %% [markdown]
# # Annotated Data - Result Visualisation

# %% [markdown]
# ## Dataset Structure Comparison before / after Re-Annotation

# %%
# %run ../scripts/load_df_for_analysis.py

# %%
# %run ../scripts/data_visualisations.py

# %%
import pandas as pd

# read the xlsx data into a pandas dataframe
df = pd.read_excel('../data/ReferenceErrorDetection_data_annotated.xlsx')
df = sort_df(df[df['Suited for Task'] != "Added"])
display(df.head())

df_prev = sort_df(pd.read_excel('../data/ReferenceErrorDetection_data.xlsx'))
display(df_prev.head())
# Out:
#     Source Citing Article ID         Citing Article DOI  \
# 0  PubPeer              c001  10.1016/j.est.2021.103553
# 1  PubPeer              c001  10.1016/j.est.2021.103553
# 2  PubPeer              c002       10.1155/2022/4601350
# 3  PubPeer              c003       10.1155/2022/2408685
# 4  PubPeer              c004       10.1155/2022/4783847
#
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain  \
# 0                       Yes  Engineering
# 1                       Yes  Engineering
# 2                       Yes    Chemistry
# 3                       Yes     Medicine
# 4                       Yes  Engineering
#
#                              Statement with Citation Corrected Statement  \
# 0  Others have aimed to reduce irreversibility or...                 NaN
# 1  Some researchers have also studied various hea...                 NaN
# 2  The relative content of total flavonoids in th...                 NaN
# 3  Research has shown that remimazolam tosylate e...                 NaN
# 4  if the efficiency of the routing algorithm is ...                 NaN
#
#   Citation Statement Section  ...  \
# 0                        NaN  ...
# 1                        NaN  ...
# 2                        NaN  ...
# 3                        NaN  ...
# 4                        NaN  ...
#
#                              Reference Article Title  \
# 0  A Fault Analysis Method for Three-Phase Induct...
# 1  Develop 24 dissimilar ANNs by suitable archite...
# 2  Lipid Data Acquisition for devices Treatment o...
# 3  Effect of propofol on breast cancer cell, the ...
# 4  Analysis and research hotspots of ceramic mate...
#
#                           Reference Article Abstract  \
# 0  The fault prediction and abductive fault diagn...
# 1  The artificial neural network optimization met...
# 2  Recently, the widespread deployment of smart p...
# 3  Breast cancer is the second leading cause of c...
# 4  From the perspective of scientometrics, comb t...
#
#   Reference Article PDF Available Reference Article Retracted  \
# 0                             Yes                          No
# 1                             Yes                          No
# 2                             Yes                          No
# 3                             Yes                          No
# 4                             Yes                          No
#
#   Reference Article Downloaded           Label Explanation Error Type  \
# 0                          Yes  Unsubstantiate  Irrelevant        NaN
# 1                          Yes  Unsubstantiate  Irrelevant        NaN
# 2                          Yes  Unsubstantiate  Irrelevant        NaN
# 3                          Yes  Unsubstantiate  Irrelevant        NaN
# 4                          Yes  Unsubstantiate  Irrelevant        NaN
#
#   Supporting Sentences Suited for Task
# 0                  NaN             NaN
# 1                  NaN             NaN
# 2                  NaN             NaN
# 3                  NaN             NaN
# 4                  NaN             NaN
#
# [5 rows x 24 columns]
#     Source Citing Article ID         Citing Article DOI  \
# 0  PubPeer              c001  10.1016/j.est.2021.103553
# 1  PubPeer              c001  10.1016/j.est.2021.103553
# 2  PubPeer              c002       10.1155/2022/4601350
# 3  PubPeer              c003       10.1155/2022/2408685
# 4  PubPeer              c004       10.1155/2022/4783847
#
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain  \
# 0                       Yes  Engineering
# 1                       Yes  Engineering
# 2                       Yes    Chemistry
# 3                       Yes     Medicine
# 4                       Yes  Engineering
#
#                              Statement with Citation Reference Article ID  \
# 0  Others have aimed to reduce irreversibility or...                 r001
# 1  Some researchers have also studied various hea...                 r002
# 2  The relative content of total flavonoids in th...                 r003
# 3  Research has shown that remimazolam tosylate e...                 r004
# 4  if the efficiency of the routing algorithm is ...                 r005
#
#              Reference Article DOI  \
# 0             10.1155/2021/2087027
# 1      10.1016/j.physa.2018.12.031
# 2  10.1088/1742-6596/1937/1/012038
# 3        10.1186/s12871-018-0543-3
# 4      10.36410/jcpr.2022.23.3.312
#
#                              Reference Article Title  \
# 0  A Fault Analysis Method for Three-Phase Induct...
# 1  Develop 24 dissimilar ANNs by suitable archite...
# 2  Lipid Data Acquisition for devices Treatment o...
# 3  Effect of propofol on breast cancer cell, the ...
# 4  Analysis and research hotspots of ceramic mate...
#
#                           Reference Article Abstract  \
# 0  The fault prediction and abductive fault diagn...
# 1  The artificial neural network optimization met...
# 2  Recently, the widespread deployment of smart p...
# 3  Breast cancer is the second leading cause of c...
# 4  From the perspective of scientometrics, comb t...
#
#   Reference Article PDF Available Reference Article Retracted  \
# 0                             Yes                          No
# 1                             Yes                          No
# 2                             Yes                          No
# 3                             Yes                          No
# 4                             Yes                          No
#
#   Reference Article Downloaded           Label Explanation
# 0                          Yes  Unsubstantiate  Irrelevant
# 1                          Yes  Unsubstantiate  Irrelevant
# 2                          Yes  Unsubstantiate  Irrelevant
# 3                          Yes  Unsubstantiate  Irrelevant
# 4                          Yes  Unsubstantiate  Irrelevant

# %%
df_annotated = df[df["Citation Function: Main"].notna()]
df_annotated
# Out:
#                         Source Citing Article ID  \
# 24                     PubPeer              c020
# 27                     PubPeer              c023
# 28                     PubPeer              c024
# 30                     PubPeer              c024
# 46                     PubPeer              c030
# 47                     PubPeer              c030
# 52                     PubPeer              c032
# 66                     PubPeer              c042
# 67                     PubPeer              c042
# 68                     PubPeer              c042
# 69                     PubPeer              c042
# 70                     PubPeer              c042
# 71                     PubPeer              c042
# 81                  Correction              c046
# 82                  Correction              c046
# 83                  Correction              c046
# 84                  Correction              c047
# 85                  Correction              c047
# 86                  Correction              c047
# 87             Lee & Lee, 1999              c048
# 88             Lee & Lee, 1999              c049
# 89         Fenton et al., 2000              c050
# 90          Lukic et al., 2004              c051
# 94   Smith & Cumberledge, 2020              c055
# 97   Smith & Cumberledge, 2020              c056
# 101  Smith & Cumberledge, 2020              c059
# 104  Smith & Cumberledge, 2020              c062
# 105  Smith & Cumberledge, 2020              c063
# 107  Smith & Cumberledge, 2020              c065
# 113  Smith & Cumberledge, 2020              c068
# 116  Smith & Cumberledge, 2020              c071
# 130  Smith & Cumberledge, 2020              c082
# 133  Smith & Cumberledge, 2020              c084
# 135  Smith & Cumberledge, 2020              c085
# 138  Smith & Cumberledge, 2020              c086
# 141  Smith & Cumberledge, 2020              c089
# 155  Smith & Cumberledge, 2020              c102
# 191  Smith & Cumberledge, 2020              c131
# 204  Smith & Cumberledge, 2020              c142
# 205  Smith & Cumberledge, 2020              c142
# 228  Smith & Cumberledge, 2020              c161
#
#                      Citing Article DOI  \
# 24                 10.1155/2022/1349935
# 27                 10.1155/2023/3320547
# 28           10.1007/s13204-021-02330-4
# 30           10.1007/s13204-021-02330-4
# 46                10.2298/gensr2201173y
# 47                10.2298/gensr2201173y
# 52                10.2298/gensr2103331l
# 66            10.1007/s10586-017-1334-1
# 67            10.1007/s10586-017-1334-1
# 68            10.1007/s10586-017-1334-1
# 69            10.1007/s10586-017-1334-1
# 70            10.1007/s10586-017-1334-1
# 71            10.1007/s10586-017-1334-1
# 81                  10.3390/jcdd8050052
# 82                  10.3390/jcdd8050052
# 83                  10.3390/jcdd8050052
# 84                10.3390/cells10082086
# 85                10.3390/cells10082086
# 86                10.3390/cells10082086
# 87   10.1111/j.1346-8138.1993.tb01394.x
# 88   10.1111/j.1346-8138.1993.tb01389.x
# 89           10.1177/000348949710600103
# 90            10.1007/s00276-001-0051-9
# 94              10.1126/science.aag3055
# 97              10.1126/science.aam7928
# 101             10.1126/science.aaf6846
# 104             10.1126/science.aag3009
# 105             10.1126/science.aaj2239
# 107              10.1126/sciadv.1600983
# 113              10.1126/sciadv.1701620
# 116              10.1126/sciadv.1501645
# 130             10.1073/pnas.1702429114
# 133                 10.1038/ncomms13828
# 135          10.1038/s41467-017-00519-2
# 138                 10.1038/ncomms14606
# 141          10.1038/s41467-017-00321-0
# 155                 10.1038/nature22973
# 191              10.1126/sciadv.1603015
# 204              10.1126/sciadv.1602548
# 205              10.1126/sciadv.1602548
# 228             10.1073/pnas.1611675114
#
#                                   Citing Article Title  \
# 24   Music Timbre Extracted from Audio Signal Features
# 27   Optimization Algorithm of Moving Object Detect...
# 28   Hybrid deep learning model for automatic fake ...
# 30   Hybrid deep learning model for automatic fake ...
# 46   Evaluation of genetic variability Rindera usin...
# 47   Evaluation of genetic variability Rindera usin...
# 52   Genetic diversity and gene-pool of Aegilops ta...
# 66   Pattern mining model based on improved neural ...
# 67   Pattern mining model based on improved neural ...
# 68   Pattern mining model based on improved neural ...
# 69   Pattern mining model based on improved neural ...
# 70   Pattern mining model based on improved neural ...
# 71   Pattern mining model based on improved neural ...
# 81   Peptidic Connexin43 Therapeutics in Cardiac Re...
# 82   Peptidic Connexin43 Therapeutics in Cardiac Re...
# 83   Peptidic Connexin43 Therapeutics in Cardiac Re...
# 84   Cell Therapy for Anal Sphincter Incontinence: ...
# 85   Cell Therapy for Anal Sphincter Incontinence: ...
# 86   Cell Therapy for Anal Sphincter Incontinence: ...
# 87   Association of Generalized granuloma annulare ...
# 88                       Autoantibodies in scleroderma
# 89   Treatment of chronic postoperative otorrhea wi...
# 90   Origin and initial course of the renal arterie...
# 94   Vertically extensive and unstable magmatic sys...
# 97   Inflammation and metabolism in tissue repair a...
# 101                     ATP as a biological hydrotrope
# 104  Mapping the human DC lineage through the integ...
# 105  Impact of cytosine methylation on DNA binding ...
# 107  Snowball Earth climate dynamics and Cryogenian...
# 113         Disabling Cas9 by an anti-CRISPR DNA mimic
# 116  Self-powered integrated microfluidic point-of-...
# 130           Tetragonal CH3NH3PbI3 is ferroelectric\t
# 133  Vacancy-induced dislocations within grains for...
# 135  Nanodiamonds suppress the growth of lithium de...
# 138                   Dynamic plasmonic colour display
# 141  53-attosecond X-ray pulses reach the carbon K-...
# 155  The whole-genome landscape of medulloblastoma ...
# 191  Machine learning of accurate energy-conserving...
# 204  The ground truth about metadata and community ...
# 205  The ground truth about metadata and community ...
# 228  On-demand high-capacity ride-sharing via dynam...
#
#     Citing Article Retracted Citing Article Downloaded            Domain  \
# 24                       Yes                       Yes  Computer Science
# 27                       Yes                       Yes  Computer Science
# 28                       Yes                       Yes  Computer Science
# 30                       Yes                       Yes  Computer Science
# 46                       Yes                       Yes           Biology
# 47                       Yes                       Yes           Biology
# 52                       Yes                       Yes           Biology
# 66                       Yes                       Yes  Computer Science
# 67                       Yes                       Yes  Computer Science
# 68                       Yes                       Yes  Computer Science
# 69                       Yes                       Yes  Computer Science
# 70                       Yes                       Yes  Computer Science
# 71                       Yes                       Yes  Computer Science
# 81                        No                       Yes          Medicine
# 82                        No                       Yes          Medicine
# 83                        No                       Yes          Medicine
# 84                        No                       Yes          Medicine
# 85                        No                       Yes          Medicine
# 86                        No                       Yes          Medicine
# 87                        No                       Yes           Biology
# 88                        No                       Yes           Biology
# 89                        No                       Yes          Medicine
# 90                        No                       Yes          Medicine
# 94                        No                       Yes           Geology
# 97                        No                       Yes           Biology
# 101                       No                       Yes           Biology
# 104                       No                       Yes           Biology
# 105                       No                       Yes           Biology
# 107                       No                       Yes       Environment
# 113                       No                       Yes           Biology
# 116                       No                       Yes           Biology
# 130                       No                       Yes         Chemistry
# 133                       No                       Yes         Chemistry
# 135                       No                       Yes         Chemistry
# 138                       No                       Yes         Chemistry
# 141                       No                       Yes           Physics
# 155                       No                       Yes          Medicine
# 191                       No                       Yes  Computer Science
# 204                       No                       Yes  Computer Science
# 205                       No                       Yes  Computer Science
# 228                       No                       Yes  Computer Science
#
#                                Statement with Citation  \
# 24   Sound perception refers to the internal proces...
# 27   Long et al. put forward DenseNet classificatio...
# 28   Before starting any of the pre-processing heav...
# 30   Before starting any of the pre-processing heav...
# 46   Bees, flies, and honeybees [citation] pollinat...
# 47   Shared alleles are related to self-pollination...
# 52   Randomly amplified polymorphic DNA (RAPD), amp...
# 66   In the most recent two decades, a few quantita...
# 67   The individual finance score models are create...
# 68   The individual finance score models are create...
# 69   The advantages of individual finance score inc...
# 70   To effectively assemble individual finance sco...
# 71   Other than the framework algorithm, other stre...
# 81   A review characterizing the possible mechanism...
# 82   Other investigations of Peptide5 in preclinica...
# 83   Other investigations of Peptide5 in preclinica...
# 84   Most often, an anal sphincter tear is usually ...
# 85   The classical clinical situation of acute anal...
# 86   In the case of extending traumatism to the lev...
# 87   T-cell subpopulations in granuloma annulare we...
# 88   In early studies, anti-Scl-70 was identified i...
# 89   Indeed, numerous growth factors and cytokines ...
# 90   The relative topography of the origins of the ...
# 94   At very high crystallinities (very low melt pe...
# 97   For example, a recent study exploring the mech...
# 101  We reconstituted FUS compartments in vitro at ...
# 104  Pitt-Hopkins syndrome (PHS) is characterized b...
# 105  This collection included 84% of the high-confi...
# 107  In the MDV, 1000 km to the north and 1.8 km lo...
# 113  Initial particle picking to generate template ...
# 116  We used new nucleic acid amplification technol...
# 130  To check whether other tetragonal MAPbX3 compo...
# 133  other parameters including Gruneisen parameter...
# 135  Li columns with a small average diameter (0.3 ...
# 138  Different from other hydrogen-storage metals s...
# 141  Prior to this study, isolated attosecond pulse...
# 155  Consistent with our previous studies [citation...
# 191  We resorted to the extensive body of research ...
# 204  Because metadata always have an uncertain rela...
# 205  This correspondence has been used productively...
# 228  Traditional approaches that rely on an integer...
#
#                                    Corrected Statement  \
# 24                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 30                                                 NaN
# 46                                                 NaN
# 47                                                 NaN
# 52                                                 NaN
# 66                                                 NaN
# 67                                                 NaN
# 68                                                 NaN
# 69                                                 NaN
# 70                                                 NaN
# 71                                                 NaN
# 81                                                 NaN
# 82   Other investigations of Peptide5 in preclinica...
# 83   Other investigations of Peptide5 in preclinica...
# 84                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 87   …, and the number of S100 positive dendritic c...
# 88   In early studies, anti-Scl-70 was ..., but, wi...
# 89                                                 NaN
# 90                                                 NaN
# 94                                                 NaN
# 97                                                 NaN
# 101  We reconstituted FUS compartments in vitro at ...
# 104  ..., which encodes the E2-2 transcription fact...
# 105  This collection included 84% of the high-confi...
# 107  In the MDV (Antarctic McMurdo Dry Valleys), 10...
# 113                                                NaN
# 116  We used new nucleic acid amplification technol...
# 130  ..., we measured tetragonal MAPbBr3 (well belo...
# 133  …, other parameters including ... and Poisson ...
# 135                                                NaN
# 138  Different from other hydrogen-storage metals s...
# 141  Prior to this study, isolated attosecond pulse...
# 155                                                NaN
# 191                                                NaN
# 204  … or a network that is sufficiently sparse tha...
# 205  This correspondence has been used productively...
# 228                                                NaN
#
#     Citation Statement Section  ...  \
# 24                  Background  ...
# 27                Related Work  ...
# 28                     Methods  ...
# 30                     Methods  ...
# 46                  Discussion  ...
# 47                  Discussion  ...
# 52                  Discussion  ...
# 66                Introduction  ...
# 67                Introduction  ...
# 68                Introduction  ...
# 69                Introduction  ...
# 70                Related Work  ...
# 71                Related Work  ...
# 81                Related Work  ...
# 82                Related Work  ...
# 83                Related Work  ...
# 84                  Background  ...
# 85                  Background  ...
# 86                  Background  ...
# 87                  Discussion  ...
# 88                Related Work  ...
# 89                  Discussion  ...
# 90                  Discussion  ...
# 94                  Background  ...
# 97                Related Work  ...
# 101                    Methods  ...
# 104                 Background  ...
# 105                    Methods  ...
# 107                 Background  ...
# 113                    Methods  ...
# 116               Introduction  ...
# 130                    Results  ...
# 133                    Results  ...
# 135                    Results  ...
# 138                 Background  ...
# 141                 Background  ...
# 155                    Results  ...
# 191                    Methods  ...
# 204                    Results  ...
# 205                    Results  ...
# 228               Introduction  ...
#
#                                Reference Article Title  \
# 24   Doppler audio signal analysis as an additional...
# 27   Advanced technology of high-resolution radar: ...
# 28   Visual sensor intelligent module based image t...
# 30   Manufacturing intelligent Corvus corone module...
# 46   Empidine dance flies pollinate the woodland ge...
# 47   Floral dimorphism, pollination, and self-ferti...
# 52   Morphometric and ISSR-Analysis of Local Popula...
# 66   A hybrid model based on rough sets theory and ...
# 67   Extreme learning machine: algorithm, theory an...
# 68   A review on particle swarm optimization algori...
# 69   The evolution of cell formation problem method...
# 70   Optimizing top precision performance measure o...
# 71   An Effective Image Representation Method Using...
# 81   Gap junction gene and protein families: Connex...
# 82   Blocking Connexin-43 mediated hemichannel acti...
# 83   The connexin43 mimetic peptide Gap19 inhibits ...
# 84   Local Injection of Bone Marrow Progenitor Cell...
# 85   Local Injection of Bone Marrow Progenitor Cell...
# 86   Treatment of Experimental Injury of Anal Sphin...
# 87   Epidermal dendritic S100 positive cells in nec...
# 88   Scl 70 antibody--a specific marker of systemic...
# 89                          The Biology of Skin Grafts
# 90   Location of the ostia of the renal arteries in...
# 94   Fluid overpressure in layered intrusions: form...
# 97   Eosinophils secrete IL-4 to facilitate liver r...
# 101  The beta/alpha peak height ratio of ATP. A mea...
# 104  Plasmacytoid dendritic cells: Recent progress ...
# 105  A census of human transcription factors: Funct...
# 107  Microbial life at −13 °C in the brine of an ic...
# 113  CTFFIND4: Fast and accurate defocus estimation...
# 116                              Megapixel digital PCR
# 130  p-T phase relations of CH3NH3PbX3 (X = Cl, Br,...
# 133  Thermoelectric alloys between PbSe and PbS wit...
# 135  Dendrite-free nanostructured anode: Entrapment...
# 138  Yttrium hydride nanoantennas for active plasmo...
# 141                              Subfemtosecond pulses
# 155  The genetic landscape of the childhood cancer ...
# 191  Machine learning potentials for atomistic simu...
# 204  Inference and phase transitions in the detecti...
# 205  Testing and modeling dependencies between a ne...
# 228  A branch-and-cut algorithm for the dial-a-ride...
#
#                             Reference Article Abstract  \
# 24   Purpose To investigate the predictive capacity...
# 27   In recent years, the performances of radar res...
# 28   Due to technology advancement, smart visual se...
# 30   Purpose\nThe manufacturing of intelligent and ...
# 46   Most flowering plants species rely on insects ...
# 47   The selective maintenance of gynodioecy depend...
# 52   Geranium molle is known as Dovefoot Geranium o...
# 66   In the stock market, technical analysis is a u...
# 67   Extreme learning machine (ELM) is a new learni...
# 68   Data clustering is one of the most popular tec...
# 69   This paper presents a literature review of the...
# 70   In this paper we study the problem of content-...
# 71   The learning of image representation is always...
# 81   Gap junction channels facilitate the intercell...
# 82   Background: Tubulointerstitial fibrosis repres...
# 83   In the brain, astrocytes represent the cellula...
# 84   Background\nAnal incontinence is a disabling c...
# 85   Background\nAnal incontinence is a disabling c...
# 86   Purpose: Sphincter injury is a common cause of...
# 87   Using an antibody to S100 protein, the number ...
# 88   Scl 70 antibodies were tested for in 107 patie...
# 89   Background: Skin grafting is commonly used to ...
# 90   A total of 30 adult abdominal aorta specimens ...
# 94   Fluids and volatile fluid overpressures in lay...
# 97   The liver is a central organ for the synthesis...
# 101  From 31P NMR measurements made in vitro at 38 ...
# 104  Plasmacytoid dendritic cells (pDCs) are specia...
# 105  Transcription factors are key cellular compone...
# 107  The permanent ice cover of Lake Vida (Antarcti...
# 113  CTFFIND is a widely-used program for the estim...
# 116  We present a microfluidic 'megapixel' digital ...
# 130  Pressure-temperature phase relations of CH3NH3...
# 133  The n-type alloys between PbSe and PbS are stu...
# 135  Entrapment of free lithium in a 3D fibrous Li7...
# 138  A key challenge for the development of active ...
# 141  High-harmonic emission is very sensitive to th...
# 155  Medulloblastoma (MB) is the most common malign...
# 191  Nowadays, computer simulations have become a s...
# 204  We present an asymptotically exact analysis of...
# 205  Network analysis is often focused on character...
# 228  In the dial-a-ride problem, users formulate re...
#
#     Reference Article PDF Available Reference Article Retracted  \
# 24                              Yes                          No
# 27                              Yes                          No
# 28                              Yes                         Yes
# 30                              Yes                          No
# 46                              Yes                          No
# 47                              Yes                          No
# 52                              Yes                          No
# 66                              Yes                          No
# 67                              Yes                          No
# 68                              Yes                          No
# 69                              Yes                          No
# 70                              Yes                          No
# 71                              Yes                          No
# 81                              Yes                          No
# 82                              Yes                          No
# 83                              Yes                          No
# 84                              Yes                          No
# 85                              Yes                          No
# 86                              Yes                          No
# 87                              Yes                          No
# 88                              Yes                          No
# 89                              Yes                          No
# 90                              Yes                          No
# 94                              Yes                          No
# 97                              Yes                          No
# 101                             Yes                          No
# 104                             Yes                          No
# 105                             Yes                          No
# 107                             Yes                          No
# 113                             Yes                          No
# 116                             Yes                          No
# 130                             Yes                          No
# 133                             Yes                          No
# 135                             Yes                          No
# 138                             Yes                          No
# 141                             Yes                          No
# 155                             Yes                          No
# 191                             Yes                          No
# 204                             Yes                          No
# 205                             Yes                          No
# 228                             Yes                          No
#
#     Reference Article Downloaded               Label  \
# 24                           Yes      Unsubstantiate
# 27                           Yes      Unsubstantiate
# 28                           Yes      Unsubstantiate
# 30                           Yes      Unsubstantiate
# 46                           Yes      Unsubstantiate
# 47                           Yes      Unsubstantiate
# 52                           Yes      Unsubstantiate
# 66                           Yes      Unsubstantiate
# 67                           Yes      Unsubstantiate
# 68                           Yes      Unsubstantiate
# 69                           Yes      Unsubstantiate
# 70                           Yes      Unsubstantiate
# 71                           Yes      Unsubstantiate
# 81                           Yes      Unsubstantiate
# 82                           Yes      Unsubstantiate
# 83                           Yes      Unsubstantiate
# 84                           Yes      Unsubstantiate
# 85                           Yes      Unsubstantiate
# 86                           Yes      Unsubstantiate
# 87                           Yes      Unsubstantiate
# 88                           Yes      Unsubstantiate
# 89                           Yes      Unsubstantiate
# 90                           Yes      Unsubstantiate
# 94                           Yes  Fully substantiate
# 97                           Yes      Unsubstantiate
# 101                          Yes  Fully substantiate
# 104                          Yes  Fully substantiate
# 105                          Yes  Fully substantiate
# 107                          Yes      Unsubstantiate
# 113                          Yes      Unsubstantiate
# 116                          Yes  Fully substantiate
# 130                          Yes      Unsubstantiate
# 133                          Yes      Unsubstantiate
# 135                          Yes  Fully substantiate
# 138                          Yes      Unsubstantiate
# 141                          Yes      Unsubstantiate
# 155                          Yes  Fully substantiate
# 191                          Yes  Fully substantiate
# 204                          Yes  Fully substantiate
# 205                          Yes  Fully substantiate
# 228                          Yes  Fully substantiate
#
#                                            Explanation  \
# 24                                          Irrelevant
# 27                                          Irrelevant
# 28                                          Irrelevant
# 30                                          Irrelevant
# 46                             Different plant species
# 47                             Different plant species
# 52     Different plant species + no mentioning of IRAP
# 66                                          Irrelevant
# 67                                          Irrelevant
# 68                                          Irrelevant
# 69                                          Irrelevant
# 70                                          Irrelevant
# 71                                          Irrelevant
# 81                                     Wrong reference
# 82                                     Wrong reference
# 83                                     Wrong reference
# 84                                     Wrong reference
# 85                                     Wrong reference
# 86                                     Wrong reference
# 87               Over-generalization to another tissue
# 88                         Wrong number (75% vs. 77%).
# 89                                   Indirect evidence
# 90                         Wrong number (65% vs. 53%).
# 94                                    Lost a condition
# 97                             Required vs. facilitate
# 101                                             Method
# 104                                                NaN
# 105                                                NaN
# 107      No mention of cyanobacteria or photosynthesis
# 113  Method - Reference is about different program ...
# 116                                             Method
# 130         Wrong number and no mentioning of pressure
# 133  The cited article gives an equation while the ...
# 135                                                NaN
# 138     No mention of poor optical response of Yttrium
# 141   few-cycle near-infrared (NIR) Ti:Sapphire las...
# 155                                                NaN
# 191                                                NaN
# 204                                                NaN
# 205                                                NaN
# 228                                                NaN
#
#                          Error Type  \
# 24                   1 - Irrelevant
# 27                   1 - Irrelevant
# 28                   1 - Irrelevant
# 30                   1 - Irrelevant
# 46                   1 - Irrelevant
# 47                   1 - Irrelevant
# 52   3.2 - Misunderstanding-partsup
# 66                   1 - Irrelevant
# 67                   1 - Irrelevant
# 68                   1 - Irrelevant
# 69                   1 - Irrelevant
# 70                   1 - Irrelevant
# 71                   1 - Irrelevant
# 81                     4 - Unwanted
# 82                     4 - Unwanted
# 83                     4 - Unwanted
# 84                     4 - Unwanted
# 85                     4 - Unwanted
# 86                     4 - Unwanted
# 87   3.2 - Misunderstanding-partsup
# 88             2 - Copy-Paste-Error
# 89                     4 - Unwanted
# 90             2 - Copy-Paste-Error
# 94                              NaN
# 97   3.2 - Misunderstanding-partsup
# 101                             NaN
# 104                             NaN
# 105                             NaN
# 107  3.2 - Misunderstanding-partsup
# 113                  1 - Irrelevant
# 116                             NaN
# 130            2 - Copy-Paste-Error
# 133  3.2 - Misunderstanding-partsup
# 135                             NaN
# 138    3.1 - Misunderstanding-nosup
# 141                  1 - Irrelevant
# 155                             NaN
# 191                             NaN
# 204                             NaN
# 205                             NaN
# 228                             NaN
#
#                                   Supporting Sentences  \
# 24                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 30                                                 NaN
# 46                                                 NaN
# 47                                                 NaN
# 52                                                 NaN
# 66                                                 NaN
# 67                                                 NaN
# 68                                                 NaN
# 69                                                 NaN
# 70                                                 NaN
# 71                                                 NaN
# 81                                                 NaN
# 82                                                 NaN
# 83                                                 NaN
# 84                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 94   ["Because the Lower and Critical zones are cha...
# 97   ["Liver injury\nresults in rapid recruitment o...
# 101                                                NaN
# 104  ["However, E2–2 likely represents only one of ...
# 105                                                NaN
# 107                                                NaN
# 113                                                NaN
# 116  ["We report a microfluidic ‘megapixel’ digital...
# 130                                                NaN
# 133                                                NaN
# 135  ["Thus, the nanostructured LiB alloy\nanode no...
# 138                                                NaN
# 141                                                NaN
# 155  ["Most notably, inactivating\nmutations of the...
# 191  ["In contrast to the classification and patter...
# 204  ["In this Letter we analyze a random generativ...
# 205  ["We introduce a novel testing procedure to de...
# 228  ["In the Dial-a-Ride Problem (DARP), users for...
#
#               Suited for Task
# 24                        Yes
# 27                        Yes
# 28                        Yes
# 30                        Yes
# 46                        Yes
# 47                        Yes
# 52                        Yes
# 66                        Yes
# 67                        Yes
# 68                        Yes
# 69                        Yes
# 70                        Yes
# 71                        Yes
# 81                        Yes
# 82                        Yes
# 83                        Yes
# 84                        Yes
# 85                        Yes
# 86                        Yes
# 87                        Yes
# 88                        Yes
# 89                         No
# 90                        Yes
# 94   Not enough understanding
# 97                        Yes
# 101  Not enough understanding
# 104  Not enough understanding
# 105                        No
# 107                       Yes
# 113                       Yes
# 116                       Yes
# 130                       Yes
# 133                       Yes
# 135                       Yes
# 138  Not enough understanding
# 141  Not enough understanding
# 155                       Yes
# 191                       Yes
# 204                       Yes
# 205                       Yes
# 228                       Yes
#
# [41 rows x 24 columns]

# %%
print(f"Number Rows Original Data: {len(df_prev)}")
print(f"Number Rows All Data (including Re-Annotated): {len(df)}")
print(f"Number Rows Annotated Data: {len(df_annotated)}")
# Out:
# Number Rows Original Data: 250
# Number Rows All Data (including Re-Annotated): 250
# Number Rows Annotated Data: 41

# %% [markdown]
# ### Label Distribution - Before vs. After Re-Annotation

# %%
show_distribution_comparison(df_prev, df, "Label", "Original Data", "All Data (including Re-Annotated)")

# %% [markdown]
# ### Domain Distribution - All Data vs. Re-Annotated Data

# %%
show_distribution_comparison(df_prev, df_annotated, "Domain", "Original Data", "Re-Annotated Data")

# %%
show_distribution_comparison_pie(df_prev, df_annotated, "Domain", "Original Data", "Re-Annotated Data")

# %% [markdown]
# The relative amount of entries belonging to the Computer Science Domain is much higher in the re-annotated dataset, because I have the most knowledge in Computer Science out of all of these Domains, so it is the easiest for me to classify and presumably with the hightest annotation accuracy.

# %% [markdown]
# ## Dataset Structure Re-Annotated Data

# %% [markdown]
# ### Distribution of Citation Statement Section

# %%
show_distribution_pie(df_annotated, "Citation Statement Section")

# %% [markdown]
# ### Distribution of Citation Functions

# %% [markdown]
# | **Main Category** | **Sub Category**            | **Explanation**                                                                                     |
# |--------------------|-----------------------------|-----------------------------------------------------------------------------------------------------|
# | Use               | Apply                       | The methods/algorithms/tools/data are directly applied and not modified.                           |
# |                   | Extend                      | The methods/algorithms/tools are modified before/while applying them, meaning the reference work is only used as a basis to build upon. |
# | Compare           | Criticize                   | Negative comparison: Reference is criticized, weaknesses are pointed out, errors are identified, citing author does not agree with reference. |
# |                   | Contrast                    | Neutral comparison: Comparison without clear positive or negative sentiment of the citing author in relation to the reference(s). |
# |                   | Confirm                     | Positive comparison: Reference results are supported by the author or can be confirmed/validated by the citing work’s results. |
# | Related           | Definition/Proof            | Definitions are directly taken from the reference, or result data is directly taken from the reference – or they are referenced to provide proof for a claim. |
# |                   | Fundamentals                | The reference provides fundamental knowledge to understand the citing author’s work.               |
# |                   | Acknowledge                 | The reference is related to the citing author’s work but not needed to understand it. This includes examples or mentioning pioneers. |
# | Background        | Introduction/Bigger picture | The reference is cited to give an introduction to the topic or to locate the citing author’s work within the broader landscape of the field, even though the reference topic is not directly related to the citing paper. |
# |                   | Unrelated/Unclear           | The reference topic is unrelated to the citing paper or it is unclear which category else to pick because there is not enough context given. |

# %%
import matplotlib.pyplot as plt

citation_functions = {
"Use": ["Apply", "Extend"],
"Compare": ["Criticize", "Contrast", "Confirm"],
"Related": ["Definition/Proof", "Fundamentals", "Acknowledge"],
"Background": ["Introduction/Bigger picture", "Unrelated/Unclear"]
}

# Define colors for each main category
main_category_colors = {
    "Related": "#1f77b4",  # Blue
    "Use": "#ff7f0e",  # Orange
    "Background": "#2ca02c",  # Green
    "Compare": "#d62728"  # Red
}

# Generate sub-category colors based on main category colors
sub_function_colors = {}
for main_category, sub_categories in citation_functions.items():
    base_color = main_category_colors[main_category]
    for i, sub_category in enumerate(sub_categories):
        # Adjust lightness for sub-categories
        lightness_factor = 1 - (i * 0.2)
        rgba = plt.cm.colors.to_rgba(base_color)
        adjusted_rgba = tuple(channel * lightness_factor if index < 3 else channel for index, channel in enumerate(rgba))
        sub_function_colors[sub_category] = plt.cm.colors.to_hex(adjusted_rgba)

print(sub_function_colors)
# Out:
# {'Apply': '#ff7f0e', 'Extend': '#cc660b', 'Criticize': '#d62728', 'Contrast': '#ab1f20', 'Confirm': '#801718', 'Definition/Proof': '#1f77b4', 'Fundamentals': '#195f90', 'Acknowledge': '#13476c', 'Introduction/Bigger picture': '#2ca02c', 'Unrelated/Unclear': '#238023'}

# %%
def get_color(sub_function):
    if sub_function in sub_function_colors:
        return sub_function_colors[sub_function]
    else:
        print(f"Warning: {sub_function} not found in sub_function_colors.")
        return "#000000"  # Default color (black) for unknown categories

# %%
# Count the occurrences of each source, including NaN values if specified
source_counts = df_annotated["Citation Function: Sub"].value_counts(dropna=False)

# Fill NaN values in the index with 'NaN'
source_counts.index = source_counts.index.fillna('NaN')

# Map the colors to the sub-functions
colors = [get_color(sub_function.strip()) for sub_function in source_counts.index]

# Plot the pie chart with defined colors
plt.figure(figsize=(8, 8))
plt.pie(source_counts, labels=source_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Distribution of column: ' + "Citation Function: Sub")
plt.show()

# %%
show_distribution_pie(df_annotated, "Citation Function: Main")

# %% [markdown]
# ## Re-Annotated Data Classification Results

# %%
# %run ../scripts/load_df_for_analysis.py
