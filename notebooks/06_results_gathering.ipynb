# %% [markdown]
# # Result Analysis

# %%
models = ["gpt-3.5-turbo-0125", "gpt-4.1-nano-2025-04-14", "gpt-4.1-mini-2025-04-14", "gpt-4.1-2025-04-14", "llama3.1.70b", "llama4.scout"]
chunkings = ["256_20", "1024_20"]
only_texts = [False, True]

# %%
# %run ../scripts/load_df_for_analysis.py

# %%
# %run ../scripts/df_calculations.py

# %% [markdown]
# ## Gather Results: Model Comparison

# %%
all_results = {}

# %%
def gather_results(chunking, only_text, model, ai_prompt=False):
    global all_results

    df = load_df_for_analysis(chunking, only_text, model, ai_prompt)
    
    results = eval_predictions(df, include_relabelled_partially=True)
    results_without_relabelled = eval_predictions(df, include_relabelled_partially=False)

    if model not in all_results:
        all_results[model] = {}
    all_results[model][f"{'only_text_' if only_text else ''}{chunking}{'_AI_prompt' if ai_prompt else ''}"] = {
        "all": results,
        "without_relabelled": results_without_relabelled,
    }

# %% [markdown]
# ### Hyperparameters for all evaluations:
# - PDF text from reference was extracted with large GROBID model
# - Ollama indexing for choosing best chunks: used text-embedding-3-large from OpenAI, chunking with SentenceSplitter, detected top 3 matching chunks for statement
# - Model temperature is set to 0
#
# ### Hyperparameters here evaluated:
# - only_text: If this is "True", then the scientific text from the TEI file from GROBID was extracted via code - Else the whole text from the TEI document (including sources, authors, ...) was included for choosing the best chunks
# - chunking: chunk size is set to either 256 or 1024, token overlap is always kept at 20
# - model: different models are evaluated and compared for the actual classification part

# %% [markdown]
# ### GPT 3.5 Turbo

# %%
model = "gpt-3.5-turbo-0125"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")
# Out:
# Row 21 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 21 Model Classification Label is not a valid label: None
# Row 21 Model Classification Label is not a valid label: None
# Row 21 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 21 Model Classification Label is not a valid label: None
# Row 21 Model Classification Label is not a valid label: None
# Row 24 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 24 Model Classification Label is not a valid label: None
# Row 24 Model Classification Label is not a valid label: None
# Row 21 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 24 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 21 Model Classification Label is not a valid label: None
# Row 24 Model Classification Label is not a valid label: None
# Row 21 Model Classification Label is not a valid label: None
# Row 24 Model Classification Label is not a valid label: None

# %% [markdown]
# ### GPT 4.1 Nano

# %%
model = "gpt-4.1-nano-2025-04-14"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")

# %% [markdown]
# ### GPT 4.1 Mini

# %%
model = "gpt-4.1-mini-2025-04-14"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")

# %% [markdown]
# ### GPT 4.1

# %%
model = "gpt-4.1-2025-04-14"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")

# %% [markdown]
# #### AI improved prompt

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model, ai_prompt=True)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")
# Out:
# Error gathering results for gpt-4.1-2025-04-14, chunking: 256_20, only_text: False: [Errno 2] No such file or directory: '../data/dfs/256_20/gpt-4.1-2025-04-14/AI_prompt/ReferenceErrorDetection_data_with_prompt_results.pkl'
# Error gathering results for gpt-4.1-2025-04-14, chunking: 1024_20, only_text: False: [Errno 2] No such file or directory: '../data/dfs/1024_20/gpt-4.1-2025-04-14/AI_prompt/ReferenceErrorDetection_data_with_prompt_results.pkl'

# %% [markdown]
# ### Llama 3.1:70b

# %%
model = "llama3.1.70b"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")
# Out:
# Row 81 Model Classification could not be decoded: 'label'
# {
#   "citation": null,
#   "conclusion": null,
#   "introduction": null,
#   "methodology": [
#     "Atomic force microscopy force spectroscopy and trans-epithelial electrical resistance assessed changes in cell-cell tethering and paracellular permeability respectively.",
#     "Carboxyfluorescein dye uptake, ATP-biosensing, and western blotting were used to assess the ability of Peptide 5 to block hemichannel activity, ATP-release, and ultimately disassembly of the adherens/tight junction complex."
#   ],
#   "question": null,
#   "results": [
#     "Co-incubation of TGF-β1 with Peptide 5 significantly reduced dye uptake and restored ATP release to near basal.",
#     "Peptide 5 successfully prevented TGF-β1-evoked changes in expression of E-cadherin, N-cadherin, Claudin-2, and ZO-1 in human primary renal proximal tubule cells.",
#     "Cx43 +/- mice exhibited minimal disassembly of the adherens and tight junction complex."
#   ]
# }
# Row 81 Model Classification Label is not a valid label: None
# Row 81 Model Classification Label is not a valid label: None

# %% [markdown]
# #### AI improved prompt

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model, ai_prompt=True)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")
# Out:
# Error gathering results for llama3.1.70b, chunking: 256_20, only_text: False: [Errno 2] No such file or directory: '../data/dfs/256_20/llama3.1.70b/AI_prompt/ReferenceErrorDetection_data_with_prompt_results.pkl'
# Error gathering results for llama3.1.70b, chunking: 1024_20, only_text: False: [Errno 2] No such file or directory: '../data/dfs/1024_20/llama3.1.70b/AI_prompt/ReferenceErrorDetection_data_with_prompt_results.pkl'

# %% [markdown]
# ### Llama 4 Scout

# %%
model = "llama4.scout"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")
# Out:
# Row 2 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 5 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Classification Result
#
# The provided reference article does not support the statement regarding the calculation of recommended trust values in a secure routing protocol.
#
# ### Explanation
#
# The reference article focuses on textile manufacturing, discussing topics such as sustainable practices, technological advancements, and environmental impacts. The article does not mention trust calculations, secure routing protocols, or any related concepts.
#
# ### Classification
#
# Unsubstantiated
#
# The classification result is: Unsubstantiated
#
# ### Justification
#
# There is no connection between the reference article's content and the statement about calculating recommended trust values in a secure routing protocol. The article's topics, such as textile manufacturing, sustainable practices, and environmental impacts, do not relate to trust calculations or secure routing protocols.
#
# ### Advice
#
# To find relevant information, consider searching for articles related to secure routing protocols, trust calculations, or wireless sensor networks. These topics might provide insight into the concepts mentioned in the statement.
#
# ### Final Answer
#
# The reference article does not provide any relevant information to support the statement about calculating recommended trust values in a secure routing protocol. Therefore, the classification result is Unsubstantiated.
# Row 6 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 7 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 8 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 11 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Understand the task
# The task is to determine if the reference article supports the statement made in the citation. The citation is about the influence of high-resolution ultrasound on melanoma diagnosis.
#
# ## Step 2: Analyze the reference article
# The reference article discusses various imaging modalities for diagnosing melanoma, including ultrasound. However, the primary focus seems to be on other imaging techniques such as dermoscopy and confocal microscopy.
#
# ## 3: Identify relevant information
# The article mentions ultrasound as one of the imaging modalities but does not provide detailed information about its application in melanoma diagnosis compared to other modalities.
#
# ## 4: Determine the support for the citation
# Given that the article does discuss ultrasound in the context of melanoma diagnosis, it implies that there is some level of support for the use of ultrasound. However, the detailed discussion seems to focus more on other imaging techniques.
#
# ## 5: Conclusion
# Based on the provided information and the context of the discussion, it appears that the reference article does provide some level of support for the use of ultrasound in melanoma diagnosis, although it might not be the primary focus.
#
# The best answer is A.
# Row 12 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Analysis of the Provided Information
#
# Given the task to assess whether the reference article [23] supports the statement in question, we first need to understand the context and content of both the statement and the reference article.
#
# ### Statement Context
#
# The original statement to be evaluated is not directly provided, but based on the reference to [23], it seems the discussion revolves around the improvement of encryption methods, specifically in the context of Wireless Sensor Networks (WSNs).
#
# ### Reference Article [23]
#
# The reference article by Rachkidy et al. presents a method for data storage combined with homomorphic encryption for certain WSN applications. This approach aims to enhance security and efficiency in data transmission within WSNs.
#
# ## Evaluation
#
# Without the specific details of the statement being evaluated, we focus on whether [23] contributes to the field of WSN security through its proposed method.
#
# ### Contribution of [23]
#
# The article by Rachkidy et al. introduces a method that combines data storage with homomorphic encryption. This approach is designed to improve the security of WSNs by enabling secure data transmission and storage.
#
# ## Conclusion
#
# Based on the information provided and the context of WSN security, the article [23] does offer a contribution to the field by proposing a method that enhances security in WSNs through homomorphic encryption.
#
# ## Final Assessment
#
# Given the information and context, the reference article [23] does support advancements in WSN security through its proposed method of combining data storage with homomorphic encryption.
#
# The best answer is Substantiated.
# Row 13 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Classification Result
#
# The provided citation [16] does not support the statement made about using a hybrid approach for 3D pose estimation or addressing the challenges in this area. Here's why:
#
# 1. **Relevance to 3D Pose Estimation**: The citation provided relates to an algorithm for secure data transmission in wireless sensor networks (WSNs), which is not directly relevant to 3D pose estimation. The paper discusses an improved identity-based encryption algorithm (IIBE) to address security concerns in WSNs, not computer vision tasks like 3D pose estimation.
#
# 2. **Hybrid Approach Mentioned**: The original statement seems to refer to a hybrid approach for 3D pose estimation, which might involve combining different methodologies (e.g., machine learning models, traditional computer vision techniques) to improve estimation accuracy. However, the citation provided does not discuss or propose a hybrid approach for 3D pose estimation.
#
# 3. **Substance of the Citation**: The substance of the citation [16] pertains to network security and data transmission protocols, not to the methodologies or challenges associated with 3D pose estimation tasks.
#
# ## Conclusion
#
# Given the information provided and the nature of the citation, it appears that citation [16] does not support or relate to the statement made about 3D pose estimation or hybrid approaches in this context.
#
# ## Classification
#
# Unsubstantiated
#
# The classification is: Unsubstantiated
# Row 14 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 15 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 18 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 19 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 20 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 22 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 23 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 24 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 25 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 26 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 28 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 30 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 32 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 34 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {0}
# Row 35 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 36 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 38 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 39 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 40 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ### Evaluation of the Citation
#
# To assess whether the reference article supports the given statement, we must analyze the content and focus of both.
#
# #### Reference Article Overview
#
# The reference article primarily discusses a method for addressing imbalanced datasets in the context of bug report classification. It proposes a combination of data reduction techniques (feature selection and instance selection) and an approach called RSMOTE (Random Over-sampling) to balance class distributions. The article evaluates the performance of this method in terms of accuracy and F-measure, comparing it with other ensemble methods.
#
# #### Given Statement
#
# The given statement pertains to the capabilities of a specific method or approach in the context of machine learning or data analysis. However, the exact statement to be evaluated against the reference article is not provided.
#
# #### Analysis
#
# Without the specific statement to evaluate, we can still discuss the general approach to determining if a reference article supports a given claim:
#
# 1. **Relevance**: Does the reference article address a topic relevant to the claim?
# 2. **Findings**: Do the findings of the reference article support or contradict the claim?
# 3. **Methodology**: Does the methodology used in the reference article align with or inform the claim?
#
# #### Conclusion
#
# Given the information and the analysis above, I conclude that:
#
# - The reference article focuses on addressing imbalanced datasets in bug report classification.
# - It proposes a method combining data reduction and oversampling techniques.
# - The article's findings support the effectiveness of its proposed method.
#
# However, without the specific claim or statement to evaluate against, it's challenging to provide a definitive answer to whether the reference article supports the given claim.
#
# ### Recommendation
#
# - Provide the specific claim or statement to be evaluated.
# - Compare the claim with the findings and methodology of the reference article.
#
# ### Final Assessment
#
# Based on the information provided and typical evaluation criteria, the reference article seems to contribute to the field of machine learning and data analysis, specifically in addressing imbalanced datasets. However, a direct assessment of its support for a specific claim requires more detailed information about the claim itself.
#
# ### Decision
#
# Given the information available, I decide that:
#
# The reference article seems to be relevant and supportive of methods addressing imbalanced datasets, but a direct evaluation of its support for a specific claim requires more context.
#
# ### Suggestions
#
# 1. Provide more details about the claim.
# 2. Compare the article's findings with the claim.
#
# ### Final Note
#
# The assessment is based on the information provided and the context of machine learning and data analysis.
#
# The best answer is:  Yes.  (or  No.  or  Not  Applicable)
# Row 41 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 42 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 44 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 46 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {0}
# Row 47 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Understand the task
# The task is to determine if the reference article supports the statement it is cited for. This involves analyzing the content of the reference article and the statement it is supposed to support.
#
# ## 2: Identify the reference article and the statement
# The reference article is not directly provided, but its content is given. The statement to be supported or refuted is not explicitly provided but is related to the content of the reference article.
#
# ## 3: Analyze the content of the reference article
# The reference article discusses the relationship between epigenetic modifications and breast cancer. It focuses on the role of long non-coding RNAs (lncRNAs) and their epigenetic regulation in breast cancer subtypes.
#
# ## 4: Determine the relevance of the reference article to the statement
# The reference article explores the epigenetic regulation of lncRNAs in breast cancer, including their role in carcinogenesis, progression, and as potential biomarkers. It delves into the specifics of how certain lncRNAs are regulated epigenetically and how they impact breast cancer subtypes.
#
# ## 5: Assess if the reference article supports the given statement
# Without the specific statement provided in the query, we must infer that the task involves evaluating whether the reference article's content supports a particular claim related to epigenetics, lncRNAs, and breast cancer.
#
# ## 6: Conclusion based on the information provided
# Given that the detailed analysis of the reference article's content and its implications for breast cancer research is provided, it seems that the article could support claims related to the epigenetic regulation of lncRNAs in breast cancer. However, the specific claim or statement in question is not provided.
#
# The best answer is:
# Given that the detailed analysis of the reference article's content and its implications for breast cancer research is provided, it seems that the article could support claims related to the epigenetic regulation of lncRNAs in breast cancer. However, the specific claim or statement in question is not provided.
# Row 48 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 50 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {0}
# Row 51 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 52 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 53 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 54 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Analyze the given information
# The task is to determine if the reference article supports the statement made in the citing article. The citing article mentions the genetic diversity of Erodium cicutarium, and the reference article is about the genetic diversity of the same plant species.
#
# ## 2: Identify the relevant information in the reference article
# The reference article discusses the genetic diversity of Erodium cicutarium, including its population structure, genetic variation, and differentiation among populations.
#
# ## 3: Determine if the reference article supports the statement made in the citing article
# The reference article provides evidence for the genetic diversity of Erodium cicutarium, including the presence of genetic variation within and among populations. This supports the statement made in the citing article.
#
# ## 4: Evaluate the relevance and accuracy of the information provided
# The information provided in the reference article is relevant to the statement made in the citing article. The article provides evidence for the genetic diversity of Erodium cicutarium, which supports the statement.
#
# ## 5: Draw a conclusion based on the analysis
# Based on the analysis, the reference article provides evidence that supports the statement made in the citing article.
#
# The final answer is:
# ### Substantiated
#
# The reference article provides substantial evidence to support the claim made in the citing article about the genetic diversity of Erodium cicutarium.
# Row 55 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 58 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 61 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {0}
# Row 62 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {0}
# Row 63 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 64 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 65 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 66 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Understand the task
# The task is to determine if the reference article supports the statement made in the citing article. The statement is about the use of Extreme Learning Machine (ELM) in classification and regression tasks.
#
# ## 2: Analyze the reference article
# The reference article discusses the use of ELM in various applications, including classification and regression tasks. It highlights the advantages of ELM, such as its fast training speed and good generalization performance.
#
# ## 3: Determine the relevance of the reference article to the statement
# The reference article provides information on the use of ELM in classification and regression tasks, which is relevant to the statement made in the citing article.
#
# ## 4: Evaluate the support provided by the reference article
# The reference article provides evidence to support the use of ELM in classification and regression tasks. It discusses the advantages of ELM, such as its fast training speed and good generalization performance.
#
# ## 5: Conclusion
# Based on the analysis, the reference article provides sufficient evidence to support the statement made in the citing article.
#
# The final answer is:
# ### Substantiated
#
# ### Explanation
# The provided reference article and excerpts do relate to the broader context of Extreme Learning Machines (ELM) and their applications in classification and regression tasks. The original statement seems to pertain to the capabilities or applications of ELM, which the referenced material supports through discussions on ELM's performance, applications, and advantages in various tasks.
#
# Given the information from the reference article and its excerpts, it appears that the article does provide a basis for understanding ELM's role in tasks like classification and regression. Therefore, the information seems to substantiate or support the broader claims about ELM's utility in these areas.
#
# The classification as "Substantiated" reflects that the referenced material does offer insights and evidence supporting the claims or applications of ELM in the mentioned contexts.
#
# The final answer is:
# ### True
# Row 68 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 71 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Analyze the given information
# The task is to determine if the reference article supports the statement made in the citation. The citation is about a method for monitoring freshness, and the reference article is about developing a pH indicator for monitoring the freshness of chicken breast.
#
# ## 2: Understand the context of the citation and reference article
# The citation seems to be related to a method for detecting freshness, possibly using a pH indicator or a similar technology. The reference article discusses the development of a pH indicator for monitoring the freshness of chicken breast.
#
# ## 3: Examine the relevance of the reference article to the citation
# The reference article focuses on creating a pH indicator for chicken breast freshness, which aligns with the concept of using a pH indicator for freshness monitoring.
#
# ## 4: Determine if the reference article supports the citation
# Given that the reference article discusses a method for monitoring freshness using a pH indicator, it seems to support the concept presented in the citation.
#
# ## 5: Conclusion
# Based on the information provided and the analysis of the reference article's content, it appears that the reference article does support the concept of using a pH indicator for freshness monitoring.
#
# The best answer is A.
# Row 74 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Understand the task
# The task is to determine if the reference article supports the statement that "the degree of physical activity is associated with weight and adiposity in children." The reference article is titled "Physical Activity and Health in Children" and is a systematic review of studies on the relationship between physical activity and health outcomes in children under 6 years old.
#
# ## Step 2: Identify the relevant information
# The relevant information for this task is found in the abstract and the body of the reference article. The abstract states that "higher levels of physical activity were associated with better weight status and adiposity in children under 6 years old." The body of the article provides more detailed information on the studies reviewed, including the methods used, the results obtained, and the conclusions drawn.
#
# ## Step 3: Analyze the information
# The analysis of the information provided in the reference article indicates that there is strong evidence to support the statement that physical activity is associated with weight and adiposity in children. The article cites several studies that have found a positive association between physical activity and weight status in children under 6 years old.
#
# ## Step 4: Draw conclusions
# Based on the information provided in the reference article, it can be concluded that there is strong evidence to support the statement that physical activity is associated with weight and adiposity in children. The article provides a comprehensive evidence that higher levels of physical activity are associated with better weight status and adiposity in children under 6 years old.
#
# The best answer is:
# The reference answer is that the relationship between physical activity and obesity in children is well established. The evidence from studies suggests that higher levels of physical activity are associated with lower levels of obesity in children. This relationship has been observed in various age groups and populations. Therefore, it can be concluded that physical activity plays an important role in maintaining a healthy weight in children.
# Row 78 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {0}
# Row 81 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Understand the task
# The task is to determine if the reference article supports the statement that connexin 43 (Cx43) hemichannel activity contributes to tubular injury in chronic kidney disease (CKD) by promoting purinergic signaling and disrupting tight junction integrity.
#
# ## Step 2: Identify the key findings
# The reference article shows that Cx43 hemichannel activity promotes purinergic signaling, which disrupts tight junction integrity and contributes to tubular injury in CKD. The article also demonstrates that inhibiting Cx43 hemichannel activity reduces tubular injury and improves renal function.
#
# ## Step 3: Analyze the results
# The results of the study show that Cx43 hemichannel activity promotes purinergic signaling, which disrupts tight junction integrity and contributes to tubular injury in CKD. The study also demonstrates that inhibiting Cx43 hemichannel activity reduces tubular injury and improves renal function.
#
# ## Step 4: Draw conclusions
# Based on the results of the study, it can be concluded that Cx43 hemichannel activity plays a significant role in promoting tubular injury in CKD by disrupting tight junction integrity and promoting purinergic signaling.
#
# The best answer is:
# N/A
# Row 82 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Evaluation of the Reference Article's Support for the Citation Statement
#
# ### Analysis
#
# The provided reference article discusses the properties and effects of Gap19, a peptide that inhibits connexin 43 (Cx43) hemichannels. The article presents various experiments and results related to Gap19's mechanism of action, its effects on astrocytes, and its potential applications.
#
# ### Relevance to the Citation Statement
#
# The citation statement appears to be related to the effects of Gap19 on Cx43 hemichannels. However, without the specific citation statement provided, it is challenging to directly assess the relevance of the reference article.
#
# ### Conclusion
#
# Based on the information provided, it seems that the reference article supports research related to Cx43 hemichannels and Gap19. However, a more detailed evaluation of the citation statement and its direct connection to the reference article is necessary to provide a definitive conclusion.
#
# ## Detailed Report
#
# ### 1. Introduction
#
# The reference article investigates the properties and effects of Gap19, a peptide that inhibits Cx43 hemichannels.
#
# ### 2. Methods and Results
#
# The article presents various experiments and results related to Gap19's mechanism of action, its effects on astrocytes, and its potential applications.
#
# ### 3. Discussion and Conclusion
#
# The article discusses the significance of the findings and their implications for understanding Cx43 hemichannels and their role in various biological processes.
#
# ## Overall Assessment
#
# The reference article provides valuable insights into the properties and effects of Gap19, which may be relevant to the citation statement. However, a more detailed evaluation of the citation statement and its direct connection to the reference article is necessary to provide a definitive conclusion.
#
# The best answer is :
#
# N.A
# Row 83 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 84 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 85 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Evaluation of the Reference
#
# The provided reference explores the potential of mesenchymal stem cells (MSCs) in repairing damaged anal sphincters. The study involves an experimental rat model with three groups: a control group, a group that received primary surgical repair without MSC injection, and a group that received surgical repair with MSC injection.
#
# ## Key Findings
#
# 1. **Improved Muscle Regeneration**: The group that received MSC injection showed improved muscle regeneration compared to the group without MSC injection.
# 2. **Enhanced Contractility**: MSC injection resulted in enhanced contractility of the anal sphincter.
# 3. **Positive Impact on Healing**: The study suggests that MSC injection has a positive impact on the healing process of damaged anal sphincters.
#
# ## Conclusion
#
# The study provides evidence that MSC injection can improve muscle regeneration and contractility in damaged anal sphincters. This finding has implications for the treatment of anal incontinence and suggests that MSC therapy may be a viable option for repairing damaged anal sphincters.
#
# ## Clinical Relevance
#
# The study's findings have clinical relevance, as they suggest that MSC therapy may be a useful treatment option for patients with anal incontinence. The use of MSCs in repairing damaged anal sphincters may provide a new approach to treating this condition, and further research is needed to explore the potential benefits of MSC therapy in this area.
#
# The answer is:
# 1. The use of mesenchymal stem cells in the repair of damaged anal sphincters.
# 2. The application of mesenchymal stem cells in the treatment of anal incontinence.
# 3. The evaluation of the effectiveness of mesenchymal stem cells in the repair of damaged anal sphincters.
# Row 87 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 88 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 93 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 94 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Understand the task
# The task is to determine if the reference article supports the statement made in the citation. This involves analyzing the content of the reference article and comparing it to the citation statement.
#
# ## 2: Identify the citation statement and reference article
# The citation statement is not directly provided, but it is implied to be related to the content of reference 73. The reference article is titled "Development of a Crystal-Rich Magma" and discusses the petrology and geochemistry of the Ongatiti ignimbrite.
#
# ## 3: Analyze the reference article
# The reference article discusses the petrology and geochemistry of the Ongatiti ignimbrite, focusing on the crystal-rich magma and its evolution. It presents data on mineral compositions, temperatures, and pressures during magma crystallization.
#
# ## 4: Compare the citation statement with the reference article
# The citation statement is not explicitly provided, but based on the task, it seems that the statement refers to the existence or characteristics of crystal-rich magmas or the processes involved in their evolution, as discussed in the reference article.
#
# ## 5: Determine if the reference article supports the citation statement
# Given that the reference article extensively discusses the crystal-rich magma of the Ongatiti ignimbrite, including its composition, evolution, and the processes involved, it appears to support or provide evidence related to the citation statement.
#
# ## 6: Conclusion
# The reference article provides detailed insights into the crystal-rich magma of the Ongatiti ignimbrite, supporting the notion that such magmas can exist and evolve through complex processes involving crystallization, temperature changes, and pressure variations.
#
# The best answer is A.
# Row 96 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 97 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Evaluation of the Reference Article's Relevance to the Citation
#
# ### Analysis of the Provided Information
#
# The provided reference article discusses the NHGRI's GWAS Catalog, a database of genetic associations with diseases and traits. The article focuses on the catalog's infrastructure, data visualization tools, and applications.
#
# ### Assessment of the Citation's Relevance
#
# The citation provided appears to be related to the GWAS Catalog, which is a comprehensive database of genetic associations with diseases and traits. However, the citation seems to be more focused on the technical aspects of the catalog rather than providing a direct evaluation of the scientific evidence.
#
# ### Conclusion
#
# Based on the provided information, it seems that the reference article is relevant to the field of genetics and genomics, but its direct relevance to the specific scientific question or hypothesis being addressed is unclear.
#
# ## Classification
#
# *   **Relevance:** 7/10
# *   **Applicability:** 6/10
# *   **Usefulness:** 7/10
#
# The reference article provides valuable insights into the GWAS Catalog and its applications, but its direct relevance to the specific scientific question or hypothesis being addressed is unclear.
#
# ## Suggestions for Improvement
#
# *   Provide more context about the specific scientific question or hypothesis being addressed.
# *   Clarify the direct relevance of the reference article to the citation.
#
# ## Final Evaluation
#
# The reference article is relevant to the field of genetics and genomics, but its direct relevance to the specific scientific question or hypothesis being addressed is unclear. Further evaluation is needed to determine the article's applicability and usefulness.
#
# ## Classification
#
# *   **Relevance:** 7/10
# *   **Applicability:** 6/10
# *   **Usefulness:** 7/10
# Row 98 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Evaluation of the Reference Article's Support for the Statement
#
# ### Analysis of the Reference Article
#
# The reference article discusses the role of lineage-determining transcription factors (LDTFs) in regulating gene expression. It presents evidence that LDTFs, such as PU.1 and C/EBP, play a crucial role in establishing active regulatory regions and modulating the binding of signal-dependent transcription factors.
#
# ### Evaluation of the Statement
#
# The statement to be evaluated is: "Microglial enhancers are primed by LDTFs." The reference article provides evidence that LDTFs are essential for establishing active regulatory regions and modulating the binding of signal-dependent transcription factors.
#
# ### Conclusion
#
# Based on the analysis of the reference article, it appears that the article provides evidence supporting the statement that LDTFs play a crucial role in establishing active regulatory regions and modulating the binding of signal-dependent transcription factors.
#
# ## Classification
#
# *   **Subclassification:** The reference article provides evidence that LDTFs are essential for establishing active regulatory regions and modulating the binding of signal-dependent transcription factors.
#
# ## Final Answer
#
# The reference article supports the statement that LDTFs play a crucial role in establishing active regulatory regions and modulating the binding of signal-dependent transcription factors.
#
# Classification: Substantiated
#
# The reference provides substantial evidence for the role of LDTFs in establishing active regulatory regions and modulating the binding of signal-dependent transcription factors, supporting the statement that LDTFs are essential for microglial enhancer priming.
# Row 99 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 100 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {0}
# Row 101 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 103 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Evaluation of the Reference Article
#
# ### Analysis of the Provided Information
#
# The reference article discusses the development and function of plasmacytoid dendritic cells (pDCs), which play a crucial role in the immune system. The article highlights the unique characteristics of pDCs, including their ability to produce large amounts of interferon-alpha (IFN-α) in response to viral infections.
#
# ### Relevance to the Cited Statement
#
# The cited statement appears to be related to the development and function of pDCs, specifically their role in the immune system. The reference article provides a detailed overview of pDC biology, including their development, function, and interactions with other immune cells.
#
# ### Evaluation of the Reference Article
#
# Based on the provided information, the reference article appears to be a comprehensive review of pDC biology. The article discusses the development of pDCs, their function in the immune system, and their interactions with other immune cells. The article also highlights the unique characteristics of pDCs, including their ability to produce large amounts of IFN-α in response to viral infections.
#
# ### Conclusion
#
# The reference article provides a detailed overview of pDC biology, including their development, function, and interactions with other immune cells. The article appears to be a comprehensive review of the current understanding of pDC biology and highlights the importance of pDCs in the immune system.
#
# The best answer is A
# Row 104 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {0}
# Row 105 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 106 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Analyze the given information
# The task is to determine if the reference article supports the statement made in the citation. The citation is about microbial life in extreme environments, specifically in a lake called Lake Vida, Antarctica.
#
# ## 2: Understand the context of the reference article
# The reference article discusses the discovery of microbial life in Lake Vida, which is a frozen lake in Antarctica. The lake has extreme conditions, with temperatures below freezing, high salinity, and a lack of sunlight.
#
# ## 3: Identify the key findings of the reference article
# The article describes the presence of microbial life in Lake Vida, including bacteria and other microorganisms that can survive in extreme conditions. The lake's ecosystem is unique, with a high concentration of dissolved salts and a lack of oxygen.
#
# ## 4: Determine if the reference article supports the citation
# The reference article provides evidence for the existence of microbial life in Lake Vida, which supports the citation. The article describes the diversity of microorganisms present in the lake, including bacteria and other organisms that can survive in extreme conditions.
#
# ## 5: Conclusion
# Based on the analysis of the reference article, it is clear that the article provides evidence for the existence of microbial life in Lake Vida, which supports the citation.
#
# The best answer is: 1
# Row 108 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 109 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 111 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 113 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 115 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 116 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 117 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 118 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Evaluation of the Statement
#
# The given statement pertains to the relationship between climate change and carbon sinks, specifically referencing the impact of climate change on terrestrial carbon sinks and the feedback mechanisms involved.
#
# ## Analysis of the Reference Article
#
# The reference article discusses various aspects of carbon cycling, including the effects of climate change on carbon sinks, feedback mechanisms, and the role of different ecosystems.
#
# ## Substantiation of the Statement
#
# The article provides insights into how climate change affects carbon sinks and feedback mechanisms. However, without a direct comparison or specific claim related to the statement provided, it's challenging to substantiate the statement directly from the information given.
#
# ## Conclusion
#
# Given the information provided and the context of the discussion on carbon cycling, the relationship between climate change and carbon sinks, and feedback mechanisms, it seems that the article could support certain aspects of the statement regarding the impact of climate change on carbon sinks. However, a direct substantiation or refutation requires a more specific claim or data related to the statement.
#
# The best answer is 1.
# Row 119 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Analyze the given information
# The task is to determine if the reference article supports the statement made in the citation. The citation is related to the potential of agricultural land use changes and mitigation strategies.
#
# ## Step 2: Identify the key points from the reference article
# The article discusses various aspects of land use, including the potential for mitigation of greenhouse gas emissions through changes in land use practices, demand-side measures, and supply-side measures.
#
# ## 3: Determine the relevance of the reference article to the citation
# The reference article provides insights into land use changes, mitigation strategies, and the potential for reducing greenhouse gas emissions. It highlights the importance of both demand-side and supply-side measures.
#
# ## 4: Assess the support provided by the reference article to the citation
# The article supports the idea that there are multiple strategies for reducing greenhouse gas emissions and that both demand-side and supply-side measures are crucial. It also emphasizes the importance of land use changes in mitigating climate change.
#
# ## 5: Conclusion
# Based on the information provided in the reference article, it appears that the article supports the citation by highlighting the potential for land use changes and mitigation strategies to reduce greenhouse gas emissions.
#
# The best answer is that the reference provides a detailed analysis supporting the idea that land use changes and mitigation strategies can significantly contribute to reducing greenhouse gas emissions.
# Row 121 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 122 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 123 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 124 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 125 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 127 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 128 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 129 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 130 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ## Step 1: Understand the task
# The task is to determine if the reference article supports the statement made in the citing article. The statement in question is related to the prevalence of ventriculomegaly in Wistar rats.
#
# ## 2: Identify the reference article and the statement to be evaluated
# The reference article discusses the prevalence of ventriculomegaly in Wistar rats, as detected by MRI. The statement to be evaluated is "43.2% of the Wistar rats had ventriculomegaly."
#
# ## 3: Analyze the reference article
# The reference article provides detailed information about the prevalence of ventriculomegaly in Wistar rats, including data from MRI scans. The study found that 43.2% of the Wistar rats had ventriculomegaly.
#
# ## 4: Evaluate the support provided by the reference article
# The reference article provides strong support for the statement that 43.2% of the Wistar rats had ventriculomegaly. The study used MRI scans to detect ventriculomegaly and found that 43.2% of the rats had the condition.
#
# ## 5: Conclusion
# Based on the analysis, the reference article provides strong support for the statement that 43.2% of the Wistar rats had ventriculomegaly.
#
# The best answer is:
# The article  provided  evidence  that 43.2 % of  Wistar  rats  had  ventriculomegaly  and  associated  with  it  the  prevalence  of  the  other  abnormality  in  the  brain  of  the  rat  .
# Row 131 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 132 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 133 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 135 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 136 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 137 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 138 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 139 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {1}
# Row 140 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 141 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Substantiated}
# Row 142 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 143 Model Classification could not be decoded: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# {Unsubstantiated}
# Row 144 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
# ### Evaluation of the Reference Article's Support for the Citation
#
# #### Article Information
# - **Title**: Not explicitly provided but inferred from the context.
# - **Reference Number**: 52
#
# #### Task
# ...
# Row 153 Model Classification Label is not a valid label: None
# Row 154 Model Classification Label is not a valid label: None
# Row 155 Model Classification Label is not a valid label: None
# Row 157 Model Classification Label is not a valid label: None
# Row 158 Model Classification Label is not a valid label: None
# Row 159 Model Classification Label is not a valid label: None
# Row 160 Model Classification Label is not a valid label: None
# Row 163 Model Classification Label is not a valid label: None
# Row 164 Model Classification Label is not a valid label: None
# Row 166 Model Classification Label is not a valid label: None
# Row 167 Model Classification Label is not a valid label: None
# Row 168 Model Classification Label is not a valid label: None
# Row 169 Model Classification Label is not a valid label: None
# Row 170 Model Classification Label is not a valid label: None
# Row 173 Model Classification Label is not a valid label: None
# Row 175 Model Classification Label is not a valid label: None
# Row 176 Model Classification Label is not a valid label: None
# Row 177 Model Classification Label is not a valid label: None
# Row 178 Model Classification Label is not a valid label: None
# Row 179 Model Classification Label is not a valid label: None
# Row 180 Model Classification Label is not a valid label: substantiated
# Row 182 Model Classification Label is not a valid label: None
# Row 183 Model Classification Label is not a valid label: None
# Row 185 Model Classification Label is not a valid label: None
# Row 186 Model Classification Label is not a valid label: None
# Row 188 Model Classification Label is not a valid label: None
# Row 189 Model Classification Label is not a valid label: None
# Row 190 Model Classification Label is not a valid label: None
# Row 191 Model Classification Label is not a valid label: None
# Row 192 Model Classification Label is not a valid label: None
# Row 194 Model Classification Label is not a valid label: None
# Row 195 Model Classification Label is not a valid label: None
# Row 196 Model Classification Label is not a valid label: None
# Row 197 Model Classification Label is not a valid label: None
# Row 199 Model Classification Label is not a valid label: None
# Row 200 Model Classification Label is not a valid label: None
# Row 202 Model Classification Label is not a valid label: None
# Row 203 Model Classification Label is not a valid label: None
# Row 204 Model Classification Label is not a valid label: None
# Row 205 Model Classification Label is not a valid label: None
# Row 206 Model Classification Label is not a valid label: None
# Row 208 Model Classification Label is not a valid label: None
# Row 209 Model Classification Label is not a valid label: None
# Row 210 Model Classification Label is not a valid label: None
# Row 211 Model Classification Label is not a valid label: None
# Row 212 Model Classification Label is not a valid label: None
# Row 214 Model Classification Label is not a valid label: None
# Row 215 Model Classification Label is not a valid label: None
# Row 216 Model Classification Label is not a valid label: None
# Row 218 Model Classification Label is not a valid label: None
# Row 219 Model Classification Label is not a valid label: None
# Row 220 Model Classification Label is not a valid label: None
# Row 221 Model Classification Label is not a valid label: None
# Row 222 Model Classification Label is not a valid label: None
# Row 223 Model Classification Label is not a valid label: None
# Row 224 Model Classification Label is not a valid label: None
# Row 225 Model Classification Label is not a valid label: None
# Row 226 Model Classification Label is not a valid label: None
# Row 228 Model Classification Label is not a valid label: None
# Row 229 Model Classification Label is not a valid label: None
# Row 230 Model Classification Label is not a valid label: None
# Row 231 Model Classification Label is not a valid label: None
# Row 232 Model Classification Label is not a valid label: None
# Row 233 Model Classification Label is not a valid label: None
# Row 235 Model Classification Label is not a valid label: None
# Row 237 Model Classification Label is not a valid label: None
# Row 238 Model Classification Label is not a valid label: None
# Row 240 Model Classification Label is not a valid label: None
# Row 241 Model Classification Label is not a valid label: None
# Row 242 Model Classification Label is not a valid label: None
# Row 243 Model Classification Label is not a valid label: None
# Row 244 Model Classification Label is not a valid label: None
# Row 245 Model Classification Label is not a valid label: None
# Row 246 Model Classification Label is not a valid label: None
# Row 247 Model Classification Label is not a valid label: None
# Row 248 Model Classification Label is not a valid label: None
# Row 0 Model Classification Label is not a valid label: None
# Row 1 Model Classification Label is not a valid label: None
# Row 3 Model Classification Label is not a valid label: None
# Row 4 Model Classification Label is not a valid label: None
# Row 5 Model Classification Label is not a valid label: None
# Row 6 Model Classification Label is not a valid label: None
# Row 7 Model Classification Label is not a valid label: None
# Row 8 Model Classification Label is not a valid label: None
# Row 10 Model Classification Label is not a valid label: None
# Row 12 Model Classification Label is not a valid label: None
# Row 13 Model Classification Label is not a valid label: None
# Row 15 Model Classification Label is not a valid label: None
# Row 16 Model Classification Label is not a valid label: None
# Row 18 Model Classification Label is not a valid label: None
# Row 19 Model Classification Label is not a valid label: None
# Row 20 Model Classification Label is not a valid label: None
# Row 21 Model Classification Label is not a valid label: None
# Row 22 Model Classification Label is not a valid label: None
# Row 24 Model Classification Label is not a valid label: None
# Row 25 Model Classification Label is not a valid label: None
# Row 26 Model Classification Label is not a valid label: None
# Row 27 Model Classification Label is not a valid label: None
# Row 28 Model Classification Label is not a valid label: None
# Row 29 Model Classification Label is not a valid label: None
# Row 30 Model Classification Label is not a valid label: None
# Row 31 Model Classification Label is not a valid label: None
# Row 33 Model Classification Label is not a valid label: None
# Row 34 Model Classification Label is not a valid label: None
# Row 35 Model Classification Label is not a valid label: None
# Row 37 Model Classification Label is not a valid label: None
# Row 39 Model Classification Label is not a valid label: None
# Row 40 Model Classification Label is not a valid label: None
# Row 41 Model Classification Label is not a valid label: None
# Row 42 Model Classification Label is not a valid label: None
# Row 43 Model Classification Label is not a valid label: None
# Row 44 Model Classification Label is not a valid label: None
# Row 46 Model Classification Label is not a valid label: None
# Row 47 Model Classification Label is not a valid label: None
# Row 48 Model Classification Label is not a valid label: None
# Row 49 Model Classification Label is not a valid label: None
# Row 50 Model Classification Label is not a valid label: None
# Row 52 Model Classification Label is not a valid label: None
# Row 53 Model Classification Label is not a valid label: None
# Row 54 Model Classification Label is not a valid label: None
# Row 57 Model Classification Label is not a valid label: None
# Row 58 Model Classification Label is not a valid label: None
# Row 59 Model Classification Label is not a valid label: None
# Row 61 Model Classification Label is not a valid label: None
# Row 62 Model Classification Label is not a valid label: None
# Row 63 Model Classification Label is not a valid label: None
# Row 64 Model Classification Label is not a valid label: None
# Row 65 Model Classification Label is not a valid label: None
# Row 66 Model Classification Label is not a valid label: None
# Row 68 Model Classification Label is not a valid label: None
# Row 69 Model Classification Label is not a valid label: None
# Row 71 Model Classification Label is not a valid label: None
# Row 72 Model Classification Label is not a valid label: None
# Row 74 Model Classification Label is not a valid label: None
# Row 76 Model Classification Label is not a valid label: None
# Row 77 Model Classification Label is not a valid label: None
# Row 78 Model Classification Label is not a valid label: None
# Row 79 Model Classification Label is not a valid label: None
# Row 80 Model Classification Label is not a valid label: None
# Row 82 Model Classification Label is not a valid label: None
# Row 83 Model Classification Label is not a valid label: None
# Row 84 Model Classification Label is not a valid label: None
# Row 85 Model Classification Label is not a valid label: None
# Row 94 Model Classification Label is not a valid label: None
# Row 95 Model Classification Label is not a valid label: None
# Row 96 Model Classification Label is not a valid label: None
# Row 97 Model Classification Label is not a valid label: None
# Row 98 Model Classification Label is not a valid label: None
# Row 100 Model Classification Label is not a valid label: None
# Row 101 Model Classification Label is not a valid label: None
# Row 105 Model Classification Label is not a valid label: None
# Row 107 Model Classification Label is not a valid label: None
# Row 108 Model Classification Label is not a valid label: None
# Row 109 Model Classification Label is not a valid label: None
# Row 112 Model Classification Label is not a valid label: None
# Row 113 Model Classification Label is not a valid label: None
# Row 116 Model Classification Label is not a valid label: None
# Row 117 Model Classification Label is not a valid label: None
# Row 118 Model Classification Label is not a valid label: None
# Row 119 Model Classification Label is not a valid label: None
# Row 120 Model Classification Label is not a valid label: None
# Row 121 Model Classification Label is not a valid label: None
# Row 122 Model Classification Label is not a valid label: None
# Row 123 Model Classification Label is not a valid label: None
# Row 124 Model Classification Label is not a valid label: None
# Row 125 Model Classification Label is not a valid label: None
# Row 126 Model Classification Label is not a valid label: None
# Row 127 Model Classification Label is not a valid label: None
# Row 130 Model Classification Label is not a valid label: None
# Row 131 Model Classification Label is not a valid label: None
# Row 133 Model Classification Label is not a valid label: None
# Row 135 Model Classification Label is not a valid label: None
# Row 136 Model Classification Label is not a valid label: None
# Row 138 Model Classification Label is not a valid label: None
# Row 139 Model Classification Label is not a valid label: None
# Row 143 Model Classification Label is not a valid label: None
# Row 144 Model Classification Label is not a valid label: None
# Row 145 Model Classification Label is not a valid label: None
# Row 146 Model Classification Label is not a valid label: None
# Row 147 Model Classification Label is not a valid label: None
# Row 148 Model Classification Label is not a valid label: None
# Row 149 Model Classification Label is not a valid label: None
# Row 150 Model Classification Label is not a valid label: None
# Row 152 Model Classification Label is not a valid label: None
# Row 153 Model Classification Label is not a valid label: None
# Row 155 Model Classification Label is not a valid label: None
# Row 157 Model Classification Label is not a valid label: None
# Row 158 Model Classification Label is not a valid label: None
# Row 159 Model Classification Label is not a valid label: None
# Row 160 Model Classification Label is not a valid label: None
# Row 163 Model Classification Label is not a valid label: None
# Row 164 Model Classification Label is not a valid label: None
# Row 166 Model Classification Label is not a valid label: None
# Row 167 Model Classification Label is not a valid label: None
# Row 168 Model Classification Label is not a valid label: None
# Row 169 Model Classification Label is not a valid label: None
# Row 170 Model Classification Label is not a valid label: None
# Row 173 Model Classification Label is not a valid label: None
# Row 175 Model Classification Label is not a valid label: None
# Row 176 Model Classification Label is not a valid label: None
# Row 177 Model Classification Label is not a valid label: None
# Row 178 Model Classification Label is not a valid label: None
# Row 179 Model Classification Label is not a valid label: None
# Row 180 Model Classification Label is not a valid label: substantiated
# Row 182 Model Classification Label is not a valid label: None
# Row 183 Model Classification Label is not a valid label: None
# Row 185 Model Classification Label is not a valid label: None
# Row 186 Model Classification Label is not a valid label: None
# Row 188 Model Classification Label is not a valid label: None
# Row 189 Model Classification Label is not a valid label: None
# Row 190 Model Classification Label is not a valid label: None
# Row 191 Model Classification Label is not a valid label: None
# Row 192 Model Classification Label is not a valid label: None
# Row 194 Model Classification Label is not a valid label: None
# Row 195 Model Classification Label is not a valid label: None
# Row 196 Model Classification Label is not a valid label: None
# Row 197 Model Classification Label is not a valid label: None
# Row 199 Model Classification Label is not a valid label: None
# Row 200 Model Classification Label is not a valid label: None
# Row 202 Model Classification Label is not a valid label: None
# Row 203 Model Classification Label is not a valid label: None
# Row 204 Model Classification Label is not a valid label: None
# Row 205 Model Classification Label is not a valid label: None
# Row 206 Model Classification Label is not a valid label: None
# Row 208 Model Classification Label is not a valid label: None
# Row 209 Model Classification Label is not a valid label: None
# Row 210 Model Classification Label is not a valid label: None
# Row 211 Model Classification Label is not a valid label: None
# Row 212 Model Classification Label is not a valid label: None
# Row 214 Model Classification Label is not a valid label: None
# Row 215 Model Classification Label is not a valid label: None
# Row 216 Model Classification Label is not a valid label: None
# Row 218 Model Classification Label is not a valid label: None
# Row 219 Model Classification Label is not a valid label: None
# Row 220 Model Classification Label is not a valid label: None
# Row 221 Model Classification Label is not a valid label: None
# Row 222 Model Classification Label is not a valid label: None
# Row 223 Model Classification Label is not a valid label: None
# Row 224 Model Classification Label is not a valid label: None
# Row 225 Model Classification Label is not a valid label: None
# Row 226 Model Classification Label is not a valid label: None
# Row 228 Model Classification Label is not a valid label: None
# Row 229 Model Classification Label is not a valid label: None
# Row 230 Model Classification Label is not a valid label: None
# Row 231 Model Classification Label is not a valid label: None
# Row 232 Model Classification Label is not a valid label: None
# Row 233 Model Classification Label is not a valid label: None
# Row 235 Model Classification Label is not a valid label: None
# Row 237 Model Classification Label is not a valid label: None
# Row 238 Model Classification Label is not a valid label: None
# Row 240 Model Classification Label is not a valid label: None
# Row 241 Model Classification Label is not a valid label: None
# Row 242 Model Classification Label is not a valid label: None
# Row 243 Model Classification Label is not a valid label: None
# Row 244 Model Classification Label is not a valid label: None
# Row 245 Model Classification Label is not a valid label: None
# Row 246 Model Classification Label is not a valid label: None
# Row 247 Model Classification Label is not a valid label: None
# Row 248 Model Classification Label is not a valid label: None

# %% [markdown]
# ### Save results

# %%
import json

with open("../data/all_results.json", "w") as json_file:
    json.dump(all_results, json_file, indent=4)
