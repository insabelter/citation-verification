# %% [markdown]
# # Prompting the models to classify the statements

# %%
import pandas as pd

# read the dataframe from a pickle file
df = pd.read_pickle('../data/ReferenceErrorDetection_data_with_chunk_info.pkl')

# %%
df.head()
# Out:
#     Source Citing Article ID         Citing Article DOI  \
# 0  PubPeer              c001  10.1016/j.est.2021.103553
# 1  PubPeer              c001  10.1016/j.est.2021.103553
# 2  PubPeer              c002       10.1155/2022/4601350
# 3  PubPeer              c003       10.1155/2022/2408685
# 4  PubPeer              c004       10.1155/2022/4783847
#
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain  \
# 0                       Yes  Engineering
# 1                       Yes  Engineering
# 2                       Yes    Chemistry
# 3                       Yes     Medicine
# 4                       Yes  Engineering
#
#                              Statement with Citation Reference Article ID  \
# 0  Others have aimed to reduce irreversibility or...                 r001
# 1  Some researchers have also studied various hea...                 r002
# 2  The relative content of total flavonoids in th...                 r003
# 3  Research has shown that remimazolam tosylate e...                 r004
# 4  if the efficiency of the routing algorithm is ...                 r005
#
#              Reference Article DOI  \
# 0             10.1155/2021/2087027
# 1      10.1016/j.physa.2018.12.031
# 2  10.1088/1742-6596/1937/1/012038
# 3        10.1186/s12871-018-0543-3
# 4      10.36410/jcpr.2022.23.3.312
#
#                              Reference Article Title  \
# 0  A Fault Analysis Method for Three-Phase Induct...
# 1  Develop 24 dissimilar ANNs by suitable archite...
# 2  Lipid Data Acquisition for devices Treatment o...
# 3  Effect of propofol on breast cancer cell, the ...
# 4  Analysis and research hotspots of ceramic mate...
#
#                           Reference Article Abstract  \
# 0  The fault prediction and abductive fault diagn...
# 1  The artificial neural network optimization met...
# 2  Recently, the widespread deployment of smart p...
# 3  Breast cancer is the second leading cause of c...
# 4  From the perspective of scientometrics, comb t...
#
#   Reference Article PDF Available Reference Article Retracted  \
# 0                             Yes                          No
# 1                             Yes                          No
# 2                             Yes                          No
# 3                             Yes                          No
# 4                             Yes                          No
#
#   Reference Article Downloaded           Label Explanation  \
# 0                          Yes  Unsubstantiate  Irrelevant
# 1                          Yes  Unsubstantiate  Irrelevant
# 2                          Yes  Unsubstantiate  Irrelevant
# 3                          Yes  Unsubstantiate  Irrelevant
# 4                          Yes  Unsubstantiate  Irrelevant
#
#                                      Top_3_Chunk_IDs  \
# 0  [5cb7b532-0bf6-42e8-b245-5ce118330981, 9c03161...
# 1  [cfec4c95-2610-4b0d-b81e-3c46710e02e3, 17e8175...
# 2  [58d642c1-5f8e-4ac3-bc25-c74eb9c6f5bf, b00c81c...
# 3  [021c7cfc-9329-4667-8653-753f07eb787d, 4aac749...
# 4  [716a8a3a-eed7-4c86-89a3-d63beecb4ff3, 7776e6e...
#
#                                    Top_3_Chunk_Texts
# 0  [the winding and lead wirep 15Connection box j...
# 1  [Therm. Anal. Calorim\n\t\t\n\t\t\t131\n\t\t\t...
# 2  [mmol/l and 6.96 mmol/l TG calculation concent...
# 3  [J Anaesthesiol\n\t\t\n\t\t\t22\n\t\t\t8\n\t\t...
# 4  [size indicator is high, reflecting the import...

# %% [markdown]
# ## Create the prompts

# %%
def format_excerpts(excerpt_list):
    excerpts_text = ""
    for id, excerpt in enumerate(excerpt_list):
        excerpts_text += f"----- Excerpt {id+1}: -----\n{excerpt}\n\n"
    return excerpts_text

# %%
print(format_excerpts(df.iloc[0]['Top_3_Chunk_Texts']))
# Out:
# ----- Excerpt 1: -----
# the winding and lead wirep 15Connection box joint loosenedp 16Poor contact of the power control loop switchp 17Decrease in rotational speedp 18Excessive current in a phasep 19Excessive excitation currentp 20A phase voltage lossp 21Foreign matter enters the rotary shaft clearancep 22-e motor oil intakep 23Oxidation and decomposition of bearing lubricating oilp 24Bearing expansion by heatp 25Bearing generates additional loadp 26Rotor axial movesp 27-e iron core of the stator and rotor has an air gapp 28Rotor winding open circuitp 29Contact resistance value increasesp 30Motor overheatingp 31Phase-absent operationp 32Abnormal rotation or the rotor is stuckp 33Insulation agingp 34Reduction of lubricant oilp 35Friction occurs between the crankshaft ring and shaft holep 36Excessive vibration of the motor in operationp 37Excessive bearing noisep 38Motor sweepingp 39-ree-phase current of the stator increasesp 40Increased pressure dropp 41-ree-phase current asymmetryp 42Excessive wear of the bearingp 43Irregular impact loadp 44Abnormal noisep 45Rotor rotation is weak or the rotor does not turn and hump 46Insulation winding burned downp 47Motor axle holderp 48Rotor stuck or stopped rotatingP 49-e motor appears local high heatp 50-e motor cannot work--
# Downloaded from https://onlinelibrary.wiley.com/doi/10.1155/2021/2087027, Wiley Online Library on [04/03/2025]. See the Terms and Conditions (https://onlinelibrary.wiley.com/terms-and-conditions) on Wiley Online Library for rules of use; OA articles are governed by the applicable Creative Commons LicenseComplexity98503, 2021, 1,
# Downloaded from https://onlinelibrary.wiley.com/doi/10.1155/2021/2087027, Wiley Online Library on [04/03/2025]. See the Terms and Conditions (https://onlinelibrary.wiley.com/terms-and-conditions) on Wiley Online Library for rules of use; OA articles are governed by the applicable Creative Commons License10Complexity8503, 2021, 1,
# O 10 ) T When k � 2,
#
# ----- Excerpt 2: -----
# ID 2635714, 16 pages
#
#
#
#
# 		A rough set-based bioinspired fault diagnosis method for electrical substations
#
# 			TWang
#
#
# 			WLiu
#
#
# 			JBZhao
#
# 		ID 105961
#
#
# 		International Journal of Electrical Power & Energy Systems
#
# 			119
# 			2020
#
#
#
#
#
#
# 		Simplified and yet turing universal spiking neural P systems with polarizations optimized by anti-spikes
#
# 			TWu
#
#
# 			TZhang
#
#
# 			FXu
#
#
#
# 		Neurocomputing
#
# 			414
#
# 			2020
#
#
#
#
#
#
# 		Spiking neural P systems with polarizations and rules on synapses
#
# 			SXJiang
#
#
# 			JHFan
#
#
# 			YJLiu
#
#
#
# 		Complexity
#
# 			2020
# 			2020
#
#
# 	Article ID 8742308, 12 pages
#
#
#
#
# 		Spiking neural P systems with polarizations
#
# 			TWu
#
#
# 			APaun
#
#
# 			ZZhang
#
#
# 			LPan
#
#
#
# 		IEEE Transactions on Neural Networks and Learning Systems
#
# 			29
# 			8
#
# 			2018
#
#
#
#
#
#
# 		A weighted corrective fuzzy reasoning spiking neural P system for fault diagnosis in power systems with variable topologies
#
# 			TWang
#
#
# 			XGWei
#
#
# 			JWang
#
#
#
# 		Engineering Applications of Artificial Intelligence
#
# 			92
#
# 			2019
#
#
# 	Article ID 103680
#
#
#
#
# 		A fault diagnosis method for power transmission networks based on spiking neural P systems with self-updating rules considering biological apoptosis mechanism
#
# 			WLiu
#
#
# 			TWang
#
#
# 			TLZang
#
# 		ID 2462647
#
#
# 		Complexity
#
# 			2020
# 			2020
#
#
#
#
#
#
# 		Uncertainty measure in evidence theory
#
# 			YDeng
#
#
#
# 		Science China Information Sciences
#
# 			63
# 			11
#
# 			2020
#
#
#
#
#
#
# 		Entailment for intuitionistic fuzzy sets based on generalized belief structures
#
# 			YXue
#
#
# 			YDeng
#
#
#
# 		International Journal of Intelligent Systems
#
# 			35
# 			6
#
# 			2020
#
#
#
#
#
#
# 		Essential motor health monitoring: making informed decisions about motor maintenance before a failure
#
# ----- Excerpt 3: -----
# Journal of Intelligent Systems
#
# 			35
# 			6
#
# 			2020
#
#
#
#
#
#
# 		Essential motor health monitoring: making informed decisions about motor maintenance before a failure occurs
#
# 			RLoiselle
#
#
# 			ZXu
#
#
# 			IVoloh
#
#
#
# 		IEEE Industry Applications Magazine
#
# 			24
# 			6
#
# 			2018
#
#
#
#
#
#
# 		Induction motors fault diagnosis using finite element method: a review
#
# 			XLiang
#
#
# 			MZAli
#
#
# 			HZhang
#
#
#
# 		IEEE Transactions on Industry Applications
#
# 			56
# 			2
#
# 			2020
#
#
#
#
#
#
# 		A motor fault diagnosis system based on cerebellar model articulation controller
#
# 			PYChen
#
#
# 			KHChao
#
#
# 			YCTseng
#
#
#
# 		IEEE Access
#
# 			7
#
# 			2019
#
#
#
#
#
#
# 		Novel approach using Hilbert transform for multiple broken rotor bars fault location detection for three phase induction motor
#
# 			MBAbd-El-Malek
#
#
# 			AKAbdelsalam
#
#
# 			OEHassan
#
#
#
# 		ISA Transactions
#
# 			80
#
# 			2018
#
#
#
#
#
#
# 		Enhanced sparse period-group lasso for bearing fault diagnosis
#
# 			ZZhao
#
#
# 			SWu
#
#
# 			BQiao
#
#
# 			SWang
#
#
# 			XChen
#
#
#
# 		IEEE Transactions on Industrial Electronics
#
# 			66
# 			3
#
# 			2019
#
#
#
#
#
#
# 		Fault tree analysis of floating offshore wind turbines
#
# 			JKang
#
#
# 			LSun
#
#
# 			CGuedesSoares
#
#
#
# 		Renewable Energy
#
# 			133
#
# 			2019
#
#
#
#
#
#
# 		A new geometric mean FMEA method based on information quality
#
# 			XCao
#
#
# 			YDeng
#
#
#
# 		IEEE Access
#
# 			7
# 			1
#
# 			2019
#
#
#
#
#
#
# 		A bidirectional diagnosis algorithm of fuzzy petri net using inner-reasoningpath
#
# 			KQZhou
#
#
# 			WHGui
#
#
# 			LPMo
#
#
#
# 		Symmetry-Basel
#
# 			10
# 			6
#
# 			2018

# %%
def create_prompt(df_row):
    title = df_row['Citing Article Title']
    statement = df_row['Statement with Citation']
    reference_title = df_row['Reference Article Title']
    reference_abstract = df_row['Reference Article Abstract']
    reference_excerpts = format_excerpts(df_row['Top_3_Chunk_Texts'])

    prompt = f"""   
    You are an experienced scientific writer and editor. 
    You will be given a statement from an article that cites a reference article and information from the reference article. 
    You will determine and explain if the reference article supports the statement.  
    
    Specifically, choose a label from "Fully substantiated", "Partially substantiated", and "Unsubstantiated". 
    Further explanations of the labels are as follows: 
    "Fully substantiated": The reference article fully substantiates the relevant part of the statement from the present article. 
    "Partially substantiated": According to the reference article, there is a minor error in the statement but the error does not invalidate the purpose of the statement. 
    "Unsubstantiate": The reference part does not substantiate any part of the statement. This could be because the statement is contradictory to, unrelated to, or simply missing from the reference article.  
    
    Format your answer in JSON with two elements: "label" and "explanation". 
    Your explanation should be short and concise. 
    
    # The citing article
    Title: {title} 
    Statement: {statement}
    
    # The reference article 
    Title: {reference_title} 
    Abstract: {reference_abstract} 
    Excerpts: \n\n{reference_excerpts}
    """

    return prompt

# %%
example_prompt = create_prompt(df.iloc[0])
print(example_prompt)
# Out:
#
#     You are an experienced scientific writer and editor.
#     You will be given a statement from an article that cites a reference article and information from the reference article.
#     You will determine and explain if the reference article supports the statement.
#
#     Specifically, choose a label from "Fully substantiated", "Partially substantiated", and "Unsubstantiated".
#     Further explanations of the labels are as follows:
#     "Fully substantiated": The reference article fully substantiates the relevant part of the statement from the present article.
#     "Partially substantiated": According to the reference article, there is a minor error in the statement but the error does not invalidate the purpose of the statement.
#     "Unsubstantiate": The reference part does not substantiate any part of the statement. This could be because the statement is contradictory to, unrelated to, or simply missing from the reference article.
#
#     Format your answer in JSON with two elements: "label" and "explanation".
#     Your explanation should be short and concise.
#
#     # The citing article
#     Title: Heating a residential building using the heat generated in the lithium ion battery pack by the electrochemical process
#     Statement: Others have aimed to reduce irreversibility or optimize energy-consumed devices [citation 36].
#
#     # The reference article
#     Title: A Fault Analysis Method for Three-Phase Induction Motors Based on Spiking Neural P Systems
#     Abstract: The fault prediction and abductive fault diagnosis of three-phase induction motors are of great importance for improving their working safety, reliability, and economy; however, it is difficult to succeed in solving these issues. This paper proposes a fault analysis method of motors based on modified fuzzy reasoning spiking neural P systems with real numbers (rMFRSNPSs) for fault prediction and abductive fault diagnosis. To achieve this goal, fault fuzzy production rules of three-phase induction motors are first proposed. Then, the rMFRSNPS is presented to model the rules, which provides an intuitive way for modelling the motors. Moreover, to realize the parallel data computing and information reasoning in the fault prediction and diagnosis process, three reasoning algorithms for the rMFRSNPS are proposed: the pulse value reasoning algorithm, the forward fault prediction reasoning algorithm, and the backward abductive fault diagnosis reasoning algorithm. Finally, some case studies are given, in order to verify the feasibility and effectiveness of the proposed method.
#     Excerpts:
#
# ----- Excerpt 1: -----
# the winding and lead wirep 15Connection box joint loosenedp 16Poor contact of the power control loop switchp 17Decrease in rotational speedp 18Excessive current in a phasep 19Excessive excitation currentp 20A phase voltage lossp 21Foreign matter enters the rotary shaft clearancep 22-e motor oil intakep 23Oxidation and decomposition of bearing lubricating oilp 24Bearing expansion by heatp 25Bearing generates additional loadp 26Rotor axial movesp 27-e iron core of the stator and rotor has an air gapp 28Rotor winding open circuitp 29Contact resistance value increasesp 30Motor overheatingp 31Phase-absent operationp 32Abnormal rotation or the rotor is stuckp 33Insulation agingp 34Reduction of lubricant oilp 35Friction occurs between the crankshaft ring and shaft holep 36Excessive vibration of the motor in operationp 37Excessive bearing noisep 38Motor sweepingp 39-ree-phase current of the stator increasesp 40Increased pressure dropp 41-ree-phase current asymmetryp 42Excessive wear of the bearingp 43Irregular impact loadp 44Abnormal noisep 45Rotor rotation is weak or the rotor does not turn and hump 46Insulation winding burned downp 47Motor axle holderp 48Rotor stuck or stopped rotatingP 49-e motor appears local high heatp 50-e motor cannot work--
# Downloaded from https://onlinelibrary.wiley.com/doi/10.1155/2021/2087027, Wiley Online Library on [04/03/2025]. See the Terms and Conditions (https://onlinelibrary.wiley.com/terms-and-conditions) on Wiley Online Library for rules of use; OA articles are governed by the applicable Creative Commons LicenseComplexity98503, 2021, 1,
# Downloaded from https://onlinelibrary.wiley.com/doi/10.1155/2021/2087027, Wiley Online Library on [04/03/2025]. See the Terms and Conditions (https://onlinelibrary.wiley.com/terms-and-conditions) on Wiley Online Library for rules of use; OA articles are governed by the applicable Creative Commons License10Complexity8503, 2021, 1,
# O 10 ) T When k � 2,
#
# ----- Excerpt 2: -----
# ID 2635714, 16 pages
#
#
#
#
# 		A rough set-based bioinspired fault diagnosis method for electrical substations
#
# 			TWang
#
#
# 			WLiu
#
#
# 			JBZhao
#
# 		ID 105961
#
#
# 		International Journal of Electrical Power & Energy Systems
#
# 			119
# 			2020
#
#
#
#
#
#
# 		Simplified and yet turing universal spiking neural P systems with polarizations optimized by anti-spikes
#
# 			TWu
#
#
# 			TZhang
#
#
# 			FXu
#
#
#
# 		Neurocomputing
#
# 			414
#
# 			2020
#
#
#
#
#
#
# 		Spiking neural P systems with polarizations and rules on synapses
#
# 			SXJiang
#
#
# 			JHFan
#
#
# 			YJLiu
#
#
#
# 		Complexity
#
# 			2020
# 			2020
#
#
# 	Article ID 8742308, 12 pages
#
#
#
#
# 		Spiking neural P systems with polarizations
#
# 			TWu
#
#
# 			APaun
#
#
# 			ZZhang
#
#
# 			LPan
#
#
#
# 		IEEE Transactions on Neural Networks and Learning Systems
#
# 			29
# 			8
#
# 			2018
#
#
#
#
#
#
# 		A weighted corrective fuzzy reasoning spiking neural P system for fault diagnosis in power systems with variable topologies
#
# 			TWang
#
#
# 			XGWei
#
#
# 			JWang
#
#
#
# 		Engineering Applications of Artificial Intelligence
#
# 			92
#
# 			2019
#
#
# 	Article ID 103680
#
#
#
#
# 		A fault diagnosis method for power transmission networks based on spiking neural P systems with self-updating rules considering biological apoptosis mechanism
#
# 			WLiu
#
#
# 			TWang
#
#
# 			TLZang
#
# 		ID 2462647
#
#
# 		Complexity
#
# 			2020
# 			2020
#
#
#
#
#
#
# 		Uncertainty measure in evidence theory
#
# 			YDeng
#
#
#
# 		Science China Information Sciences
#
# 			63
# 			11
#
# 			2020
#
#
#
#
#
#
# 		Entailment for intuitionistic fuzzy sets based on generalized belief structures
#
# 			YXue
#
#
# 			YDeng
#
#
#
# 		International Journal of Intelligent Systems
#
# 			35
# 			6
#
# 			2020
#
#
#
#
#
#
# 		Essential motor health monitoring: making informed decisions about motor maintenance before a failure
#
# ----- Excerpt 3: -----
# Journal of Intelligent Systems
#
# 			35
# 			6
#
# 			2020
#
#
#
#
#
#
# 		Essential motor health monitoring: making informed decisions about motor maintenance before a failure occurs
#
# 			RLoiselle
#
#
# 			ZXu
#
#
# 			IVoloh
#
#
#
# 		IEEE Industry Applications Magazine
#
# 			24
# 			6
#
# 			2018
#
#
#
#
#
#
# 		Induction motors fault diagnosis using finite element method: a review
#
# 			XLiang
#
#
# 			MZAli
#
#
# 			HZhang
#
#
#
# 		IEEE Transactions on Industry Applications
#
# 			56
# 			2
#
# 			2020
#
#
#
#
#
#
# 		A motor fault diagnosis system based on cerebellar model articulation controller
#
# 			PYChen
#
#
# 			KHChao
#
#
# 			YCTseng
#
#
#
# 		IEEE Access
#
# 			7
#
# 			2019
#
#
#
#
#
#
# 		Novel approach using Hilbert transform for multiple broken rotor bars fault location detection for three phase induction motor
#
# 			MBAbd-El-Malek
#
#
# 			AKAbdelsalam
#
#
# 			OEHassan
#
#
#
# 		ISA Transactions
#
# 			80
#
# 			2018
#
#
#
#
#
#
# 		Enhanced sparse period-group lasso for bearing fault diagnosis
#
# 			ZZhao
#
#
# 			SWu
#
#
# 			BQiao
#
#
# 			SWang
#
#
# 			XChen
#
#
#
# 		IEEE Transactions on Industrial Electronics
#
# 			66
# 			3
#
# 			2019
#
#
#
#
#
#
# 		Fault tree analysis of floating offshore wind turbines
#
# 			JKang
#
#
# 			LSun
#
#
# 			CGuedesSoares
#
#
#
# 		Renewable Energy
#
# 			133
#
# 			2019
#
#
#
#
#
#
# 		A new geometric mean FMEA method based on information quality
#
# 			XCao
#
#
# 			YDeng
#
#
#
# 		IEEE Access
#
# 			7
# 			1
#
# 			2019
#
#
#
#
#
#
# 		A bidirectional diagnosis algorithm of fuzzy petri net using inner-reasoningpath
#
# 			KQZhou
#
#
# 			WHGui
#
#
# 			LPMo
#
#
#
# 		Symmetry-Basel
#
# 			10
# 			6
#
# 			2018

# %% [markdown]
# ## Prompting the models

# %%
# Read the content of open_ai_key.txt into a variable
with open('../open_ai_key.txt', 'r') as file:
    open_ai_key = file.read().strip()

# %%
from openai import OpenAI
client = OpenAI(api_key=open_ai_key)

def send_prompt(prompt, model="gpt-3.5-turbo-0125"):
    completion = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "user",
                "content": prompt
            }
        ]
    )
    return completion.choices[0].message.content

# %%
send_prompt(example_prompt)
# Out:
# '{\n    "label": "Unsubstantiated",\n    "explanation": "The reference article does not mention anything related to reducing irreversibility or optimizing energy-consumed devices as stated in the citing article."\n}'

# %%
# Create a new column in the dataframe to store the responses
df['Model Classification'] = None

# Iterate through the dataframe
for index, row in df.iterrows():
    if row['Reference Article Downloaded'] == 'Yes':
        print(f"Processing: " + row['Reference Article ID'])

        # Create the prompt
        prompt = create_prompt(row)
        
        # Send the prompt and get the response
        response = send_prompt(prompt)
        
        # Save the response to the new column
        df.at[index, 'Model Classification'] = response

# Display the updated dataframe
df.head()
# Out:
# Processing: r001
# Processing: r002
# Processing: r003
# Processing: r004
# Processing: r005
# Processing: r006
# Processing: r007
# Processing: r008
# Processing: r009
# Processing: r010
# Processing: r011
# Processing: r012
# Processing: r013
# Processing: r013
# Processing: r014
# Processing: r015
# Processing: r005
# Processing: r017
# Processing: r018
# Processing: r019
# Processing: r020
# Processing: r021
# Processing: r022
# Processing: r023
# Processing: r024
# Processing: r013
# Processing: r025
# Processing: r026
# Processing: r027
# Processing: r028
# Processing: r029
# Processing: r030
# Processing: r031
# Processing: r032
# Processing: r033
# Processing: r034
# Processing: r035
# Processing: r036
# Processing: r037
# Processing: r038
# Processing: r039
# Processing: r040
# Processing: r041
# Processing: r042
# Processing: r043
# Processing: r044
# Processing: r045
# Processing: r046
# Processing: r047
# Processing: r048
# Processing: r049
# Processing: r050
# Processing: r051
# Processing: r052
# Processing: r053
# Processing: r051
# Processing: r055
# Processing: r056
# Processing: r057
# Processing: r058
# Processing: r059
# Processing: r060
# Processing: r061
# Processing: r062
# Processing: r063
# Processing: r064
# Processing: r065
# Processing: r066
# Processing: r067
# Processing: r068
# Processing: r069
# Processing: r070
# Processing: r071
# Processing: r072
# Processing: r074
# Processing: r075
# Processing: r076
# Processing: r077
# Processing: r078
# Processing: r079
# Processing: r080
# Processing: r081
# Processing: r081
# Processing: r082
# Processing: r083
# Processing: r084
# Processing: r085
# Processing: r086
# Processing: r087
# Processing: r087
# Processing: r087
# Processing: r088
# Processing: r089
# Processing: r090
# Processing: r091
# Processing: r092
# Processing: r093
# Processing: r094
# Processing: r095
# Processing: r096
# Processing: r097
# Processing: r098
# Processing: r099
# Processing: r100
# Processing: r101
# Processing: r102
# Processing: r103
# Processing: r104
# Processing: r105
# Processing: r106
# Processing: r107
# Processing: r108
# Processing: r109
# Processing: r110
# Processing: r111
# Processing: r112
# Processing: r113
# Processing: r114
# Processing: r115
# Processing: r116
# Processing: r117
# Processing: r118
# Processing: r119
# Processing: r120
# Processing: r121
# Processing: r122
# Processing: r123
# Processing: r124
# Processing: r125
# Processing: r126
# Processing: r127
# Processing: r128
# Processing: r129
# Processing: r130
# Processing: r131
# Processing: r132
# Processing: r133
# Processing: r134
# Processing: r135
# Processing: r136
# Processing: r137
# Processing: r138
# Processing: r139
# Processing: r140
# Processing: r141
# Processing: r142
# Processing: r143
# Processing: r144
# Processing: r145
# Processing: r146
# Processing: r147
# Processing: r148
# Processing: r149
# Processing: r150
# Processing: r151
# Processing: r152
# Processing: r153
# Processing: r154
# Processing: r155
# Processing: r156
# Processing: r157
# Processing: r158
# Processing: r159
# Processing: r160
# Processing: r161
# Processing: r162
# Processing: r163
# Processing: r164
# Processing: r165
# Processing: r166
# Processing: r167
# Processing: r168
# Processing: r169
# Processing: r170
# Processing: r171
# Processing: r172
# Processing: r173
# Processing: r174
# Processing: r175
# Processing: r176
# Processing: r177
# Processing: r178
# Processing: r179
# Processing: r180
# Processing: r181
# Processing: r182
# Processing: r183
# Processing: r184
# Processing: r185
# Processing: r186
# Processing: r187
# Processing: r188
# Processing: r189
# Processing: r190
# Processing: r191
# Processing: r192
# Processing: r193
# Processing: r194
# Processing: r195
# Processing: r196
# Processing: r197
# Processing: r198
# Processing: r199
# Processing: r200
# Processing: r201
# Processing: r202
# Processing: r203
# Processing: r204
# Processing: r205
# Processing: r206
# Processing: r207
# Processing: r208
# Processing: r209
# Processing: r210
# Processing: r211
# Processing: r212
# Processing: r213
# Processing: r214
# Processing: r215
# Processing: r216
# Processing: r217
# Processing: r218
# Processing: r219
# Processing: r220
# Processing: r221
# Processing: r222
# Processing: r223
# Processing: r224
# Processing: r225
# Processing: r226
# Processing: r227
# Processing: r228
# Processing: r229
# Processing: r230
# Processing: r231
# Processing: r232
# Processing: r233
# Processing: r234
# Processing: r235
# Processing: r236
# Processing: r237
# Processing: r238
# Processing: r239
# Processing: r240
# Processing: r241
# Processing: r242
# Processing: r243
#     Source Citing Article ID         Citing Article DOI  \
# 0  PubPeer              c001  10.1016/j.est.2021.103553
# 1  PubPeer              c001  10.1016/j.est.2021.103553
# 2  PubPeer              c002       10.1155/2022/4601350
# 3  PubPeer              c003       10.1155/2022/2408685
# 4  PubPeer              c004       10.1155/2022/4783847
#
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain  \
# 0                       Yes  Engineering
# 1                       Yes  Engineering
# 2                       Yes    Chemistry
# 3                       Yes     Medicine
# 4                       Yes  Engineering
#
#                              Statement with Citation Reference Article ID  \
# 0  Others have aimed to reduce irreversibility or...                 r001
# 1  Some researchers have also studied various hea...                 r002
# 2  The relative content of total flavonoids in th...                 r003
# 3  Research has shown that remimazolam tosylate e...                 r004
# 4  if the efficiency of the routing algorithm is ...                 r005
#
#              Reference Article DOI  \
# 0             10.1155/2021/2087027
# 1      10.1016/j.physa.2018.12.031
# 2  10.1088/1742-6596/1937/1/012038
# 3        10.1186/s12871-018-0543-3
# 4      10.36410/jcpr.2022.23.3.312
#
#                              Reference Article Title  \
# 0  A Fault Analysis Method for Three-Phase Induct...
# 1  Develop 24 dissimilar ANNs by suitable archite...
# 2  Lipid Data Acquisition for devices Treatment o...
# 3  Effect of propofol on breast cancer cell, the ...
# 4  Analysis and research hotspots of ceramic mate...
#
#                           Reference Article Abstract  \
# 0  The fault prediction and abductive fault diagn...
# 1  The artificial neural network optimization met...
# 2  Recently, the widespread deployment of smart p...
# 3  Breast cancer is the second leading cause of c...
# 4  From the perspective of scientometrics, comb t...
#
#   Reference Article PDF Available Reference Article Retracted  \
# 0                             Yes                          No
# 1                             Yes                          No
# 2                             Yes                          No
# 3                             Yes                          No
# 4                             Yes                          No
#
#   Reference Article Downloaded           Label Explanation  \
# 0                          Yes  Unsubstantiate  Irrelevant
# 1                          Yes  Unsubstantiate  Irrelevant
# 2                          Yes  Unsubstantiate  Irrelevant
# 3                          Yes  Unsubstantiate  Irrelevant
# 4                          Yes  Unsubstantiate  Irrelevant
#
#                                      Top_3_Chunk_IDs  \
# 0  [5cb7b532-0bf6-42e8-b245-5ce118330981, 9c03161...
# 1  [cfec4c95-2610-4b0d-b81e-3c46710e02e3, 17e8175...
# 2  [58d642c1-5f8e-4ac3-bc25-c74eb9c6f5bf, b00c81c...
# 3  [021c7cfc-9329-4667-8653-753f07eb787d, 4aac749...
# 4  [716a8a3a-eed7-4c86-89a3-d63beecb4ff3, 7776e6e...
#
#                                    Top_3_Chunk_Texts  \
# 0  [the winding and lead wirep 15Connection box j...
# 1  [Therm. Anal. Calorim\n\t\t\n\t\t\t131\n\t\t\t...
# 2  [mmol/l and 6.96 mmol/l TG calculation concent...
# 3  [J Anaesthesiol\n\t\t\n\t\t\t22\n\t\t\t8\n\t\t...
# 4  [size indicator is high, reflecting the import...
#
#                                 Model Classification
# 0  {\n    "label": "Unsubstantiated",\n    "expla...
# 1  {\n    "label": "Unsubstantiated",\n    "expla...
# 2  {\n    "label": "Unsubstantiated",\n    "expla...
# 3  {\n\t"label": "Partially substantiated",\n\t"e...
# 4  {\n    "label": "Unsubstantiated",\n    "expla...

# %%
df.head()
# Out:
#     Source Citing Article ID         Citing Article DOI  \
# 0  PubPeer              c001  10.1016/j.est.2021.103553
# 1  PubPeer              c001  10.1016/j.est.2021.103553
# 2  PubPeer              c002       10.1155/2022/4601350
# 3  PubPeer              c003       10.1155/2022/2408685
# 4  PubPeer              c004       10.1155/2022/4783847
#
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain  \
# 0                       Yes  Engineering
# 1                       Yes  Engineering
# 2                       Yes    Chemistry
# 3                       Yes     Medicine
# 4                       Yes  Engineering
#
#                              Statement with Citation Reference Article ID  \
# 0  Others have aimed to reduce irreversibility or...                 r001
# 1  Some researchers have also studied various hea...                 r002
# 2  The relative content of total flavonoids in th...                 r003
# 3  Research has shown that remimazolam tosylate e...                 r004
# 4  if the efficiency of the routing algorithm is ...                 r005
#
#              Reference Article DOI  \
# 0             10.1155/2021/2087027
# 1      10.1016/j.physa.2018.12.031
# 2  10.1088/1742-6596/1937/1/012038
# 3        10.1186/s12871-018-0543-3
# 4      10.36410/jcpr.2022.23.3.312
#
#                              Reference Article Title  \
# 0  A Fault Analysis Method for Three-Phase Induct...
# 1  Develop 24 dissimilar ANNs by suitable archite...
# 2  Lipid Data Acquisition for devices Treatment o...
# 3  Effect of propofol on breast cancer cell, the ...
# 4  Analysis and research hotspots of ceramic mate...
#
#                           Reference Article Abstract  \
# 0  The fault prediction and abductive fault diagn...
# 1  The artificial neural network optimization met...
# 2  Recently, the widespread deployment of smart p...
# 3  Breast cancer is the second leading cause of c...
# 4  From the perspective of scientometrics, comb t...
#
#   Reference Article PDF Available Reference Article Retracted  \
# 0                             Yes                          No
# 1                             Yes                          No
# 2                             Yes                          No
# 3                             Yes                          No
# 4                             Yes                          No
#
#   Reference Article Downloaded           Label Explanation  \
# 0                          Yes  Unsubstantiate  Irrelevant
# 1                          Yes  Unsubstantiate  Irrelevant
# 2                          Yes  Unsubstantiate  Irrelevant
# 3                          Yes  Unsubstantiate  Irrelevant
# 4                          Yes  Unsubstantiate  Irrelevant
#
#                                      Top_3_Chunk_IDs  \
# 0  [5cb7b532-0bf6-42e8-b245-5ce118330981, 9c03161...
# 1  [cfec4c95-2610-4b0d-b81e-3c46710e02e3, 17e8175...
# 2  [58d642c1-5f8e-4ac3-bc25-c74eb9c6f5bf, b00c81c...
# 3  [021c7cfc-9329-4667-8653-753f07eb787d, 4aac749...
# 4  [716a8a3a-eed7-4c86-89a3-d63beecb4ff3, 7776e6e...
#
#                                    Top_3_Chunk_Texts  \
# 0  [the winding and lead wirep 15Connection box j...
# 1  [Therm. Anal. Calorim\n\t\t\n\t\t\t131\n\t\t\t...
# 2  [mmol/l and 6.96 mmol/l TG calculation concent...
# 3  [J Anaesthesiol\n\t\t\n\t\t\t22\n\t\t\t8\n\t\t...
# 4  [size indicator is high, reflecting the import...
#
#                                 Model Classification
# 0  {\n    "label": "Unsubstantiated",\n    "expla...
# 1  {\n    "label": "Unsubstantiated",\n    "expla...
# 2  {\n    "label": "Unsubstantiated",\n    "expla...
# 3  {\n\t"label": "Partially substantiated",\n\t"e...
# 4  {\n    "label": "Unsubstantiated",\n    "expla...

# %%
df.to_pickle('../data/ReferenceErrorDetection_data_with_prompt_results.pkl')

# %% [markdown]
# ## Compare model classification with labels

# %%
# Fix the entries where additional json prefixes and suffixes were added
for index, row in df.iterrows():
    if row['Model Classification'] and row['Model Classification'].startswith("```json") and row['Model Classification'].endswith("```"):
        df.at[index, 'Model Classification'] = row['Model Classification'][7:-3].strip()
    elif row['Model Classification'] and row['Model Classification'].startswith("```json") and row['Model Classification'].rstrip().endswith("```"):
        df.at[index, 'Model Classification'] = row['Model Classification'][7:].rstrip()[:-3].strip()

# %% [markdown]
# ### All labels

# %%
import json

correct_classification = 0
incorrect_classification = 0
json_error = 0

for index, row in df.iterrows():
    if row['Reference Article Downloaded'] == 'Yes':
        try:
            model_classification = json.loads(row['Model Classification'])
            # print(f"{model_classification['label']}")
            if model_classification['label'][:-1].lower() == row['Label'].lower():
                correct_classification += 1
            else:
                # print(f"Row {index} Model Classification: {model_classification['label']} Actual Label: {row['Label']}")
                incorrect_classification += 1
        except json.JSONDecodeError as e:
            # print(f"Row {index} Model Classification could not be decoded: {e}")
            print(row['Model Classification'])
            json_error += 1

# %%
print(f"Correct classifications: {correct_classification}")
print(f"Incorrect classifications: {incorrect_classification}")
print(f"JSON errors: {json_error}")

print(f"Accuracy: {correct_classification / (correct_classification + incorrect_classification + json_error)}")
print(f"Accuracy without JSON errors: {correct_classification / (correct_classification + incorrect_classification)}")
# Out:
# Correct classifications: 135
# Incorrect classifications: 112
# JSON errors: 0
# Accuracy: 0.5465587044534413
# Accuracy without JSON errors: 0.5465587044534413

# %% [markdown]
# ### Only two labels

# %%
import json

correct_classification = 0
incorrect_classification = 0
json_error = 0

for index, row in df.iterrows():
    if row['Reference Article Downloaded'] == 'Yes':
        try:
            model_classification = json.loads(row['Model Classification'])
            # print(f"{model_classification['label']}")
            if model_classification['label'][:-1].lower() in ['fully substantiate', 'partially substantiate'] and row['Label'].lower() in ['fully substantiate', 'partially substantiate']:
                correct_classification += 1
            elif model_classification['label'][:-1].lower() == 'unsubstantiate' and row['Label'].lower() == 'unsubstantiate':
                correct_classification += 1
            elif model_classification['label'][:-1].lower() not in ['fully substantiate', 'partially substantiate', 'unsubstantiate']:
                print(f"Row {index} Model Classification: {model_classification['label']} Actual Label: {row['Label']}")
                incorrect_classification += 1
            else:
                # print(f"Row {index} Model Classification: {model_classification['label']} Actual Label: {row['Label']}")
                incorrect_classification += 1
        except json.JSONDecodeError as e:
            # print(f"Row {index} Model Classification could not be decoded: {e}")
            json_error += 1

# %%
print(f"Correct classifications: {correct_classification}")
print(f"Incorrect classifications: {incorrect_classification}")
print(f"JSON errors: {json_error}")

print(f"Accuracy: {correct_classification / (correct_classification + incorrect_classification + json_error)}")
print(f"Accuracy without JSON errors: {correct_classification / (correct_classification + incorrect_classification)}")
# Out:
# Correct classifications: 196
# Incorrect classifications: 51
# JSON errors: 0
# Accuracy: 0.7935222672064778
# Accuracy without JSON errors: 0.7935222672064778
